# %%
path = "data"
filename = "Leads06082020"


import os, random, sys, time
# from urllib.parse import urlparse
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.common.exceptions import NoSuchElementException
from Detect_New_Entries import detect_new_entires, merge_new_entires
import time

# Scrapes the new data from glassdoor
# and saves it to the Scrapping revenue.xlsx
from selenium import webdriver

#     browser = webdriver.Chrome(executable_path=r'C:\path\to\chromedriver.exe')
#     browser.get('http://google.com/')

### LEADS MISSING
##############################################################
leads_df = pd.read_excel('Scrapping revenue.xlsx')
original_leads = pd.read_csv(f'{path}/{filename}.csv', encoding='latin-1')

### LEADS MISSING
##############################################################
original_leads = original_leads.rename({'Company / Account':'Company'}, axis=1)
scraped_comp = pd.DataFrame(leads_df['Name'].unique(),columns=["Comp"]).dropna()
orig_leads = pd.DataFrame(original_leads['Company'].unique(),columns=["Comp"]).dropna()

to_scrape = orig_leads.merge(scraped_comp,indicator = True, how='left').loc[lambda x : x['_merge']!='both']
new_leads = to_scrape['Comp']
#     new_leads = list(set(scraped_comp) - set(orig_leads))
print("New Leads in Scrapping revenue:", len(new_leads))
# Out:
# New Leads in Scrapping revenue: 6859

# %%
### LOGIN
##############################################################
browser = webdriver.Chrome('driver/chromedriver83.exe')
browser.get('https://www.glassdoor.es/profile/login_input.htm?userOriginHook=HEADER_SIGNIN_LINK')

file = open('CONFIG/config_glassdoor.txt')
lines = file.readlines()
username = lines[0]
password = lines[1]

time.sleep(round(random.uniform(1, 2),2))

##############################################################
elementID = browser.find_element_by_id('userEmail')
elementID.send_keys(username)
time.sleep(round(random.uniform(1, 1.3),2))

elementID = browser.find_element_by_id('userPassword')
elementID.send_keys(password)
time.sleep(round(random.uniform(1, 2),2))

elementID.submit()

# %%
# READ
##############################################################
company_list = new_leads
company_list = company_list.dropna() 
company_list = company_list.drop_duplicates()
company_list = company_list.tolist()
companies = company_list
print("New companies:", len(companies))
# Out:
# New companies: 6859

# %%
### LOOP
##############################################################
companies_list = []
companies_count = 0

browser.get('https://www.glassdoor.es/Opiniones/barcelona-amazon-opiniones-SRCH_IL.0,9_IM1015_KE10,16.htm')

for company in companies:
    error = False
    inside_page = False
    headers_list = []
    comp_data_list = []

    headers_list.append('Name')
    comp_data_list.append(company)
    browser.get('https://www.glassdoor.es/Opiniones/barcelona-amazon-opiniones-SRCH_IL.0,9_IM1015_KE10,16.htm')

    time.sleep(round(random.uniform(3, 4),2))

    try: 
        elementID = browser.find_element_by_id('sc.keyword')
    except: ## ERROR WHEN IT GETS OUT OF THE OPINIONS SEARCH
        browser.get('https://www.glassdoor.es/Opiniones/barcelona-amazon-opiniones-SRCH_IL.0,9_IM1015_KE10,16.htm')
        error = True
    elementID = browser.find_element_by_id('sc.keyword')
    elementID.send_keys(Keys.CONTROL, 'a')
    elementID.send_keys(Keys.BACKSPACE)
    elementID.send_keys(company)
    elementID.submit()


    time.sleep(round(random.uniform(5, 7),2))

    ### SOMETIMES IT ENTERS THE PAGE DIRECTLY
    try:
        browser.find_element_by_xpath("//span[@class='sqLogo tighten lgSqLogo logoOverlay']//img").click()
        inside_page = True
    except:
        pass

    # IF COMPANY NOT FOUND, CATCH.
    if inside_page == False:
        try:
            browser.find_element_by_xpath("//body[contains(@class,'_initOk noTouch tablet mobileFF')]/div[contains(@class,'pageContentWrapper')]/div[@id='PageContent']/div[@id='PageBodyContents']/div[contains(@class,'pageInsideContent cf')]/div[@id='EI-Srch']/div[@id='SearchResults']/div[@id='ReviewSearchResults']/article[@id='MainCol']/div[contains(@class,'module')]/div[2]/div[1]/div[2]/div[1]").click()  
        except NoSuchElementException:  #spelling error making this code not work as expected
            error = True

    time.sleep(round(random.uniform(5, 6),2))    

    if error==False:    
        src = browser.page_source
        soup = BeautifulSoup(src, 'lxml')

        try:
            company_div = soup.find('div', {'class': 'info flexbox row col-hh'})
            header = company_div.find_all('label')
            info = company_div.find_all('span')
        except:
            pass

        for i in range(0,len(header)):
            headers_list.append(header[i].get_text().strip())
            comp_data_list.append(info[i].get_text().strip())

    companies_list.append(headers_list)
    companies_list.append(comp_data_list)

    companies_count = companies_count+1
    if companies_count % 250 == 0:
        time.sleep(round(random.uniform(65, 90),2))
    print('{}: Scraping: {}% completed - {}'.format(companies_count,round(companies_count/len(companies)*100,2),company))


companies_list

grid_header = ['Name','Sitio web', 'Sede', 'Tamaño', 'Fundada en', 'Tipo', 'Sector', 'Ingresos']
dataframe = []

for k in range(0,companies_count):
    j = 0
    i = 0
    lista = []

    while i< len(grid_header):
        try:
            if grid_header[i] == companies_list[0+k*2][j]:
                field = companies_list[1+k*2][j]
            else:
                field = None
                j -= 1
            lista.append(field)
            j +=1

        except:
            lista.append(None)
        i += 1    
    dataframe.append(lista)

df = pd.DataFrame.from_records(dataframe,columns=grid_header)
# Out:
# 1: Scraping: 6.25% completed - Introstat Printing and IT Solutions
# 2: Scraping: 12.5% completed - P.h.d in industrial and production engineering
# 3: Scraping: 18.75% completed - University of Bologna-School of engineering and architecture
# 4: Scraping: 25.0% completed - Mitchell and son web design ltd
# 5: Scraping: 31.25% completed - LeoTech Rapid Prototyping and Tooling GmbH
# 6: Scraping: 37.5% completed - Cimtas Precision Machining Industries and Trading Ltd. Co.
# 7: Scraping: 43.75% completed - ASDT - Aerospace Security and Defense Tecnologies
# 8: Scraping: 50.0% completed - Grassroots Arts and Research UG
# 9: Scraping: 56.25% completed - Boogertman and Partners Architects
# 10: Scraping: 62.5% completed - The Foot and Leg Clinic
# 11: Scraping: 68.75% completed - Berry and Escott Engineering
# 12: Scraping: 75.0% completed - Baldwin and Francis
# 13: Scraping: 81.25% completed - depot and factory equipment ltd.
# 14: Scraping: 87.5% completed - Airbus Defence and Space
# 15: Scraping: 93.75% completed - Larsen and toubro ltd
# 16: Scraping: 100.0% completed - Scholar and Network

# %%
df
# Out:
#                                                  Name  \
# 0                 Introstat Printing and IT Solutions
# 1      P.h.d in industrial and production engineering
# 2   University of Bologna-School of engineering an...
# 3                     Mitchell and son web design ltd
# 4          LeoTech Rapid Prototyping and Tooling GmbH
# 5   Cimtas Precision Machining Industries and Trad...
# 6   ASDT - Aerospace Security and Defense Tecnologies
# 7                     Grassroots Arts and Research UG
# 8                  Boogertman and Partners Architects
# 9                             The Foot and Leg Clinic
# 10                       Berry and Escott Engineering
# 11                                Baldwin and Francis
# 12                   depot and factory equipment ltd.
# 13                           Airbus Defence and Space
# 14                              Larsen and toubro ltd
# 15                                Scholar and Network
#
#                    Sitio web                                Sede  \
# 0                       None                                None
# 1                       None                                None
# 2                       None                                None
# 3                       None                                None
# 4                       None                                None
# 5                       None                                None
# 6                       None                                None
# 7                       None                                None
# 8                       None                                None
# 9                       None                                None
# 10                      None                                None
# 11                      None                                None
# 12                      None                                None
# 13                      None                                None
# 14            www.lntecc.com                                None
# 15  www.healthpronetwork.com  Panorama City, CA (Estados Unidos)
#
#                      Tamaño      Fundada en             Tipo  \
# 0                      None            None             None
# 1                      None            None             None
# 2                      None            None             None
# 3                      None            None             None
# 4                      None            None             None
# 5                      None            None             None
# 6                      None            None             None
# 7                      None            None             None
# 8                      None            None             None
# 9                      None            None             None
# 10                     None            None             None
# 11                     None            None             None
# 12                     None            None             None
# 13                     None            None             None
# 14  De 501 a 1000 empleados  Desconocido(a)  Empresa privada
# 15      De 1 a 50 empleados  Desconocido(a)  Empresa privada
#
#                                         Sector  \
# 0                                         None
# 1                                         None
# 2                                         None
# 3                                         None
# 4                                         None
# 5                                         None
# 6                                         None
# 7                                         None
# 8                                         None
# 9                                         None
# 10                                        None
# 11                                        None
# 12                                        None
# 13                                        None
# 14                                Construcción
# 15  Contratación de personal y externalización
#
#                             Ingresos
# 0                               None
# 1                               None
# 2                               None
# 3                               None
# 4                               None
# 5                               None
# 6                               None
# 7                               None
# 8                               None
# 9                               None
# 10                              None
# 11                              None
# 12                              None
# 13                              None
# 14  Desconocido/No aplicable por año
# 15  Desconocido/No aplicable por año

# %%
### SAVE
##############################################################
prev_file = pd.read_excel("Scrapping revenue.xlsx")
date_string = time.strftime("%Y-%m-%d-%Hh")

out_grid_header = ['Name','Sitio web', 'Sede', 'Tamaño', 'Fundada en', 'Tipo', 'Sector', 'Ingresos']

mix_file = prev_file.append(df)
mix_file = mix_file.drop(columns=['Unnamed: 0'])
mix_file = mix_file[out_grid_header]

mix_file.to_excel("Scrapping revenue.xlsx")
mix_file.to_excel(f'backups_scrape/Scrapping revenue{date_string}.xlsx')
print("Scrapping revenue and its backups saved correctly.")
# Out:
# C:\Users\solej\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# Scrapping revenue and its backups saved correctly.
