# %% [markdown]
# ## LinkedIn Auto Connect Bot

# %%
import os, random, sys, time
# from urllib.parse import urlparse
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.common.exceptions import NoSuchElementException

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
### LOGIN
##############################################################
browser = webdriver.Chrome('driver/chromedriver.exe')
browser.get('https://www.linkedin.com/login')

file = open('config_linkedin_6.txt')
lines = file.readlines()
username = lines[0]
password = lines[1]

##############################################################
elementID = browser.find_element_by_id('username')
elementID.send_keys(username)

elementID = browser.find_element_by_id('password')
elementID.send_keys(password)
elementID.submit()

# %%
# READ
##############################################################
leads_df = pd.read_csv('data2.csv')
leads_df = leads_df.sort_values(by=['FYQ Created On Correct'], ascending=False)
leads_df = leads_df[leads_df['Lead Status']!='Qualified']

company_list = leads_df['Company']
company_list = company_list.dropna() 
company_list = company_list.drop_duplicates()
company_list = company_list.tolist()

##############################################################
companies = company_list[19500:20000] ### FALTA
##############################################################
companies
# Out:
# ['Finnish Enviroment Institute',
#  'Rabbit Disruptive Innovation',
#  'NOVAIR',
#  'ProCut',
#  'Procurement Practice GmbH',
#  'INVATEC SPA Medtronic Endovascular Therapies',
#  'HTD-Italia di Ravasi Lorenzo',
#  'Peter Brehm GmbH',
#  'PeRoBa GmbH',
#  'DOSIM S.L.',
#  'IAE SAVOIE MONT-BLAC',
#  'Iamanufacturing',
#  'Grunwald GmbH',
#  'Iapmm',
#  'IBAK Helmut Hunger GmbH Co.KG',
#  'Performio GmbH',
#  'PERADOTTO',
#  'IBS Filtran GmbH',
#  'Grünbeck Wasseraufbereitung GmbH',
#  'Ic Energo',
#  'ICFO',
#  'GROUPEKARDOL',
#  'HWB Gubesch Kunststoff engineering GmbH',
#  'Gurit Uk',
#  'GUIC INSTALLACIONS',
#  'Guenther Spelsberg GmbH Co. KG',
#  'Huawei Technologies Finland',
#  'Podotec3D',
#  'PG',
#  'Hullo 3d Design Studio',
#  'petron',
#  'HUSKY IMS',
#  'Gto Plating B.v',
#  'Husqvarna Uk Ltd',
#  'PEUGEOT DIVISION MOTOR SPORT',
#  'Gsw Uk Ltd',
#  'Hutchinson Engineering Ltd',
#  'ICREATIA.ES',
#  'ICSN-CNRS',
#  'PATENTES TALGO',
#  'Gregory Keyes Ltd',
#  'GREEN21ARQUITECTURA',
#  'PolyPid Ltd.',
#  'PATENTES TALGO SL',
#  'GREEN ELETTROPOMPE DI BRUSCOLI ENRICO',
#  'IFP',
#  'POLYTECH LYON',
#  'Polytronics',
#  'PartsGroupEurope GmbH',
#  'GRAMMER AG',
#  'Gramm UG (haftungsbeschränkt)',
#  'Ikea Communications Ab',
#  'ifolor.',
#  'GROUPECOHESIONINTERNATIONAL',
#  'GROUPE J3L',
#  'GROUPE ZEBRA',
#  'Ict',
#  'ICT MANAGER',
#  'GROUPE SURYS',
#  'GROUPE SEB ROWENTA',
#  'Idea Prototipi srl',
#  'Groupe PSA (vélizy)',
#  'Ideascout Oy',
#  'GROUPE GONZALES',
#  'GROUPE FIZFAB',
#  'GROUPE BARBIER',
#  'Pca Engineers Limited',
#  'PC System',
#  'Idtechex',
#  'Iemme sas',
#  'Paxer',
#  'IES VIRGEN DEL PILAR',
#  'H-team-mobile',
#  'PNS NV',
#  'PHENIX RETRO CONCEPT',
#  'Hirschvogel Holding GmbH',
#  'Hassia Verpackungsmaschinen GmbH',
#  'Hjbugge Consulting As',
#  'Pipex Px National Oilwell Varco Fgs',
#  'PLASTIGRAF',
#  'HMP',
#  'PINTH BUBENZER',
#  'Harting Customised Solutions GmbH Co. KG',
#  'HARTING Customised Solutions Gmbh & Co.KG',
#  'Hochschule Emden-Leer',
#  'Hochschule fuer angewandte Wissenschaften Wrzburg-Schweinfurt',
#  'Hochschule Karlsruhe',
#  'Hochschule Nordhausen',
#  'PLASTIQUE PAILLARD',
#  'Hochschule Offenburgoffenburg. university',
#  'HOET EYEWEAR',
#  'Pitkit',
#  'Pixel Cites',
#  'hf 3d',
#  'heritage spareparts consulting',
#  'Hesse GmbH',
#  'HERAFCAM',
#  'Hemocue AB',
#  'PLASTI GUN',
#  'Hemocue',
#  'HELLENPLAN LTD',
#  'Plastica',
#  'Hevel',
#  'Héliographie Girard',
#  'Hfele Berlin GmbH Co. KG',
#  'Heinrichs Co. KG - Schrauben-und Drehteilefabrik',
#  'hhter',
#  'HEIA',
#  'Highpatents',
#  'Highvoltage Union-rzva Llc',
#  'Pieper Innovationsgesellschaft GmbH',
#  'Hoganas',
#  'HOSOKAWA ALPINE AG',
#  'Halewood Jaguar Cars Ltd',
#  'HALASCO GmbH',
#  'Plus medica OT',
#  'Photek Ltd',
#  'HAFELE',
#  'Horiba Mira Ltd',
#  'Haenco UG',
#  'Pm Group',
#  'Phoenix Engineering Company Li',
#  'Halliburton',
#  'PHOENIX CONTACTConnector Technology GmbH',
#  'Phoenix Contact Spa',
#  'Howden Group',
#  'HPS GmbH',
#  'Hôpitaux Universitaires de Genève',
#  'Hardings',
#  'Pictomed',
#  'Holmatro',
#  'plastomold',
#  'HOMAG',
#  'HARA',
#  'Hansa Armaturen GmbH',
#  'Hans Böckler Berufskolleg',
#  'PLATINIUM3D',
#  'Phs Logistiktechnik Gmbh',
#  'HOME STEEL',
#  'Honda Motor Europe Logistics Nv',
#  'HANDY BIONIC SAS',
#  'platti natale c s.n.c.',
#  'Handtmann Maschinenfabrik',
#  'HanCon Hanselmann Consulting',
#  'HONEYCOMB Y COMPOSITES S. L.',
#  'Phu Seba Sp. J Gorlice',
#  'Parsons Brinckerhoff Ltd',
#  'Parmley Technologies Ltd',
#  'Procter Gamble Manufacturing GmbH',
#  'Gestra AG',
#  'Ingenieurbüro A. Dönnebrink',
#  'Ingenieurbüro Huß Feickert GbR',
#  'Ingenieursbureau JK de Heer',
#  'INLOGEM S.L.',
#  'Innalabs',
#  'GESIPA Blindniettechnik GmbH',
#  'Gesellschaft fur innovative Beschaftigng',
#  'Gerner Paul',
#  'Gerhard Schubert GmbH Verpackungsmaschinen',
#  'INNOTEC MAGYAR KFT.',
#  'Osborn Design Limited',
#  'Geometric Manufacturing Ltd',
#  'Ingenieur Studio Hollaus',
#  'OSSUR GROUP',
#  'Infomir',
#  'Pride Electrical',
#  'INFN-Genova',
#  'Gima Trade GmbH',
#  'ottobock.',
#  'Gilbert Gilkes Gordon Ltd',
#  'Info Sit',
#  'Gilbert Gilkes And Gordan',
#  'Otto Olsen As',
#  'Ingegnere l.p.',
#  'GiB mbH',
#  'Primetals Technologies Limited',
#  'GGBA',
#  'OTNET',
#  'INFYNITY BIOMARKERS',
#  'ing. Giuseppe Starace',
#  'ORWO Net GmbH',
#  'PROCIM Xperts GmbH',
#  'Institut furVerbundwerkstoffe GmbH',
#  'Institute Of Ell Biophysics Ras',
#  'INSTITUTO OFTALMOLOGIA EXTREMADURA',
#  'Probisa',
#  'INTERCOS S.p.A.',
#  'Interfleet Techology Limited',
#  'InterMedia Sistem Integrator',
#  'INTERNATIONAL HELLENIC UNIVERSITY',
#  'Interservsouz',
#  'PRO.DISTIC.ltd',
#  'Intertek',
#  'Ge Oil Gas',
#  'INTEVIA',
#  'INTROLIZ LTD.',
#  'Procter Gamble Manufactoring GmbH',
#  'pro1o1ypen',
#  'Institut für Flugzeugbau',
#  'Innovative Industrial Solutions',
#  'Inotech As',
#  'GENTILI TECHNOLOGY EQUIPMENT DI GENTILI ALDO E ERNESTO SAS',
#  'INNOVOILE SAS',
#  'private adviser',
#  'Private Busness',
#  'INNOWER 3D',
#  'Generation 3d',
#  'Ortopedic Solution Jacob-OJS',
#  'Institut fuer Produktentwicklung und Konstruktionstechnik',
#  'INOX DESIGN',
#  'INOX DESIGN s.r.l.',
#  'gen',
#  'INPLATEC PLASTICOS SL',
#  'Inspire Design S.r.o',
#  'INSTITUT ARTS ET METIERS CHAMBERY',
#  'Gimon, S.L.',
#  'PARKER HANNIFIN France SAS',
#  'Imi Plc',
#  'Pöttinger Maschinenfabrik Gesmbh',
#  'GOIALDE S.L.',
#  'Immensa Technology Labs',
#  'Panduit',
#  'Panasonic Europe',
#  'Panaitescu Victor Pfa',
#  'Pamec srl',
#  'Powder Injection Molding Saran Tch Safran Additive Manufacturing',
#  'GOEDHART REPRO',
#  'implantcast',
#  'Implement Consulting Group',
#  'Go3d Oy',
#  'Pall Europe Ltd',
#  'PALFINGER EUROPE GMBH',
#  'GMH Schmiedetechnik GmbH',
#  'Pannonia Precision Eng',
#  'Gold-cam',
#  'GOLDONI SPA',
#  'Pordir',
#  'POROCESOS INDSUTRIALES PAPEL Y FILTRACION S.L.',
#  'Grace Jens Knudsen As',
#  'GPS Reisacher GmbH & Co. KG',
#  'PARI GmbH',
#  'Paravia SRL',
#  'GORDAN MURRAY DESIGN LTD',
#  'Pos',
#  'Goprint3d',
#  'pap co.',
#  'IMERSION',
#  'pantur s.l.',
#  'GMC-I PROSYS Ltd',
#  'Gmail',
#  'pq SpA',
#  'girardini srl',
#  'INDÉPENDANT',
#  'GKVTecPart Verband Technische Kunststoff-Produkte e. V.',
#  'INDUPLAVER TRADING S.L.',
#  'Premo Ab',
#  'OZ CAR DESIGN',
#  'INDUSTRIAS ALEGRE S.A.',
#  'INDUSTRIAS DEU',
#  'PA-6UP AKMATS GMBH',
#  'giorgi srl',
#  'OXHEX',
#  'INDUSTRIAS MECÁNICAS PERALTA S.L.',
#  'INDUSTRIAS METALICAS RUIZ',
#  'OVO',
#  'OVIT ZRT',
#  'Previero N srl',
#  'PREMA INDUSTRIAL S.L.',
#  'Glatt Systemtechnik GmbH',
#  'IMPRESIONES PALMERO S.L.',
#  'Pactra International',
#  'PR CUBE',
#  'Pr H',
#  'In Summa Innovation',
#  'Gloor Gebr. AG',
#  'PRASA',
#  'Globalcom Engineering',
#  'prefer srl',
#  'Paco Sako Bv',
#  'Paco Sako',
#  'Precise',
#  'Precise Trading Co Llc',
#  'Inca Spa',
#  'PACCARd',
#  'PRÉFECTURE DE LA RÉGION AUVERGNE-RHÔNE-ALPES',
#  'FLAVIA AERONAÚTICA Y SISTEMAS',
#  'REGION AUVERGNE RHONE ALPES',
#  'Mott Macdonald Ltd',
#  'Rollstar AG',
#  'ENDEER',
#  'Mamrewood Ab',
#  'ENAR ENVOLVENTES ARQUITECTÓNICAS',
#  'MAN Diesel Turbo',
#  'ENAGRAF',
#  'ENEDIS',
#  'RONAL AG',
#  'Mott Macdonald Bentley Limited',
#  'MAN Diesel Turbo SE',
#  'MAN Truck Bus',
#  'MOTOR FR',
#  'MOTOR APPLIANCES SRL',
#  'MANIFATTURA CERAOLO MORONI SRL',
#  'Movitec Wrapping Systems, S.L.',
#  'engelbet Strauss',
#  'Engelbert Strauss GmbH Co. KG',
#  'Enermop',
#  'MP2I',
#  'Mainstay Marine Solutions Lt',
#  'ROLLOMATIC',
#  'ENERGY POOL',
#  'Energy International Systems Ltd',
#  'MOVIN SPA',
#  "'energommashspecstall",
#  'MOUSSET SARL',
#  'LASERSCAN',
#  'Roland Berger GmbH',
#  'Rotex Europe Ltd',
#  'Mora Groupe',
#  'MOPUS 3D',
#  'MAPUBLI',
#  'Maquette 74',
#  'Elopak GmbH',
#  'elobau GmbH Co. KG',
#  'MAPAL Prazisionswerkzeuge Dr. Kress KG',
#  'Elmatica As',
#  'Moog GmbH',
#  'Elka Design',
#  'ROUSSELET CENTRIFUGATION',
#  'marbet',
#  'Marden Edwards LTD',
#  'MORABALLES SLU',
#  'ROTECNA',
#  'EMPRESARIOS AGRUPADOS',
#  'MANNHUMMEL',
#  'ROSEN Technology Research Center GmbH',
#  'Mannesmann Precision Tubes',
#  'Rosendahl Gmbh',
#  'EMM',
#  'EMKA GmbH Co. KG',
#  'Eminox Ltd',
#  'Moray College',
#  'RosRoca',
#  'Emem',
#  'Mannhummel Uk',
#  'Mannhummel Uk Ltd',
#  'Manroland Systems',
#  'MORESIL S.L.',
#  'EM LYON BUSINESS SCHOOL AND ECOLE CENTRALE DE LYON',
#  "Magna Int'l",
#  'Mr.',
#  'LOVATO ELECTRIC SPA',
#  'Munsch Kunststoffschweißtechnik',
#  'Lumiradx',
#  'ESCRIBANO MECHANICAL ENGINEERING',
#  'Lupeon',
#  'LUT JHC-protolab',
#  'Esametal srl ex ALPOWER Spa',
#  'LUYTEN IMPORT',
#  'LVMH',
#  'ESDESIGN CO., LTD',
#  'es',
#  'ERT',
#  'Robert Bosch España SLU',
#  'MULTIPLAST TECNOLOGICA S.L.',
#  'M. Sc. Mechatronik und Entwicklungsingenieur',
#  'MULTICAPAS INDUSTRIAL S.L.',
#  'R-JET',
#  'erill cnc 3d',
#  'Mwh Uk',
#  'MYKITA STUDIO',
#  'Lpw Technology Ltd',
#  'eta engine technology',
#  'LSA FACTORY',
#  'Ltd. Quoteight Prioritiesquot',
#  'Ltronica',
#  'MWA Nova GmbH',
#  'MVM UNDERGROUND GAS STORAGE',
#  'Rivers State University Of Sci',
#  'ESPRIT DE VELOX FOUNDATION',
#  'MVRA ASSURANCES',
#  'MVRA',
#  'Mvp As',
#  'Lucidasolar',
#  'ERPRO',
#  'MULTICAPAS INDUSTRIAL',
#  'Ent-cUungsg Produktnfs GmbH',
#  'EOLANESAINT-AGREVE',
#  'Environmental Pumping Solutions Ltd',
#  'Envion Oy',
#  'Rockwell Collins',
#  'Entf',
#  'Ensinger Italia',
#  'Ensemble',
#  'Rodriguez',
#  'Magan Alexandru Pfa',
#  'Eni RM',
#  'Engnsol',
#  'Engitec Lda',
#  'ROINSAL PREMAM',
#  'EP MECA',
#  'Rocad',
#  'M.G.I. SRL',
#  'M.H. Material Handling Spa',
#  'M.I. Medical',
#  'ROBERT STANBURY SPRL',
#  'M.ROAD CONSEIL',
#  'M.t.a. Doo',
#  'Mubea',
#  'MTU Friedrichshafen GmbH',
#  'Eppendorf',
#  'MTS GALERIES',
#  'Mac Srl',
#  'MACARBOX',
#  'erciyes university',
#  'Robonica Srl',
#  'EQUIPOS DE RECICLADO BIOLÓGICO S.L.',
#  'MT',
#  'Monte Bianco Sa',
#  'ROVIPHARM',
#  'Rowantelmac',
#  'midrand glass aluminium',
#  'Midlothian Council',
#  'Mercedes AMG',
#  'SAFAC SRL',
#  'Mercedes Benz',
#  'Microtel spa',
#  'SAFIR',
#  'Memcom',
#  'Dumlupinar',
#  'Microcosm Pty Ltd',
#  'Micro Matic AS',
#  'MESRUR MUHENDISLIK',
#  'DUCOS CONSULTANT',
#  'Ducab',
#  'E. U. POLTECNICA LA ALMUNIA',
#  'MEMBRE DU RESEAU INFINITY CAPITAL',
#  'Millennium 7',
#  'ECAM LYON',
#  'ECAF',
#  'Ebs Ink Jet',
#  'MINERALES DEL BREZO S.L.',
#  'Mineral Processing Services',
#  'mikrosens electronics',
#  'MELTON S.L.',
#  'Meggitt Thermal Systems',
#  'EASINNOV',
#  'SACMI IMOLA S.C.',
#  'MELAG MEdizintechnik oHG',
#  'MeliesArt',
#  'MIHB',
#  'SACOPA',
#  'Messe Dusseldorf',
#  'Montblanc-Simplo GmbH',
#  'Dr B Lynch',
#  'DQBD',
#  'Metro AG',
#  'DPS Software GmbH',
#  'Dpm Srl',
#  'MG-TECH',
#  'MÉTROPOLE DE LYON',
#  'MEU',
#  'Saith Limited',
#  'Mexence Digital & Robotics',
#  'Dounreay Site Restoration Ltd',
#  'MEYER WERFT',
#  'MG63',
#  'MG TECH',
#  'Dositecno 95',
#  'Salvision',
#  'DOSIPER',
#  'MH MATERIAL HANDLING SRL',
#  'Safripol',
#  'SAINTBRIEUCFACTORY',
#  'MeSys',
#  'MET Company',
#  'METADESK',
#  'Metal Processing',
#  'DResearch',
#  'Dr. Ing. h.c. F. Porsche Aktiengesellschat',
#  'dresden-elektronik',
#  'Saint-Gobain Performance Plastics LS GmbH',
#  'SAINTJEANINDUSTRIES',
#  'Metaltecna srl',
#  'metec snc',
#  'Saipem Norge As',
#  'Meth Engineering & Consulting S.R.L.',
#  'Dr. Ing. H.c.F. Porsche AG',
#  "ECAM, ÉCOLE D'INGÉNIEUR",
#  'MECTROL',
#  'Minghua Logistics Technology GmbH',
#  'EL Global',
#  'Electricon Systems International',
#  'Eldevik Industridesign As',
#  'ELCOM',
#  'Materflow',
#  'Materials Matter Ltd',
#  'MATERIANOVA',
#  'Ekza',
#  'RS Components Limited',
#  'Rudi Schindhelm Metall GmbH Co KG']

# %%
### LOOP
##############################################################

companies_list = []
companies_count = 0

for company in companies:
       
    browser.get('https://www.linkedin.com/')
    comp_search = "https://www.linkedin.com/search/results/companies/?keywords="
    fullLink_search = comp_search + company
    browser.get(fullLink_search)
    time.sleep(round(random.uniform(6, 9),2))

    error = False

    headers_list = []
    comp_data_list = []
    
    comp_data_list.append(company)
    headers_list.append('Name')
    
    # If it does not find the company catch.
    try:
        browser.find_element_by_xpath("//h3[@class='search-result__title t-16 t-black t-bold']").click()   
    except NoSuchElementException:  #spelling error making this code not work as expected
        companies_list.append(headers_list)
        companies_list.append(comp_data_list)
        error = True
    
    time.sleep(round(random.uniform(6, 9),2))
    
    if error == False:
        current_page = browser.current_url
        
        if "about/" in current_page:
            pass
        else:
            fullLink = current_page + "about/"
            browser.get(fullLink)
        browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(round(random.uniform(6, 9),2))
        
        src = browser.page_source
        soup = BeautifulSoup(src, 'lxml')
        
        try:
            comp_data_list.append(browser.find_element_by_xpath("//h1[@class='org-top-card-summary__title t-24 t-black truncate']").text)
            headers_list.append('Web_Name')
        except NoSuchElementException:  
            pass 
        
        
        company_div = soup.find('div', {'class': 'org-grid__core-rail--no-margin-left'})
        comp = company_div.find_all('p')
        
        # Chech if there is anything in the about page
        try:
            comp_desc = comp[0]
        except IndexError:  #spelling error making this code not work as expected
            companies_list.append(headers_list)
            companies_list.append(comp_data_list)
            error = True    
            
        if error == False:    
            comp_desc = comp[0].get_text().strip() 
            header = company_div.find_all('dt')
            comp_data = company_div.find_all('dd')

            j = 0         
            for i in range(len(header)):
                headers_list.append(header[i].get_text().strip())
                comp_data_list.append(comp_data[j].get_text().strip())
                if header[i].get_text().strip()=="Company size" and len(header) < len(comp_data):
                    j += 1  
                j += 1

            companies_list.append(headers_list)
            companies_list.append(comp_data_list)
        
    companies_count = companies_count+1
    if companies_count % 150 == 0:
        time.sleep(round(random.uniform(65, 90),2))
        
    print('{}: Scraping: {}% completed - {}'.format(companies_count,round(companies_count/len(companies)*100,2),company))
# Out:
# 1: Scraping: 0.2% completed - Finnish Enviroment Institute
# 2: Scraping: 0.4% completed - Rabbit Disruptive Innovation
# 3: Scraping: 0.6% completed - NOVAIR
# 4: Scraping: 0.8% completed - ProCut
# 5: Scraping: 1.0% completed - Procurement Practice GmbH
# 6: Scraping: 1.2% completed - INVATEC SPA Medtronic Endovascular Therapies
# 7: Scraping: 1.4% completed - HTD-Italia di Ravasi Lorenzo
# 8: Scraping: 1.6% completed - Peter Brehm GmbH
# 9: Scraping: 1.8% completed - PeRoBa GmbH
# 10: Scraping: 2.0% completed - DOSIM S.L.
# 11: Scraping: 2.2% completed - IAE SAVOIE MONT-BLAC
# 12: Scraping: 2.4% completed - Iamanufacturing
# 13: Scraping: 2.6% completed - Grunwald GmbH
# 14: Scraping: 2.8% completed - Iapmm
# 15: Scraping: 3.0% completed - IBAK Helmut Hunger GmbH Co.KG
# 16: Scraping: 3.2% completed - Performio GmbH
# 17: Scraping: 3.4% completed - PERADOTTO
# 18: Scraping: 3.6% completed - IBS Filtran GmbH
# 19: Scraping: 3.8% completed - Grünbeck Wasseraufbereitung GmbH
# 20: Scraping: 4.0% completed - Ic Energo
# 21: Scraping: 4.2% completed - ICFO
# 22: Scraping: 4.4% completed - GROUPEKARDOL
# 23: Scraping: 4.6% completed - HWB Gubesch Kunststoff engineering GmbH
# 24: Scraping: 4.8% completed - Gurit Uk
# 25: Scraping: 5.0% completed - GUIC INSTALLACIONS
# 26: Scraping: 5.2% completed - Guenther Spelsberg GmbH Co. KG
# 27: Scraping: 5.4% completed - Huawei Technologies Finland
# 28: Scraping: 5.6% completed - Podotec3D
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-027258183e68> in <module>
#      53
#      54         company_div = soup.find('div', {'class': 'org-grid__core-rail--no-margin-left'})
# ---> 55         comp = company_div.find_all('p')
#      56
#      57         # Chech if there is anything in the about page
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
# executar tot lo dabaix!

grid_header = ['Name', 'Web_Name', 'Website','Phone','Industry','Company size','Headquarters','Type','Founded','Specialties']
dataframe = []

for k in range(0,companies_count):
    j = 0
    i = 0
    lista = []

    while i< len(grid_header):
        try:
            if grid_header[i] == companies_list[0+k*2][j]:
                field = companies_list[1+k*2][j]
            else:
                field = None
                j -= 1
            lista.append(field)
            j +=1

        except:
            lista.append(None)
        i += 1    
    dataframe.append(lista)
    
df = pd.DataFrame.from_records(dataframe,columns=grid_header)
df['Phone'] = df['Phone'].str.split('\n').str[0]
df
# Out:
#                                                   Name                                           Web_Name Website Phone Industry Company size Headquarters  Type Founded Specialties
# 0                         Finnish Enviroment Institute                                               None    None  None     None         None         None  None    None        None
# 1                         Rabbit Disruptive Innovation                               Firm Solutions, Inc.    None  None     None         None         None  None    None        None
# 2                                               NOVAIR                                             Novair    None  None     None         None         None  None    None        None
# 3                                               ProCut                                          Procut AS    None  None     None         None         None  None    None        None
# 4                            Procurement Practice GmbH                                 Porsche Consulting    None  None     None         None         None  None    None        None
# 5         INVATEC SPA Medtronic Endovascular Therapies                                               None    None  None     None         None         None  None    None        None
# 6                         HTD-Italia di Ravasi Lorenzo                                               None    None  None     None         None         None  None    None        None
# 7                                     Peter Brehm GmbH                                   PETER BREHM GmbH    None  None     None         None         None  None    None        None
# 8                                          PeRoBa GmbH                   PeRoBa Unternehmensberatung GmbH    None  None     None         None         None  None    None        None
# 9                                           DOSIM S.L.  Medicinal Organic Cannabis Australia (MOCA) Fu...    None  None     None         None         None  None    None        None
# 10                                IAE SAVOIE MONT-BLAC                                               None    None  None     None         None         None  None    None        None
# 11                                     Iamanufacturing                                   IA Manufacturing    None  None     None         None         None  None    None        None
# 12                                       Grunwald GmbH                                      GRUNWALD GMBH    None  None     None         None         None  None    None        None
# 13                                               Iapmm                                              IAPMM    None  None     None         None         None  None    None        None
# 14                       IBAK Helmut Hunger GmbH Co.KG                   IBAK Helmut Hunger Gmbh & Co. KG    None  None     None         None         None  None    None        None
# 15                                      Performio GmbH                                     performio GmbH    None  None     None         None         None  None    None        None
# 16                                           PERADOTTO                                          PERADOTTO    None  None     None         None         None  None    None        None
# 17                                    IBS Filtran GmbH                                   IBS Filtran GmbH    None  None     None         None         None  None    None        None
# 18                    Grünbeck Wasseraufbereitung GmbH                   Grünbeck Wasseraufbereitung GmbH    None  None     None         None         None  None    None        None
# 19                                           Ic Energo                            OT Energy Services a.s.    None  None     None         None         None  None    None        None
# 20                                                ICFO                                               ICFO    None  None     None         None         None  None    None        None
# 21                                        GROUPEKARDOL                                               None    None  None     None         None         None  None    None        None
# 22             HWB Gubesch Kunststoff engineering GmbH                                               None    None  None     None         None         None  None    None        None
# 23                                            Gurit Uk                                 GURIT (UK) LIMITED    None  None     None         None         None  None    None        None
# 24                                  GUIC INSTALLACIONS                                               None    None  None     None         None         None  None    None        None
# 25                      Guenther Spelsberg GmbH Co. KG                                               None    None  None     None         None         None  None    None        None
# 26                         Huawei Technologies Finland                             Otaniemi Marketing Ltd    None  None     None         None         None  None    None        None
# 27                                           Podotec3D                                          PodoTec3D    None  None     None         None         None  None    None        None
# 28                                                  PG                                                 PG    None  None     None         None         None  None    None        None
# 29                              Hullo 3d Design Studio                                               None    None  None     None         None         None  None    None        None
# 30                                              petron                                 Petron Corporation    None  None     None         None         None  None    None        None
# 31                                           HUSKY IMS                            Husky Ims Colombia Ltd.    None  None     None         None         None  None    None        None
# 32                                     Gto Plating B.v                                               None    None  None     None         None         None  None    None        None
# 33                                    Husqvarna Uk Ltd                                  Telenor Connexion    None  None     None         None         None  None    None        None
# 34                        PEUGEOT DIVISION MOTOR SPORT                                               None    None  None     None         None         None  None    None        None
# 35                                          Gsw Uk Ltd                                       GSW (UK) LTD    None  None     None         None         None  None    None        None
# 36                          Hutchinson Engineering Ltd                         Hutchinson Engineering Ltd    None  None     None         None         None  None    None        None
# 37                                         ICREATIA.ES                                        icreatia.es    None  None     None         None         None  None    None        None
# 38                                           ICSN-CNRS                                               None    None  None     None         None         None  None    None        None
# 39                                      PATENTES TALGO                              PATENTES TALGO S.L.U.    None  None     None         None         None  None    None        None
# 40                                   Gregory Keyes Ltd                                GREGORY KEYES MD PS    None  None     None         None         None  None    None        None
# 41                                 GREEN21ARQUITECTURA                                               None    None  None     None         None         None  None    None        None
# 42                                        PolyPid Ltd.                                            PolyPid    None  None     None         None         None  None    None        None
# 43                                   PATENTES TALGO SL                                               None    None  None     None         None         None  None    None        None
# 44               GREEN ELETTROPOMPE DI BRUSCOLI ENRICO                                               None    None  None     None         None         None  None    None        None
# 45                                                 IFP                                                IFP    None  None     None         None         None  None    None        None
# 46                                       POLYTECH LYON                                      Polytech Lyon    None  None     None         None         None  None    None        None
# 47                                         Polytronics                                        Polytronics    None  None     None         None         None  None    None        None
# 48                               PartsGroupEurope GmbH                              PartsGroupEurope GmbH    None  None     None         None         None  None    None        None
# 49                                          GRAMMER AG                                         Grammer AG    None  None     None         None         None  None    None        None
# 50                       Gramm UG (haftungsbeschränkt)                                               None    None  None     None         None         None  None    None        None
# 51                              Ikea Communications Ab                                     Okaii Media AB    None  None     None         None         None  None    None        None
# 52                                             ifolor.                                       Ifolor Group    None  None     None         None         None  None    None        None
# 53                         GROUPECOHESIONINTERNATIONAL                                               None    None  None     None         None         None  None    None        None
# 54                                          GROUPE J3L                                               None    None  None     None         None         None  None    None        None
# 55                                        GROUPE ZEBRA                                       Groupe Zebra    None  None     None         None         None  None    None        None
# 56                                                 Ict                                                ICT    None  None     None         None         None  None    None        None
# 57                                         ICT MANAGER                                         ICT Career    None  None     None         None         None  None    None        None
# 58                                        GROUPE SURYS                                               None    None  None     None         None         None  None    None        None
# 59                                  GROUPE SEB ROWENTA                                   Groupe SEB India    None  None     None         None         None  None    None        None
# 60                                  Idea Prototipi srl                                 IDEA PROTOTIPI SRL    None  None     None         None         None  None    None        None
# 61                                 Groupe PSA (vélizy)                                               None    None  None     None         None         None  None    None        None
# 62                                        Ideascout Oy                                               None    None  None     None         None         None  None    None        None
# 63                                     GROUPE GONZALES                                    GROUPE GONZALES    None  None     None         None         None  None    None        None
# 64                                       GROUPE FIZFAB                                             FizFab    None  None     None         None         None  None    None        None
# 65                                      GROUPE BARBIER                                     GROUPE BARBIER    None  None     None         None         None  None    None        None
# 66                               Pca Engineers Limited                              PCA Engineers Limited    None  None     None         None         None  None    None        None
# 67                                           PC System                                          PC System    None  None     None         None         None  None    None        None
# 68                                            Idtechex                                           IDTechEx    None  None     None         None         None  None    None        None
# 69                                           Iemme sas                                               None    None  None     None         None         None  None    None        None
# 70                                               Paxer                                              Paxer    None  None     None         None         None  None    None        None
# 71                                IES VIRGEN DEL PILAR                                               None    None  None     None         None         None  None    None        None
# 72                                       H-team-mobile                                      H-Team Mobile    None  None     None         None         None  None    None        None
# 73                                              PNS NV                                               None    None  None     None         None         None  None    None        None
# 74                                PHENIX RETRO CONCEPT                               PHENIX RETRO CONCEPT    None  None     None         None         None  None    None        None
# 75                            Hirschvogel Holding GmbH                           Hirschvogel Holding GmbH    None  None     None         None         None  None    None        None
# 76                    Hassia Verpackungsmaschinen GmbH                   Hassia Verpackungsmaschinen GmbH    None  None     None         None         None  None    None        None
# 77                               Hjbugge Consulting As                                               None    None  None     None         None         None  None    None        None
# 78                 Pipex Px National Oilwell Varco Fgs                                               None    None  None     None         None         None  None    None        None
# 79                                          PLASTIGRAF                                         PLASTIGRAF    None  None     None         None         None  None    None        None
# 80                                                 HMP                                                hmp    None  None     None         None         None  None    None        None
# 81                                      PINTH BUBENZER                                               None    None  None     None         None         None  None    None        None
# 82            Harting Customised Solutions GmbH Co. KG                                               None    None  None     None         None         None  None    None        None
# 83           HARTING Customised Solutions Gmbh & Co.KG                                               None    None  None     None         None         None  None    None        None
# 84                               Hochschule Emden-Leer          University of Applied Sciences Emden/Leer    None  None     None         None         None  None    None        None
# 85   Hochschule fuer angewandte Wissenschaften Wrzb...                                               None    None  None     None         None         None  None    None        None
# 86                                Hochschule Karlsruhe  Hochschule Karlsruhe – Technik und Wirtschaft ...    None  None     None         None         None  None    None        None
# 87                               Hochschule Nordhausen  Hochschule Nordhausen University of Applied Sc...    None  None     None         None         None  None    None        None
# 88                                  PLASTIQUE PAILLARD                                               None    None  None     None         None         None  None    None        None
# 89           Hochschule Offenburgoffenburg. university                                               None    None  None     None         None         None  None    None        None
# 90                                        HOET EYEWEAR                                        Hoet design    None  None     None         None         None  None    None        None
# 91                                              Pitkit                                       Pitkit T.L.M    None  None     None         None         None  None    None        None
# 92                                         Pixel Cites                 Xoia Extending Reality - AR and VR    None  None     None         None         None  None    None        None
# 93                                               hf 3d                                     HF-Engineering    None  None     None         None         None  None    None        None
# 94                      heritage spareparts consulting                                               None    None  None     None         None         None  None    None        None
# 95                                          Hesse GmbH                                         Hesse GmbH    None  None     None         None         None  None    None        None
# 96                                            HERAFCAM                                           HERAFCAM    None  None     None         None         None  None    None        None
# 97                                          Hemocue AB                                         HemoCue AB    None  None     None         None         None  None    None        None
# 98                                          PLASTI GUN                             Dreamscape Engineering    None  None     None         None         None  None    None        None
# 99                                             Hemocue                                         HemoCue AB    None  None     None         None         None  None    None        None
# 100                                     HELLENPLAN LTD                                               None    None  None     None         None         None  None    None        None
# 101                                           Plastica                                           PLASTICA    None  None     None         None         None  None    None        None
# 102                                              Hevel                                              Hevel    None  None     None         None         None  None    None        None
# 103                                Héliographie Girard                                Heliographie Girard    None  None     None         None         None  None    None        None
# 104                           Hfele Berlin GmbH Co. KG                                               None    None  None     None         None         None  None    None        None
# 105   Heinrichs Co. KG - Schrauben-und Drehteilefabrik                            HEINRICHS GmbH & Co. KG    None  None     None         None         None  None    None        None
# 106                                              hhter                                               None    None  None     None         None         None  None    None        None
# 107                                               HEIA                                               HEIA    None  None     None         None         None  None    None        None
# 108                                        Highpatents                                               None    None  None     None         None         None  None    None        None
# 109                         Highvoltage Union-rzva Llc                                               None    None  None     None         None         None  None    None        None
# 110                Pieper Innovationsgesellschaft GmbH                                               None    None  None     None         None         None  None    None        None
# 111                                            Hoganas                                            HÖGANÄS    None  None     None         None         None  None    None        None
# 112                                 HOSOKAWA ALPINE AG                                   Civest CS s.r.o.    None  None     None         None         None  None    None        None
# 113                           Halewood Jaguar Cars Ltd                                               None    None  None     None         None         None  None    None        None
# 114                                       HALASCO GmbH                                               None    None  None     None         None         None  None    None        None
# 115                                     Plus medica OT                                     plus medica OT    None  None     None         None         None  None    None        None
# 116                                         Photek Ltd                                         Photek Ltd    None  None     None         None         None  None    None        None
# 117                                             HAFELE                                   Häfele Australia    None  None     None         None         None  None    None        None
# 118                                    Horiba Mira Ltd                                        HORIBA MIRA    None  None     None         None         None  None    None        None
# 119                                          Haenco UG                                               None    None  None     None         None         None  None    None        None
# 120                                           Pm Group                                           PM Group    None  None     None         None         None  None    None        None
# 121                     Phoenix Engineering Company Li                                          Intronics    None  None     None         None         None  None    None        None
# 122                                        Halliburton                                        Halliburton    None  None     None         None         None  None    None        None
# 123           PHOENIX CONTACTConnector Technology GmbH                                               None    None  None     None         None         None  None    None        None
# 124                                Phoenix Contact Spa                                     Accel Electric    None  None     None         None         None  None    None        None
# 125                                       Howden Group                               HOWDEN GROUP LIMITED    None  None     None         None         None  None    None        None
# 126                                           HPS GmbH                          HPS GmbH / Stellen-Helden    None  None     None         None         None  None    None        None
# 127                  Hôpitaux Universitaires de Genève            HUG - Hôpitaux Universitaires de Genève    None  None     None         None         None  None    None        None
# 128                                           Hardings                                           Hardings    None  None     None         None         None  None    None        None
# 129                                           Pictomed                                 Picto mediterranée    None  None     None         None         None  None    None        None
# 130                                           Holmatro                                           Holmatro    None  None     None         None         None  None    None        None
# 131                                         plastomold                                         Plastomold    None  None     None         None         None  None    None        None
# 132                                              HOMAG                                              HOMAG    None  None     None         None         None  None    None        None
# 133                                               HARA                                               Hara    None  None     None         None         None  None    None        None
# 134                               Hansa Armaturen GmbH                               Hansa Armaturen GmbH    None  None     None         None         None  None    None        None
# 135                          Hans Böckler Berufskolleg                          Hans-Böckler-Berufskolleg    None  None     None         None         None  None    None        None
# 136                                        PLATINIUM3D                                        PLATINIUM3D    None  None     None         None         None  None    None        None
# 137                           Phs Logistiktechnik Gmbh                           PHS Logistiktechnik GmbH    None  None     None         None         None  None    None        None
# 138                                         HOME STEEL                                         Home Steel    None  None     None         None         None  None    None        None
# 139                    Honda Motor Europe Logistics Nv                    Honda Motor Europe Logistics NV    None  None     None         None         None  None    None        None
# 140                                   HANDY BIONIC SAS                                               None    None  None     None         None         None  None    None        None
# 141                             platti natale c s.n.c.                                               None    None  None     None         None         None  None    None        None
# 142                          Handtmann Maschinenfabrik  Handtmann Maschinenfabrik GmbH & Co. KG Maschi...    None  None     None         None         None  None    None        None
# 143                       HanCon Hanselmann Consulting                                               None    None  None     None         None         None  None    None        None
# 144                       HONEYCOMB Y COMPOSITES S. L.                        Honeycomb y Composites S.L.    None  None     None         None         None  None    None        None
# 145                             Phu Seba Sp. J Gorlice                                               None    None  None     None         None         None  None    None        None
# 146                           Parsons Brinckerhoff Ltd                           PARSONS BRINCKERHOFF LTD    None  None     None         None         None  None    None        None
# 147                           Parmley Technologies Ltd                           Parmley Technologies Ltd    None  None     None         None         None  None    None        None
# 148                  Procter Gamble Manufacturing GmbH         Procter & Gamble Manufacturing Berlin GmbH    None  None     None         None         None  None    None        None
# 149                                          Gestra AG                                          Gestra AG    None  None     None         None         None  None    None        None
# 150                        Ingenieurbüro A. Dönnebrink                   Ingenieurbüro Andreas Dönnebrink    None  None     None         None         None  None    None        None
# 151                     Ingenieurbüro Huß Feickert GbR                                               None    None  None     None         None         None  None    None        None
# 152                        Ingenieursbureau JK de Heer                                               None    None  None     None         None         None  None    None        None
# 153                                       INLOGEM S.L.                                               None    None  None     None         None         None  None    None        None
# 154                                           Innalabs                                      InnaLabs® Ltd    None  None     None         None         None  None    None        None
# 155                       GESIPA Blindniettechnik GmbH                                               None    None  None     None         None         None  None    None        None
# 156           Gesellschaft fur innovative Beschaftigng                                               None    None  None     None         None         None  None    None        None
# 157                                        Gerner Paul                                               None    None  None     None         None         None  None    None        None
# 158         Gerhard Schubert GmbH Verpackungsmaschinen         Gerhard Schubert GmbH Verpackungsmaschinen    None  None     None         None         None  None    None        None
# 159                                INNOTEC MAGYAR KFT.                                               None    None  None     None         None         None  None    None        None
# 160                              Osborn Design Limited                              OSBORN DESIGN LIMITED    None  None     None         None         None  None    None        None
# 161                        Geometric Manufacturing Ltd                        Geometric Manufacturing Ltd    None  None     None         None         None  None    None        None
# 162                           Ingenieur Studio Hollaus                           Ingenieur Studio Hollaus    None  None     None         None         None  None    None        None
# 163                                        OSSUR GROUP                  DGS Business Services Sp. z o. o.    None  None     None         None         None  None    None        None
# 164                                            Infomir                                            Infomir    None  None     None         None         None  None    None        None
# 165                                   Pride Electrical                                   Pride Electrical    None  None     None         None         None  None    None        None
# 166                                        INFN-Genova                                      PM_TEN s.r.l.    None  None     None         None         None  None    None        None
# 167                                    Gima Trade GmbH                                    Gima Trade GmbH    None  None     None         None         None  None    None        None
# 168                                          ottobock.                                           Ottobock    None  None     None         None         None  None    None        None
# 169                          Gilbert Gilkes Gordon Ltd                      Gilbert Gilkes and Gordon Ltd    None  None     None         None         None  None    None        None
# 170                                           Info Sit                                            Infosit    None  None     None         None         None  None    None        None
# 171                          Gilbert Gilkes And Gordan                                               None    None  None     None         None         None  None    None        None
# 172                                      Otto Olsen As                                      Otto Olsen AS    None  None     None         None         None  None    None        None
# 173                                     Ingegnere l.p.                                        P. & C. SRL    None  None     None         None         None  None    None        None
# 174                                            GiB mbH                                            GIB mbH    None  None     None         None         None  None    None        None
# 175                     Primetals Technologies Limited                             Primetals Technologies    None  None     None         None         None  None    None        None
# 176                                               GGBA                                               GGBA    None  None     None         None         None  None    None        None
# 177                                              OTNET                 Otnet Serviços de Informações Ltda    None  None     None         None         None  None    None        None
# 178                                INFYNITY BIOMARKERS                                InfYnity Biomarkers    None  None     None         None         None  None    None        None
# 179                              ing. Giuseppe Starace                                               None    None  None     None         None         None  None    None        None
# 180                                      ORWO Net GmbH                                      ORWO Net GmbH    None  None     None         None         None  None    None        None
# 181                                 PROCIM Xperts GmbH                                               None    None  None     None         None         None  None    None        None
# 182                 Institut furVerbundwerkstoffe GmbH                                               None    None  None     None         None         None  None    None        None
# 183                    Institute Of Ell Biophysics Ras                                               None    None  None     None         None         None  None    None        None
# 184                 INSTITUTO OFTALMOLOGIA EXTREMADURA        INSTITUTO DE OFTALMOLOGIA DE EXTREMADURA SL    None  None     None         None         None  None    None        None
# 185                                            Probisa                                            Probisa    None  None     None         None         None  None    None        None
# 186                                    INTERCOS S.p.A.                                    INTERCOS S.P.A.    None  None     None         None         None  None    None        None
# 187                       Interfleet Techology Limited                                               None    None  None     None         None         None  None    None        None
# 188                       InterMedia Sistem Integrator                                               None    None  None     None         None         None  None    None        None
# 189                  INTERNATIONAL HELLENIC UNIVERSITY                  International Hellenic University    None  None     None         None         None  None    None        None
# 190                                      Interservsouz                                               None    None  None     None         None         None  None    None        None
# 191                                     PRO.DISTIC.ltd                                               None    None  None     None         None         None  None    None        None
# 192                                           Intertek                                           Intertek    None  None     None         None         None  None    None        None
# 193                                         Ge Oil Gas                                                 GE    None  None     None         None         None  None    None        None
# 194                                            INTEVIA  Asociación Técnica de Emulsiones Bituminosas A...    None  None     None         None         None  None    None        None
# 195                                      INTROLIZ LTD.                                               None    None  None     None         None         None  None    None        None
# 196                  Procter Gamble Manufactoring GmbH                                               None    None  None     None         None         None  None    None        None
# 197                                         pro1o1ypen                                               None    None  None     None         None         None  None    None        None
# 198                           Institut für Flugzeugbau                                               None    None  None     None         None         None  None    None        None
# 199                    Innovative Industrial Solutions              Innovative Industrial Solutions (IIS)    None  None     None         None         None  None    None        None
# 200                                         Inotech As                                            Inotech    None  None     None         None         None  None    None        None
# 201  GENTILI TECHNOLOGY EQUIPMENT DI GENTILI ALDO E...                                               None    None  None     None         None         None  None    None        None
# 202                                      INNOVOILE SAS                                               None    None  None     None         None         None  None    None        None
# 203                                    private adviser                       Private Alpha Switzerland AG    None  None     None         None         None  None    None        None
# 204                                    Private Busness                 Business Engineering (PTY) Limited    None  None     None         None         None  None    None        None
# 205                                         INNOWER 3D                                            INNOWER    None  None     None         None         None  None    None        None
# 206                                      Generation 3d               Generation 3D - 3D Printing Services    None  None     None         None         None  None    None        None
# 207                       Ortopedic Solution Jacob-OJS                                               None    None  None     None         None         None  None    None        None
# 208  Institut fuer Produktentwicklung und Konstrukt...                                               None    None  None     None         None         None  None    None        None
# 209                                        INOX DESIGN                                         INOXDESIGN    None  None     None         None         None  None    None        None
# 210                                 INOX DESIGN s.r.l.                                    Inox-fer s.r.l.    None  None     None         None         None  None    None        None
# 211                                                gen                                                Gen    None  None     None         None         None  None    None        None
# 212                              INPLATEC PLASTICOS SL                                               None    None  None     None         None         None  None    None        None
# 213                               Inspire Design S.r.o                              INSPIRE DESIGN s.r.o.    None  None     None         None         None  None    None        None
# 214                  INSTITUT ARTS ET METIERS CHAMBERY                                               None    None  None     None         None         None  None    None        None
# 215                                        Gimon, S.L.                                               None    None  None     None         None         None  None    None        None
# 216                         PARKER HANNIFIN France SAS                 Parker Hannifin France Finance SAS    None  None     None         None         None  None    None        None
# 217                                            Imi Plc                                            IMI PLC    None  None     None         None         None  None    None        None
# 218                   Pöttinger Maschinenfabrik Gesmbh                                               None    None  None     None         None         None  None    None        None
# 219                                       GOIALDE S.L.                                               None    None  None     None         None         None  None    None        None
# 220                            Immensa Technology Labs                            Immensa Technology Labs    None  None     None         None         None  None    None        None
# 221                                            Panduit                                            Panduit    None  None     None         None         None  None    None        None
# 222                                   Panasonic Europe                                   Panasonic Europe    None  None     None         None         None  None    None        None
# 223                              Panaitescu Victor Pfa                                               None    None  None     None         None         None  None    None        None
# 224                                          Pamec srl                                       PAMEC S.R.L.    None  None     None         None         None  None    None        None
# 225  Powder Injection Molding Saran Tch Safran Addi...                                               None    None  None     None         None         None  None    None        None
# 226                                     GOEDHART REPRO                                     Goedhart Repro    None  None     None         None         None  None    None        None
# 227                                        implantcast                                   implantcast GmbH    None  None     None         None         None  None    None        None
# 228                         Implement Consulting Group                         Implement Consulting Group    None  None     None         None         None  None    None        None
# 229                                            Go3d Oy                                               None    None  None     None         None         None  None    None        None
# 230                                    Pall Europe Ltd                                      Pall-Ex Group    None  None     None         None         None  None    None        None
# 231                              PALFINGER EUROPE GMBH  PALFINGER SANY – Simplicity – Our Gain Creator...    None  None     None         None         None  None    None        None
# 232                           GMH Schmiedetechnik GmbH                                               None    None  None     None         None         None  None    None        None
# 233                             Pannonia Precision Eng                                               None    None  None     None         None         None  None    None        None
# 234                                           Gold-cam                                           SolidCAM    None  None     None         None         None  None    None        None
# 235                                        GOLDONI SPA                                             Aleide    None  None     None         None         None  None    None        None
# 236                                             Pordir                                               None    None  None     None         None         None  None    None        None
# 237     POROCESOS INDSUTRIALES PAPEL Y FILTRACION S.L.                                               None    None  None     None         None         None  None    None        None
# 238                              Grace Jens Knudsen As                                               None    None  None     None         None         None  None    None        None
# 239                        GPS Reisacher GmbH & Co. KG                                 GPS Reisacher GmbH    None  None     None         None         None  None    None        None
# 240                                          PARI GmbH                                          PARI GmbH    None  None     None         None         None  None    None        None
# 241                                        Paravia SRL                                     PARAVIA S.R.L.    None  None     None         None         None  None    None        None
# 242                           GORDAN MURRAY DESIGN LTD                                               None    None  None     None         None         None  None    None        None
# 243                                                Pos                                         POS Portal    None  None     None         None         None  None    None        None
# 244                                          Goprint3d                                          GoPrint3D    None  None     None         None         None  None    None        None
# 245                                            pap co.                                              Papco    None  None     None         None         None  None    None        None
# 246                                           IMERSION                                           IMERSION    None  None     None         None         None  None    None        None
# 247                                        pantur s.l.                                               None    None  None     None         None         None  None    None        None
# 248                                   GMC-I PROSYS Ltd                                       GMC-I PROSyS    None  None     None         None         None  None    None        None
# 249                                              Gmail                                              gmail    None  None     None         None         None  None    None        None
# 250                                             pq SpA                                     PQ Nails & Spa    None  None     None         None         None  None    None        None
# 251                                      girardini srl                                      Girardini Srl    None  None     None         None         None  None    None        None
# 252                                        INDÉPENDANT                                        Independant    None  None     None         None         None  None    None        None
# 253  GKVTecPart Verband Technische Kunststoff-Produ...                                               None    None  None     None         None         None  None    None        None
# 254                            INDUPLAVER TRADING S.L.                                               None    None  None     None         None         None  None    None        None
# 255                                           Premo Ab                                       AR MOTORS AB    None  None     None         None         None  None    None        None
# 256                                      OZ CAR DESIGN                                         Oz by cath    None  None     None         None         None  None    None        None
# 257                             INDUSTRIAS ALEGRE S.A.                                         Irani S.A.    None  None     None         None         None  None    None        None
# 258                                     INDUSTRIAS DEU                                Industrias Deu S.A.    None  None     None         None         None  None    None        None
# 259                                 PA-6UP AKMATS GMBH                                               None    None  None     None         None         None  None    None        None
# 260                                         giorgi srl                                         GIORGI SRL    None  None     None         None         None  None    None        None
# 261                                              OXHEX                                               None    None  None     None         None         None  None    None        None
# 262                  INDUSTRIAS MECÁNICAS PERALTA S.L.                                               None    None  None     None         None         None  None    None        None
# 263                          INDUSTRIAS METALICAS RUIZ                  INMER - Industrias Metálicas Ruiz    None  None     None         None         None  None    None        None
# ...
# 412                                           MACARBOX                                           Macarbox    None  None     None         None         None  None    None        None
# 413                                 erciyes university                               Erciyes Üniversitesi    None  None     None         None         None  None    None        None
# 414                                       Robonica Srl                                       Robonica Srl    None  None     None         None         None  None    None        None
# 415                EQUIPOS DE RECICLADO BIOLÓGICO S.L.                                               None    None  None     None         None         None  None    None        None
# 416                                                 MT                                              MT.be    None  None     None         None         None  None    None        None
# 417                                    Monte Bianco Sa                    Monte Bianco Participações S.A.    None  None     None         None         None  None    None        None
# 418                                          ROVIPHARM                                          ROVIPHARM    None  None     None         None         None  None    None        None
# 419                                        Rowantelmac                                               None    None  None     None         None         None  None    None        None
# 420                            midrand glass aluminium                                               None    None  None     None         None         None  None    None        None
# 421                                 Midlothian Council                                 Midlothian Council    None  None     None         None         None  None    None        None
# 422                                       Mercedes AMG                                  Mercedes-AMG GmbH    None  None     None         None         None  None    None        None
# 423                                          SAFAC SRL                                          Safac Srl    None  None     None         None         None  None    None        None
# 424                                      Mercedes Benz  Mercedes-Benz Hijos de Manuel Crespo Concesion...    None  None     None         None         None  None    None        None
# 425                                       Microtel spa               MICROTEL TECNOLOGIE ELETTRONICHE SPA    None  None     None         None         None  None    None        None
# 426                                              SAFIR                                              SAFIR    None  None     None         None         None  None    None        None
# 427                                             Memcom                                             memcom    None  None     None         None         None  None    None        None
# 428                                         Dumlupinar                                         DUMLUPINAR    None  None     None         None         None  None    None        None
# 429                                  Microcosm Pty Ltd                                               None    None  None     None         None         None  None    None        None
# 430                                     Micro Matic AS                                        Micro Matic    None  None     None         None         None  None    None        None
# 431                                 MESRUR MUHENDISLIK                                               None    None  None     None         None         None  None    None        None
# 432                                   DUCOS CONSULTANT                                               None    None  None     None         None         None  None    None        None
# 433                                              Ducab                        Dubai Cable Company - Ducab    None  None     None         None         None  None    None        None
# 434                        E. U. POLTECNICA LA ALMUNIA                                               None    None  None     None         None         None  None    None        None
# 435                  MEMBRE DU RESEAU INFINITY CAPITAL                                    Kaza Patrimoine    None  None     None         None         None  None    None        None
# 436                                       Millennium 7                                       Millennium 7    None  None     None         None         None  None    None        None
# 437                                          ECAM LYON                                          ECAM Lyon    None  None     None         None         None  None    None        None
# 438                                               ECAF                           ECAF Soluções Integradas    None  None     None         None         None  None    None        None
# 439                                        Ebs Ink Jet                                    EBS Ink-Jet USA    None  None     None         None         None  None    None        None
# 440                           MINERALES DEL BREZO S.L.                                               None    None  None     None         None         None  None    None        None
# 441                        Mineral Processing Services                     MINERAL PROCESSING SERVICES LL    None  None     None         None         None  None    None        None
# 442                              mikrosens electronics                                          MikroSens    None  None     None         None         None  None    None        None
# 443                                        MELTON S.L.                               Melton & Melton, LLP    None  None     None         None         None  None    None        None
# 444                            Meggitt Thermal Systems                                            Meggitt    None  None     None         None         None  None    None        None
# 445                                           EASINNOV                                           EASINNOV    None  None     None         None         None  None    None        None
# 446                                   SACMI IMOLA S.C.                                              SACMI    None  None     None         None         None  None    None        None
# 447                           MELAG MEdizintechnik oHG                                               None    None  None     None         None         None  None    None        None
# 448                                          MeliesArt                                               None    None  None     None         None         None  None    None        None
# 449                                               MIHB                                               MIHB    None  None     None         None         None  None    None        None
# 450                                             SACOPA                                     Sacopã Capital    None  None     None         None         None  None    None        None
# 451                                   Messe Dusseldorf                              Messe Düsseldorf GmbH    None  None     None         None         None  None    None        None
# 452                              Montblanc-Simplo GmbH                              Montblanc-Simplo GmbH    None  None     None         None         None  None    None        None
# 453                                         Dr B Lynch                 Warmond Fiduciary Services Limited    None  None     None         None         None  None    None        None
# 454                                               DQBD                                          DQBD GmbH    None  None     None         None         None  None    None        None
# 455                                           Metro AG                                           METRO AG    None  None     None         None         None  None    None        None
# 456                                  DPS Software GmbH                                  DPS Software GmbH    None  None     None         None         None  None    None        None
# 457                                            Dpm Srl                                      D.P.M. S.R.L.    None  None     None         None         None  None    None        None
# 458                                            MG-TECH                                            MG Tech    None  None     None         None         None  None    None        None
# 459                                  MÉTROPOLE DE LYON                                  Métropole de Lyon    None  None     None         None         None  None    None        None
# 460                                                MEU               Meu Rebuliço - Decoration for living    None  None     None         None         None  None    None        None
# 461                                      Saith Limited                                      Saith Limited    None  None     None         None         None  None    None        None
# 462                         Mexence Digital & Robotics                         MEXENCE DIGITAL & ROBOTICS    None  None     None         None         None  None    None        None
# 463                      Dounreay Site Restoration Ltd                             RadEcol Consulting Ltd    None  None     None         None         None  None    None        None
# 464                                        MEYER WERFT                          MEYER WERFT GmbH & Co. KG    None  None     None         None         None  None    None        None
# 465                                               MG63                                               MG63    None  None     None         None         None  None    None        None
# 466                                            MG TECH                                            MG Tech    None  None     None         None         None  None    None        None
# 467                                       Dositecno 95                                    DOSITECNO 95 SL    None  None     None         None         None  None    None        None
# 468                                          Salvision                                               None    None  None     None         None         None  None    None        None
# 469                                            DOSIPER                SISTEMAS DE DOSIFICACION DOSIPER SL    None  None     None         None         None  None    None        None
# 470                           MH MATERIAL HANDLING SRL                                               None    None  None     None         None         None  None    None        None
# 471                                           Safripol                                           SAFRIPOL    None  None     None         None         None  None    None        None
# 472                                 SAINTBRIEUCFACTORY                                               None    None  None     None         None         None  None    None        None
# 473                                              MeSys                                           MESYS AG    None  None     None         None         None  None    None        None
# 474                                        MET Company                                    MET Company Srl    None  None     None         None         None  None    None        None
# 475                                           METADESK                                           Metadesk    None  None     None         None         None  None    None        None
# 476                                   Metal Processing                         Metal Processing Co., Inc.    None  None     None         None         None  None    None        None
# 477                                          DResearch               DResearch Digital Media Systems GmbH    None  None     None         None         None  None    None        None
# 478         Dr. Ing. h.c. F. Porsche Aktiengesellschat                                               None    None  None     None         None         None  None    None        None
# 479                                 dresden-elektronik           dresden elektronik ingenieurtechnik gmbh    None  None     None         None         None  None    None        None
# 480          Saint-Gobain Performance Plastics LS GmbH                                               None    None  None     None         None         None  None    None        None
# 481                                SAINTJEANINDUSTRIES                                               None    None  None     None         None         None  None    None        None
# 482                                     Metaltecna srl                                               None    None  None     None         None         None  None    None        None
# 483                                          metec snc                                               None    None  None     None         None         None  None    None        None
# 484                                    Saipem Norge As                                               None    None  None     None         None         None  None    None        None
# 485               Meth Engineering & Consulting S.R.L.                     Iridium Construction (Pty) Ltd    None  None     None         None         None  None    None        None
# 486                         Dr. Ing. H.c.F. Porsche AG                                 Porsche Schweiz AG    None  None     None         None         None  None    None        None
# 487                            ECAM, ÉCOLE D'INGÉNIEUR                                          ECAM Lyon    None  None     None         None         None  None    None        None
# 488                                            MECTROL                            Mectrol HIWIN do Brasil    None  None     None         None         None  None    None        None
# 489                  Minghua Logistics Technology GmbH                                               None    None  None     None         None         None  None    None        None
# 490                                          EL Global                                           Elglobal    None  None     None         None         None  None    None        None
# 491                   Electricon Systems International                                               None    None  None     None         None         None  None    None        None
# 492                          Eldevik Industridesign As                          Eldevik Industridesign AS    None  None     None         None         None  None    None        None
# 493                                              ELCOM                                              Elcom    None  None     None         None         None  None    None        None
# 494                                          Materflow                                          Materflow    None  None     None         None         None  None    None        None
# 495                               Materials Matter Ltd                               Materials Matter Ltd    None  None     None         None         None  None    None        None
# 496                                        MATERIANOVA                                       Materia Nova    None  None     None         None         None  None    None        None
# 497                                               Ekza                                               None    None  None     None         None         None  None    None        None
# 498                              RS Components Limited                  RS Components Limited (Sri Lanka)    None  None     None         None         None  None    None        None
# 499                  Rudi Schindhelm Metall GmbH Co KG                  Rudi Schindhelm Metall GmbH&Co KG    None  None     None         None         None  None    None        None

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#############################################
focus_on = 'Industry'
#############################################

sns.set(style="darkgrid")
plt.figure(figsize=(15,20))
sns.set(font_scale = 1.5)
ax = sns.countplot(y=focus_on, data=df, color="b", order = df[focus_on].value_counts().index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-c98f0ff55359> in <module>
#       9 plt.figure(figsize=(15,20))
#      10 sns.set(font_scale = 1.5)
# ---> 11 ax = sns.countplot(y=focus_on, data=df, color="b", order = df[focus_on].value_counts().index)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1606         self.establish_variables(x, y, hue, data, orient,
#    1607                                  order, hue_order, units)
# -> 1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#    1610
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in establish_colors(self, color, palette, saturation)
#     313         # Determine the gray color to use for the lines framing the plot
#     314         light_vals = [colorsys.rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 315         lum = min(light_vals) * .6
#     316         gray = mpl.colors.rgb2hex((lum, lum, lum))
#     317
#
# ValueError: min() arg is an empty sequence

# %%
# EXECUTAR QUAN ACABI O ERROR
df.to_excel("Scrapping (12710-13210)MIQUEL.xlsx")

# %%
prev_file = pd.read_excel("Excel Scraping.xlsx")


out_grid_header = ['Name', 'Web_Name', 'Website','Phone','Industry','Company size','Headquarters','Type','Founded','Specialties']

mix_file = prev_file.append(df)
mix_file = mix_file.drop(columns=['Unnamed: 0'])
mix_file = mix_file[out_grid_header]

# mix_file.to_excel("Excel Scraping.xlsx")
