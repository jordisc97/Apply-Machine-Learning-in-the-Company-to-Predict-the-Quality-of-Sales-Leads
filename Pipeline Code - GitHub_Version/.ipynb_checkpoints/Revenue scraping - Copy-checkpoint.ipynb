# %%
import os, random, sys, time
# from urllib.parse import urlparse
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.common.exceptions import NoSuchElementException

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
### LOGIN
##############################################################
browser = webdriver.Chrome('driver/chromedriver.exe')
browser.get('https://www.glassdoor.es/profile/login_input.htm?userOriginHook=HEADER_SIGNIN_LINK')

# %%
file = open('config_glassdoor.txt')
lines = file.readlines()
username = lines[0]
password = lines[1]

time.sleep(round(random.uniform(1, 2),2))

##############################################################
elementID = browser.find_element_by_id('userEmail')
elementID.send_keys(username)
time.sleep(round(random.uniform(1, 1.3),2))

elementID = browser.find_element_by_id('userPassword')
elementID.send_keys(password)
time.sleep(round(random.uniform(1, 2),2))

elementID.submit()

# %%
# READ
##############################################################
leads_df = pd.read_csv('data/data2.csv')
leads_df = leads_df.sort_values(by=['FYQ Created On Correct'], ascending=True)
leads_df = leads_df[leads_df['Lead Status']!='Qualified']

company_list = leads_df['Company']
company_list = company_list.dropna() 
company_list = company_list.drop_duplicates()
company_list = company_list.tolist()

##############################################################
companies = company_list[11393:] ###READY
##############################################################
companies
# Out:
# ['Daimler corp',
#  'Curt nicolin gymnasiet',
#  'Kongsberg maritime',
#  'Ad adenta',
#  'Prisca',
#  'Gemini erp system design',
#  'Tangram solutions sl',
#  'Essentra packaging ltd',
#  'Dana italia spa',
#  'Daco solutions ltd (future)',
#  'Kirubotics surgical solutions',
#  'Kirpart',
#  'Dacey orthopaedics ltd',
#  'Bel engineering',
#  'Polytec car styling uk ltd',
#  'TE Connectivity Germany GmbH',
#  'KION Group',
#  'Tangram solutions s.l.',
#  'Dacey limited',
#  'Dana motion system italia',
#  'Belgrade insulations ltd',
#  'Gdd solutions',
#  'Bautermic',
#  'Geka GmbH',
#  'Koninklijke douwe egberts b.v',
#  'Tcn',
#  'Geko electronics ltd',
#  'Postnord strålfors',
#  'Prima industries srl',
#  'Konstruktionen alt',
#  'Bee Robotics',
#  'Primes gmbh',
#  'Power dynamic technology',
#  'Konstruktörbüro huwer',
#  'Kookaburra Bv',
#  'Bayer ag',
#  'Bayer',
#  'Bay plastics',
#  'Kopas',
#  'Tdm',
#  'Koppendorfer roboter-service & feinwerktechnik',
#  'Bego gmbh & co. kg',
#  'Baxter international inc.',
#  'Acodeq kunststoffen',
#  'Biemmegi spa',
#  'Tech data',
#  'Dannenman gmbh',
#  'Lag spa',
#  'Cs.ccoo',
#  'Geometryfactory',
#  'Lahnwerk gmbh',
#  'Geopas s.a.c.',
#  "Laing o'rourke",
#  'Kellpla group',
#  'DATA PLASTICS LTD',
#  'Produmax',
#  'Plastic manu. and reclying',
#  'Data4image th. loth',
#  'Proengin',
#  'Technoconsult firenze',
#  'Lambson',
#  'Datacomp sp. z o.o.',
#  'Plastcom s.r.o.',
#  'Lamia',
#  'Bhf aktiengesellschaft',
#  'Georg fischer automobilguss gmbh',
#  'Bhge',
#  'Das-nano',
#  'Product 4 ltd',
#  'Techno sky',
#  'Gabinete de ortopedia alcalá',
#  'Gabel industria tessile',
#  'Gã¼ntner',
#  'Ga.ma srl',
#  'Ga operation s.p.a.',
#  'Labrox oy',
#  'Labs planet',
#  'DARIO DESIGN SARL',
#  'Technische universität ilmenau production technology group',
#  'Plasticos Tatay',
#  'Barronkress',
#  'Technisches büro gmbh',
#  'Beurer gmbh',
#  'Lacroix emballages',
#  'Baron & verhoef materieel b.v.',
#  'Prodiel',
#  'Kenwood ltd',
#  'Plasticon uk ltd',
#  'Geolid',
#  'Das kunststoff-zentrum skz',
#  'kein Unternehmen',
#  'Pizeta srl di peron e zerbato',
#  'Pixers',
#  'Profile consulting group',
#  'PROFILS-SYSTEMES',
#  'LAPP Group',
#  'Abs precision limited',
#  'Bank of england',
#  'Future products ltd',
#  'Dauphelec',
#  'Talarmade ltd',
#  'larderArch Srls',
#  'pironex GmbH',
#  'Talar made limited',
#  'Furness college',
#  'Crit',
#  'Gerard perrier industrie',
#  'Talentoo',
#  'Fzi forschungszentrum informatik',
#  'Technology product&application technology uponor gmbh',
#  'Academy of fine arts in krakow',
#  'Crp',
#  'Georg fishcher',
#  'Georg schlegel gmbh & co.kg',
#  'Academia piramides',
#  'Lanbide',
#  'Crown Equipment Corporation',
#  'Datagenius',
#  'Ac2',
#  'Lander automotive',
#  'Plan.tec. gruppe',
#  'Technology and production center switzerland ag',
#  'Geosec srl',
#  'Geotecnical consulting',
#  'Placer y deseo',
#  'Crompton technology group ltd',
#  'Kea & partners',
#  'Technische universität graz institut für fertigungstechnik',
#  'Kyocera',
#  'Techdata',
#  'Techedge',
#  'L gemeinschaft',
#  'L&g ingeniería sostenible s.l.',
#  'Proair gerätebau gmbh',
#  'Proaltec',
#  'L&s italia s.r.l di brugnera',
#  'Acekare',
#  'L.l. gioielli di luigi loddo',
#  'Pmg füssen gmbh',
#  'Cubidesign gehäuse gmbh individuelle kunststottgehäuse',
#  'Technical services',
#  'Keuco gmbh & co. kg',
#  'Pm project services ltd',
#  'Technical unfyersityof liberec',
#  'Cubic inch',
#  'Dansk am hub',
#  'Basell deutschland gmbh',
#  'Base 3d printing solutions gmbh',
#  'La factoria 3d',
#  'Technical university of denmark',
#  'Ess engineering, services & solutions gmbh',
#  'Tech-a ltd',
#  'tech@housing',
#  'Polamco limited',
#  'Kunststoff-zentrum in leipzig ggmbh',
#  'Et global exhibit group',
#  'POK SAS',
#  'Eta',
#  'Berrilan ingenieria bim',
#  'Kurz',
#  'GAO operations',
#  'Tech soft 3d',
#  'Berufliches schulzentrum otto lilienthal',
#  'Berthold sichert gmbh',
#  'Keytec international b.v.',
#  'Podoquiles',
#  'Podfo',
#  'Kvt-fastening',
#  'Pobjeda technology gora?de d.d.',
#  'Kw special projects',
#  'Pny',
#  'Pneumo, frankfurt',
#  'Ess engineering, services &solutions gmbh',
#  'Polamco limited second contact',
#  'Gallina mario',
#  'Kesseböhmer Beschlagsysteme GmbH & Co. KG',
#  'Bestmedic',
#  'Beta Robots',
#  "Laboratoires m&l groupe l'occitane",
#  'Betech',
#  'Betech kunststoffen bv',
#  'Beth-ei industries ndreas koege beth-ei zikhron yaaqov industries ltd.',
#  'Talleres de escoriaza, s.a.u.',
#  'Technische Hochschule Mittelhessen',
#  'Technische universität berlin institut für mathematik sd-labor sekr.',
#  'Gaeva promotores',
#  'Between Technology',
#  'Laboratorios almirall s.l.',
#  'Etaja3d',
#  'Prodelox',
#  'Technische Universität Chemnitz',
#  'Laboratorios normon',
#  'Labor für allgemeine datenverarbeitung 3d-druck und -scan technische hochschule köln campus gummersbach technology',
#  'Techniplas',
#  'Best future',
#  'Esne',
#  'Accumotive gmbh & co kg',
#  'Berufsbildendeschulen rinteln',
#  'Gallardo&murillo',
#  'Berufsbildungswerk neckargemünd gmbh',
#  'Acciona infraestructuras',
#  'Kessböhmer Gmbh',
#  'Ctdi gmbh',
#  'Galiciadreams',
#  'Berufsförderungswerk schömberg',
#  'Procter & gamble manufacturing gmbh',
#  'Besaplast kunststoffe gmbh',
#  'Procoplast',
#  'La vie claire',
#  'Accesorios Correo Neumático SL',
#  'Player one',
#  'Procter and gamble',
#  'Bespak',
#  'Labara s.r.o.',
#  'Bespak europe limited',
#  'Lab-lob',
#  'Eso sud est',
#  'Ct3 ingeniería',
#  'Limacorporate s.p.a.',
#  'Skanska',
#  'Patia diabetes',
#  '3d printfabriek',
#  '3d prod platex',
#  'Neher systeme',
#  'To BE Anounced Later',
#  'Ffl s.r.l.',
#  'Neinver',
#  'Negativedesign',
#  'Camvac ltd',
#  'Cifp someso',
#  'Nemak',
#  'Nemak Linz GmbH',
#  'Nel technologies limited',
#  'Faerch plast uk ltd',
#  'Cice, s.a.',
#  '3D Manz',
#  'NDT Global',
#  'Mecmesin ltd',
#  '3d medical print kg',
#  'Mechatronik system gmbh',
#  'Candy italy',
#  'Nedschroef',
#  'Cieciefrezdwanie.pl produkcja/biuro',
#  'Festo italy',
#  '3D Phoenix',
#  'Neaforma',
#  'Cice, la escuela profesional de nuevas tecnologías',
#  'CIM GmbH Logistik-Systeme',
#  'Facultés universitaires notre-dame de la paix',
#  'Cis galicia - axencia galega de innovación - xunta de galicia',
#  'Mdh sp.z o.o',
#  'CIRP',
#  'Netzsch gerätebau gmbh',
#  'Ciser system slu',
#  'Neurtek',
#  'Cisme',
#  'Calsonic kansei',
#  'Factoría 5 hub',
#  'Mdesign intl',
#  'Neon lab',
#  'Mds regensburg',
#  'Fibrax ltd',
#  'Fh dortmund',
#  'Fh kiel',
#  'Cameron-price ltd',
#  'Fh würzburg- schweinfurt',
#  'Fhecor',
#  'Fibreco',
#  'Cips',
#  'Meanwhile',
#  'Cámara de comercio',
#  'Fibernet',
#  'Factoria5hub',
#  'Factoría 5 training hub',
#  'Factorhia sl',
#  'Fertig Motors GmbH',
#  'Nbso',
#  'Medlab media group',
#  'Carboplast  s.a.s.',
#  'Fagorederlangroup',
#  'Christoph deiss',
#  'Carbofibretec gmbh',
#  'Mediktiv',
#  'Carase 2787 s.l.',
#  'Chopsticks studio',
#  'Cardis sp. z o.o.',
#  '34914562937',
#  'Naber plastics b.v',
#  'Meine anhängsel gmbh',
#  'Carestream health',
#  'Medysalud',
#  'Nachoviedo',
#  'Megator',
#  'Megasaber',
#  'Nakama steam college',
#  'Namthaja',
#  'Meggitt sensing systems',
#  'Cice',
#  'Medicon eg',
#  'Mediapro',
#  'CIBO GmbH',
#  'Navantia.sa',
#  'Medartis',
#  'Canterbury college',
#  'Medanco bv',
#  'Canterbury chemicals international llc',
#  '3d druck stahl',
#  'Medica panamericana',
#  "Caran d'ache",
#  'Natec-medical ltd',
#  'Medicea medica',
#  'National oilwell varco',
#  '3d cadtor',
#  'Captae digitalizado 3d, s.l.',
#  'Capitel',
#  'Capgemini',
#  'Medica praha s.r.o.',
#  'Meister strömungstechnik gmbh',
#  'Nevicolor',
#  'Citd engineering & technologies',
#  'Nke cad systems',
#  'Nke cad systems, s.l.',
#  'First solution technologies limited',
#  'Cll consulting',
#  'Tknika',
#  '3d startup campus nrw',
#  'Masterdor ltd',
#  'Titon hardware ltd',
#  '3d startupcampus. nrw',
#  'Clwyd compounders ltd',
#  'Cad&lan s. a.',
#  '3d shopnl',
#  'Clevedon fasteners',
#  'Fip',
#  'Cadac',
#  'Tmg',
#  'Nke cad systemes',
#  'Matricel GmbH',
#  'Fire angel / sprue safety products',
#  'Clickthegear',
#  'Nissan motor ibérica, s.a.',
#  'Climarqtec',
#  'Materials Research Institute Aalen',
#  'Fischbach uk ltd',
#  'Titk e.v.',
#  'Cab automotive',
#  'Nokia tecss',
#  'Mas consulting',
#  'Ca digital',
#  'Fives landis limited',
#  'C95 creative',
#  'Marty sports',
#  'Martor kg',
#  'Nölle nodeko betriebs-gmbh',
#  'Martini & rossi s.p.a',
#  'Tine',
#  'Martor martor kg',
#  'Cm advanded printing iberia, s.a',
#  'Noelle + von campe',
#  'Cm tools',
#  'Titgemeyer uk ltd',
#  'Titanium generation gmbh',
#  'Massmould ltd',
#  'Fischer elektromotoren gmbh',
#  'Fischer elektronik',
#  'Cmp marketing limited',
#  'No climb products limited',
#  'Fischer italia',
#  'Fishercast (uk) ltd',
#  'Noba consultores',
#  'Cad global consultors',
#  'Cad & bim services',
#  'Cabot switzerland gmbh',
#  'No nome yet',
#  'Fichet',
#  'Matthias kolb und volker scheibe gbr',
#  'Fachhochschule augsburg',
#  'Cair lgl',
#  'Mca engineering / eos',
#  'Mc orthopädietechnik gmbh',
#  'Cixa',
#  'Cixa design',
#  'Nexans france',
#  'Ck charles kieffer group',
#  'Mbs sulzbach',
#  'Ngi',
#  'Filon products ltd',
#  "Nicholson's aircraft seals limited",
#  'NG Plastics',
#  'News innovation',
#  'Newgate clocks',
#  'Citd, engineering & technologies',
#  'Fachhochschule würzburg-schweinfurt',
#  'New model in technology & engineering',
#  'Fieldmade as',
#  'Callfersa',
#  'Fachhochschule nordwestschweiz',
#  'Calleadesign snc',
#  'Newarc limited',
#  'Mclaren applied technologies',
#  'Mcl control usa',
#  'Finsa',
#  'Nicomatic',
#  'Nidec control techniques dynamics',
#  'Max planck institute for brain research',
#  'F-iniciativas',
#  'Clean tech uk ltd',
#  'Clece',
#  'Nimrana ltd',
#  'Fink chem+tec, bad dürrheim',
#  'Nioco, s.l.',
#  'Fabs robotics slu',
#  'Maurer & wirtz house of perfumes',
#  'Fabrinet uk limited',
#  'Cadems s.l',
#  'Mb tecnology',
#  'Clausell studio',
#  'Nilfisk spa',
#  'Filtrec spa',
#  'Face',
#  'Mb group fischer vertriebs gmbh',
#  'Mazzergrip gd',
#  'Fimark',
#  'Nietfeld gmbh',
#  'Nifco',
#  'Nikkiso europe gmbh',
#  'Cadmium',
#  'Maxilaria',
#  'FABULOUS 3D',
#  'Financiera maderera',
#  'Timmerije bv',
#  'Mejorando',
#  'Chinook sciences',
#  'Modula',
#  'Mht ag',
#  'Fcaixeiro',
#  'To Be Informed Later',
#  'Mojalefalahakoloi suppliers',
#  'Cci meuse',
#  'Fanuc benelux bvba',
#  'Cerlux kft',
#  'Cci 52',
#  'Fanuc',
#  'CERES E&P GmbH',
#  'Modeltek s.n.c.',
#  'Modelark',
#  'Michell bearings limited',
#  'Modell- und formenbau stefan dreher',
#  'Tofco enterprises limited',
#  'Tods aerospace ltd',
#  'Modern combat gear',
#  'Michail dimou',
#  'Tobit.software',
#  'MICADO SMART ENGINEERING GmbH',
#  'Centurion safety products ltd',
#  'Miar additive manufacturing',
#  'Todograf s.a.',
#  'Monterrubio arquitectura',
#  'Moore stpehens',
#  'Moosing',
#  'Cesyco',
#  'Caterpillar inc.',
#  'Metzconnect',
#  'Ccc',
#  'MFD GmbH',
#  'Mga technologies',
#  'Molotov raw',
#  'Catuav',
#  'Cc+rr',
#  'Monosol af ltd',
#  'Monsieur eric manteau',
#  'Mg mike gascoyne int.',
#  'Fange aps',
#  'Mondi scunthorpe ltd',
#  'Morgan advanced marterials',
#  'Faro',
#  'Mod',
#  'Fastweb',
#  'Fath gmbh',
#  'Cendres+Métaux SA',
#  'Ministry of puplic works',
#  'Minitec españa',
#  'Celsa',
#  ' abb ag',
#  'Minoko design as',
#  'Torque-jet gmbh',
#  ' johnson matthey technology centre',
#  'Fau',
#  'Mikrocentrum',
#  ' lumi industries',
#  'Central scanning worcester',
#  'Minsait',
#  'Mill precision engineers ltd',
#  'Mimeos',
#  'Cemengal',
#  'Celwise ab',
#  'Torus technology group',
#  'Cemk',
#  'Modelar solutions',
#  'Miguel haro',
#  'Torneria automatica faentina',
#  'Centro ortopedico tecnologico',
#  'MICROSOFT',
#  'Ceetak ltd',
#  'Centro ortopedico torrejon,s.l.',
#  'Mm m  a member of daikin group aaf-international b.v.',
#  'Centro ortopedico extremeño',
#  'Centro ortopedico venezuela s.l.',
#  'Microhelis.de',
#  'Cecosa',
#  'Microdrones',
#  'Microdesk',
#  'Faza s.r.l.',
#  'Microsonic gmbh',
#  'Misumi',
#  'Tornejats i mecanitzats sl',
#  ' strahl kraft metalltechnik schmidt gmbh & co. kg',
#  'Mitsubishi electric europe',
#  'Mitsubishi Electric Europe B.V. Polish Branch',
#  'Centro ortopedico cuadrado',
#  'Top3dshop',
#  'Centre r&d nestle purina',
#  'Top. light',
#  'Mivetek',
#  'Top light',
#  'Middlesex university trent park campus',
#  'Cariotipo',
#  'Morph',
#  'Carmengarciavfx',
#  'Carmen toro',
#  'Müller erfindungen',
#  '2acad',
#  'Müller systeme gmbh',
#  'Mühlbauer gmbh & co. kg',
#  'Meritaistelukeikus Merivoimat',
#  'Charpak ltd',
#  'Carlos jose canut roldan',
#  'Multirotor',
#  '2acad global group',
#  'Merck',
#  'Carlos núñez',
#  '2acad global group s.l.',
#  'Charles kieffer group',
#  'Mtu friedrichshafen gmbh royce power systems company',
#  'To be determined later',
#  'Mt ortho',
#  'Mta prototyping gmbh',
#  'Chalmers university',
#  '24studiobim',
#  'Chamber of commerce and industry of belarus',
#  'Chaneco',
#  'Mtu aero engines ag',
#  'Msl control.usa',
#  'Mundos digitales',
#  "Municipalité d'ecully",
#  '2shapes technologies slu',
#  'Myeasy3d',
#  'Meljac',
#  'Faiveley (wabtec)',
#  'China-Euro Vehicle Technology',
#  '2shapes',
#  'Melba products ltd',
#  'Carl wittkopp',
#  'Mekverken tool',
#  'Faithful+gould',
#  '3 consulting',
#  'My travel',
#  'Menasco',
#  'Chelsea22',
#  'Chelsea22, slu',
#  'Mercedes-amg gmbh',
#  'Feronyl nv',
#  'Muodonmuutos oy',
#  'Muovipoli',
#  'Chief technology elektronische geräte-gesellschaft m.b.h. riedelbach technologiepark',
#  'Mercadona',
#  'Musi lublin',
#  'Muuntosaâ¤hko oy trafox',
#  'Mvn arquitectos',
#  'Ferralca',
#  'To be identified later',
#  'Catepillar',
#  'Metalsoto',
#  'Famag s.r.l.',
#  'Castor technologies ltd.',
#  '1a ingenieros',
#  'To be Found Later',
#  'Movement consulting gmbh',
#  '1a ingenieros slp',
#  'Metalis',
#  'Metalife',
#  'Fehrer AG',
#  'MPB srl',
#  'Meteg plast ltd',
#  'Motiva dv support gmbh',
#  'Morris commercial ltd',
#  'Metropolia (orthotics and prosthetics)',
#  'Metromecanica s.l.',
#  'Motivation',
#  'Fameco',
#  'Moss maritime',
#  'Cev barcelona',
#  'Mosca ing francesco',
#  'M-shtab',
#  'Castell safety international ltd',
#  'Feinwerktechnik hago GmbH',
#  'Messtechnik neth gmbh der lichten heide 18 169 hofgei v.messte. i.de',
#  'Mrt gmbh',
#  'Cgv engineering',
#  'Mesquecookies',
#  'Faltec europe',
#  'Mpo iberica',
#  'Mpo iberica s.l.',
#  'Metal Work Polska Sp. Z o.o.',
#  'Feist modellbau',
#  'Caseificio badin snc',
#  'Mr windscreen',
#  'C.m.e. srl',
#  'Exagonoa',
#  'Ortopinos',
#  'Lufthansa technik',
#  'Lüecop b prototypen &kleir',
#  'Ludwig-geiã?ler-schule',
#  'Consolite technology limited',
#  'Ludus vr',
#  'Consonance',
#  'Exaccta soluciones s.l.',
#  'Lucy electric',
#  'Ortoteco',
#  'Fornituras Técnicas S.L.',
#  'Ludwig meister gmbh',
#  'Lucid innovation',
#  'Teutonia kinderwagenfabrik gmbh',
#  '4DTECH SRL',
#  'Ortopedia todograf',
#  'Texcel technology plc',
#  'Lumi industries',
#  'Ortopedia tres cruces sl',
#  'Ortopedia turu',
#  '4iq',
#  'Lulau',
#  'Luis vidal + arquitectos',
#  'Excelcia limited',
#  'Ortopedia tecnica tarancon s.l.',
#  'Consorcio regional de transportes de madrid',
#  'Lrt automotive gmbh automotive',
#  '4ulab ug',
#  '5d',
#  'Lpw carpenter additive',
#  'Lpw carpennter additive',
#  'Botau materiaalbewerking',
#  'Osstem imolant',
#  'Lpc lamboy packaging consulting',
#  'Osstem implant',
#  'Consulente free lancer',
#  'Testa motari gmbh',
#  'JPB SYSTEME',
#  'Teufel prototypen gmbh',
#  'Construmatica',
#  'Evoteo',
#  'Eweer',
#  '4sd',
#  'Botek präzisionsbohrtechnik gmbh',
#  'Consorzio re-cord',
#  'Ewake',
#  'Lsgi',
#  'Oscident gmbh',
#  'Tetrapak',
#  'Ltr',
#  'botek',
#  'L-stin',
#  'Consoveyo',
#  'Osswald gmbh & c metallbearbeitung verbindungstechnik',
#  'Texmer gmbh & co. kg',
#  'Exe ejecución por excelencia',
#  'Lycee lafayette',
#  'Origen cad cam cae sl',
#  'Lycée hector guimard',
#  'Bpifrance financement',
#  'Bpi recycled products',
#  'Orhopedie lier',
#  'Orolux sa',
#  'Bowyer engineering',
#  'Bowman',
#  'Bowa-electronic gmbh &amp; co.kg',
#  'Ortecmo',
#  'Ortho organizers gmbh',
#  'Ortho-dent specials',
#  'Orottica di flavio mangiavacchi',
#  'Condat',
#  'Organica',
#  'Orckid',
#  'Forecreu biometal',
#  'Forestadent bernhard förster gmbh',
#  'CONCEPT MANUFACTURING',
#  'The automation partnership (cambridge) ltd',
#  'Lycée rempart',
#  'Form and branch',
#  '3yourmind sp. z o.o.',
#  'Exever',
#  "Orange Côte d'Ivoire",
#  'Brace orthopaedic',
#  'Texo',
#  'Condat projekt gmbh',
#  'Orthotics centre ltd',
#  'Lüttges gmbh',
#  'Ortopedia lacalle',
#  'Ortopedia mascotas',
#  'Ortopedia nalon',
#  'Ortopedia natal',
#  'Lüpke, berlin',
#  'Ortopedia juan bravo, s.l.',
#  'Executive forum',
#  'Ortopedia romeo',
#  'Formfactory',
#  'Ortopedia santos',
#  'Ortopedia sumisan, s.l.',
#  'Ortopedia técnica 2001',
#  'Ortopedia tecnica manuel gutierrez',
#  'Ortopedia ortosan sl',
#  'Orthos fachlabor für kieferorthopädie gmbh & co. kg',
#  'Ortopedia Ibor',
#  'Condor gmbh',
#  'Formerly utc aerospace (kidde graviner ltd)',
#  'Conec Elektronische Bauelemente Gmbh',
#  'Luzán 5',
#  'Ortomissa',
#  'Luxe srl',
#  'Ortopedia alser',
#  'Ortopedia arturo eyries',
#  'Ortopedia cemasa',
#  'Ortopedia clínica rico nestares',
#  'Ortopedia florencio',
#  'Conference series llc ltd',
#  'Luxottica srl',
#  '3yd',
#  'Ot4 gmbh',
#  'Bomag gmbh',
#  'Bomag',
#  'Core technnologie. gmbh',
#  'Bolton plastic components ltd',
#  'A&j instalaciones electricas',
#  'Temix communication',
#  'Lisi medical fasteners',
#  'Böllhoff verbindungstechnik',
#  'Telia',
#  'Teletu',
#  'Bodycote',
#  'Bolsas y mercados españoles',
#  'LJB',
#  'Lmt belin',
#  'Tenmat ltd',
#  'Palram polycarb ltd',
#  'Eurosarda',
#  'Copygraf sas',
#  'Lm',
#  'Lks',
#  'COPYWORLD KARLSRUHE',
#  'Francotyp-postalia gmbh',
#  'Bombardier european holdings',
#  'Bombardier aerostructures and engineering services',
#  'LLC 3d.ru',
#  'Pandrol',
#  'Paldoma',
#  'Linpac packaging',
#  'Linköpings universitet',
#  'Fraunhofer imws',
#  'Teknologisk institut',
#  'Lincoln ict koncept',
#  'Partners partners & company',
#  'Partool',
#  'Fraunhofer institut messtechnik',
#  'Bme',
#  'Bmb - tideway west',
#  'Blyweert beaufort aluminium',
#  'Bmo',
#  'Telefónica de españa s.a.u.',
#  'Fraunhofer ilt',
#  'Telarc',
#  'Linkam scientific instruments',
#  'Fraunhofer additive produktionstechnologien iapt',
#  'Fraunhofer anwendungszentrum systemtechnik ilmenau',
#  'Linertech ltd',
#  'Bnl uk ltd',
#  'Telair international gmbh',
#  'Parker hannifin manufacturing germany gmbh & co. kg',
#  'BMW AG',
#  'Bmw',
#  'Bmt additive n.v.',
#  'Particle technology',
#  'Fraunhofer iapt',
#  'Consulting afirr',
#  'Lmt lichtmesstechnik gmbh berlin',
#  'Lmtb laser- und, berlin',
#  'Ottobock. healthcare deutschland gmbh',
#  'Our lady and st. patrick school',
#  'Outotec',
#  'Everelgroup spa',
#  'Bosch Castellet SA',
#  'Loomans',
#  'Loom rosengrens',
#  'Fp mercure',
#  'Owen greenings & mumford holdings ltd',
#  'Everel group s.p.a.',
#  'Oxford plastic systems ltd',
#  'Loop unique companies',
#  'Oxford university radiobiology unit',
#  'Ottobock',
#  'Termotek gmbh',
#  'Evoke i',
#  'Tesera de hospitalidad',
#  'Oth regensburg, labor lasermaterialbearbeitung',
#  'Oticon a/s',
#  '916344331',
#  'Bosch Rexroth Ltd',
#  'OTTIMO SYSTEMS',
#  'Fourth state',
#  'Continuous retorts limited',
#  'A & d verpackungsmaschinenbau gmbh',
#  'Bosch schwieberding',
#  'Bonnplast',
#  'Logical space, s.l.',
#  'Loex comfort technology',
#  'Boneham & turner ltd',
#  'Bone3D',
#  'Lockpoint limited',
#  'Cooper capri sas',
#  'Francesco osti',
#  'Pakkanen additive manufacturing m&h cnc technik gmbh',
#  'Pakull',
#  'Pal group operations ltd',
#  'Eurotherm',
#  'Tenneco',
#  'Tennants uk ltd',
#  'Oxyplus international company ltd.',
#  'Bopla Gehause Sysreme GmbH',
#  'Tenuta le velette',
#  'London orthotic consultancy',
#  'London fog ltd',
#  'London fluid system technologies limited',
#  'P a n y industrial bts design innovation srl',
#  'P&c',
#  'FPT Robotik GmbH & Co. KG',
#  'Coolway',
#  'Termisa',
#  'Convatec',
#  'Loire gestamp',
#  'Logoplaste',
#  'Boreco, borst reparatie & constructie',
#  'Pablocascon',
#  'LOMOPRESS Srl',
#  'Lyon communication services',
#  'Lyon place financiere et tertiaire',
#  'Brammer dichtungen & tgmhs brammer gmbh',
#  'Manroland goss group',
#  'Codinfos',
#  'Budi',
#  'Flono additive',
#  'F.s. fehrer',
#  'Nupik international',
#  'Nuremberg plant center of competence 3d-printing',
#  'F.lli gancia & c.',
#  'Mann und hummel',
#  'Nutechnologies',
#  'F.iniciativas',
#  'Thorn lighting',
#  'Coellner edv service',
#  'Flli. ziveri',
#  'Nuonled',
#  'Nt-trading gmbh & co. kg',
#  'Codal de proyectos',
#  'Manufacturing technology center',
#  'Manufactura.co',
#  'Nuevos espacios y rehabilitacionez s.l.',
#  'Nuig',
#  '3dimensional',
#  'Buildy',
#  'Codditive',
#  'FLOVAC VACUUM SYSTEMS',
#  'F. iniciativas i+d+i',
#  'Obicex',
#  'Colegio aparejadores madrid',
#  'F. hoffmann - la roche ag',
#  'MAKPRO',
#  'Fluor alcoa',
#  'F&e optische sicherheitsmerkmale papierfabrik louisenthal gmbh',
#  'Obo bettermann gmbh 6 co. kg',
#  'Colegio oficial de aparejadores de madrid',
#  'Colegio oficial de ingenieros tecnicos industriales',
#  'Thomas gmbh',
#  'Colegio salesianos atocha',
#  'Objectiu comunicació',
#  'Nylacast holdings ltd',
#  'Thomas GmbH + Co. Technik + Innovation KG',
#  'Obe ohnmacht & baumgartner gmbh & co. kg',
#  'Btech_qe',
#  'O.l.d. engineering limited',
#  'Oaa stampi',
#  'Oa-engineering',
#  'Fluidmaster gb ltd',
#  'Oasis well',
#  '3dnet (sem as)',
#  'Thomas magnete gmbh',
#  'MAN',
#  'Fluidra engineering services',
#  'Cojac limited',
#  'mammt',
#  'OBE GmbH Co.KG',
#  'Thomas moore',
#  'Ntn-snr',
#  'Northern engineering sheffield ltd',
#  'Fabberz',
#  'Byerley,g,& sons',
#  '3d-druck.de',
#  'Mark arinstein maschinen und anlagen gmbh',
#  'Not Yet Found',
#  '3dcenter',
#  'Flemming dental gmbh',
#  'Tiger lifting uk limited',
#  'Butic the new school',
#  'Nova group ltd',
#  "Marina's service srl",
#  '3degin',
#  'Norsk titanium',
#  'Normon',
#  'Martin industriedesign',
#  'Noqo group',
#  'Noras performance',
#  'Marsh',
#  'Tilde consultora',
#  'Nord-lock ab',
#  'Marpak extrusions ltd',
#  '3dcejter',
#  'NORMA Group',
#  'C&w',
#  'Flam3D',
#  'Thyssenkrupp marine systems gmbh',
#  'Butic',
#  '3D-EST',
#  'Coba plastics',
#  'Burkert sas',
#  'Burghaus-stahlwaren',
#  'Cobham',
#  '3di consulting ltd',
#  'Flexipol packaging ltd',
#  'Coam',
#  'NRU GmbH',
#  'Nsert machining limited',
#  'NST',
#  'Mapfre digital health',
#  'Flexocard gmbh',
#  'Burg f.w. lüling kg',
#  'Cocemfe',
#  'Bürkert werke gmbh',
#  'Novia handels gmbh & co. kg',
#  'Margarita industries ltd',
#  'Ticsoluciones',
#  'Cnr imm',
#  'Novasystem srl',
#  'Novatec gmbh',
#  'Flexi narrow isle',
#  '3dhappiness.bg',
#  'Fa. tts clentec gmbh',
#  'Ti group',
#  'Novenco marine & offshore as',
#  'Maker media gmbh',
#  'Col-lab',
#  'Brembo s.p.a',
#  'Fonts fresco ltd.',
#  'Food and more',
#  'Bregil b.v.',
#  'Company lego system a/s',
#  'Onefid gmbh',
#  'Complejo hospitalario universitario de canarias',
#  'Onesubsea',
#  'The tintometer ltd',
#  'Bre global ltd',
#  'Mab group',
#  'Expertants gmbh',
#  'Expert tooling & automation',
#  'Bray',
#  'Machineworks ltd',
#  '3dynamic system',
#  'Bricsys',
#  'Fondazione enaip',
#  'Omniwise gmbh',
#  'Breyner/ tetra medical',
#  'Theissen industrietechnik',
#  'Fonti alta valle po',
#  'Theegarten-pactec gmbh & co. kg',
#  'Madaca-sys',
#  'Comite d entreprise de sofradir',
#  'The university of west of scotland',
#  '3M Deutschland GmbH',
#  '3m españa sl',
#  'Mackart additive',
#  'Made for movement group as',
#  'Fondation epf',
#  'Complextechsnab llc',
#  'Brava producciones',
#  ...]

# %%
### LOOP
##############################################################

companies_list = []
companies_count = 0

browser.get('https://www.glassdoor.es/Opiniones/amazon-opiniones-SRCH_KE0,6.htm')

for company in companies:
    error = False
    inside_page = False
    headers_list = []
    comp_data_list = []
    
    headers_list.append('Name')
    comp_data_list.append(company)
    
    time.sleep(round(random.uniform(3, 4),2))

    try: 
        elementID = browser.find_element_by_id('sc.keyword')
    except: ## ERROR WHEN IT GETS OUT OF THE OPINIONS SEARCH
        browser.get('https://www.glassdoor.es/Opiniones/amazon-opiniones-SRCH_KE0,6.htm')
        error = True
    elementID = browser.find_element_by_id('sc.keyword')
    elementID.send_keys(Keys.CONTROL, 'a')
    elementID.send_keys(Keys.BACKSPACE)
    elementID.send_keys(company)
    elementID.submit()
    
    
    time.sleep(round(random.uniform(5, 7),2))
    
    ### SOMETIMES IT ENTERS THE PAGE DIRECTLY
    try:
        browser.find_element_by_xpath("//span[@class='sqLogo tighten lgSqLogo logoOverlay']//img").click()
        inside_page = True
    except:
        pass
    
    # IF COMPANY NOT FOUND, CATCH.
    if inside_page == False:
        try:
            browser.find_element_by_xpath("//body[contains(@class,'_initOk noTouch tablet mobileFF')]/div[contains(@class,'pageContentWrapper')]/div[@id='PageContent']/div[@id='PageBodyContents']/div[contains(@class,'pageInsideContent cf')]/div[@id='EI-Srch']/div[@id='SearchResults']/div[@id='ReviewSearchResults']/article[@id='MainCol']/div[contains(@class,'module')]/div[2]/div[1]/div[2]/div[1]").click()  
        except NoSuchElementException:  #spelling error making this code not work as expected
            error = True
            
    time.sleep(round(random.uniform(5, 6),2))    
    
    if error==False:    
        src = browser.page_source
        soup = BeautifulSoup(src, 'lxml')
        
        try:
            company_div = soup.find('div', {'class': 'info flexbox row col-hh'})
            header = company_div.find_all('label')
            info = company_div.find_all('span')
        except:
            pass

        for i in range(0,len(header)):
            headers_list.append(header[i].get_text().strip())
            comp_data_list.append(info[i].get_text().strip())

    companies_list.append(headers_list)
    companies_list.append(comp_data_list)

    companies_count = companies_count+1
    if companies_count % 250 == 0:
        time.sleep(round(random.uniform(65, 90),2))
    print('{}: Scraping: {}% completed - {}'.format(companies_count,round(companies_count/len(companies)*100,2),company))
# Out:
# 1: Scraping: 0.01% completed - Daimler corp
# 2: Scraping: 0.02% completed - Curt nicolin gymnasiet
# 3: Scraping: 0.03% completed - Kongsberg maritime
# 4: Scraping: 0.04% completed - Ad adenta
# 5: Scraping: 0.05% completed - Prisca
# 6: Scraping: 0.05% completed - Gemini erp system design
# 7: Scraping: 0.06% completed - Tangram solutions sl
# 8: Scraping: 0.07% completed - Essentra packaging ltd
# 9: Scraping: 0.08% completed - Dana italia spa
# 10: Scraping: 0.09% completed - Daco solutions ltd (future)
# 11: Scraping: 0.1% completed - Kirubotics surgical solutions
# 12: Scraping: 0.11% completed - Kirpart
# 13: Scraping: 0.12% completed - Dacey orthopaedics ltd
# 14: Scraping: 0.13% completed - Bel engineering
# 15: Scraping: 0.14% completed - Polytec car styling uk ltd
# 16: Scraping: 0.14% completed - TE Connectivity Germany GmbH
# 17: Scraping: 0.15% completed - KION Group
# 18: Scraping: 0.16% completed - Tangram solutions s.l.
# 19: Scraping: 0.17% completed - Dacey limited
# 20: Scraping: 0.18% completed - Dana motion system italia
# 21: Scraping: 0.19% completed - Belgrade insulations ltd
# 22: Scraping: 0.2% completed - Gdd solutions
# 23: Scraping: 0.21% completed - Bautermic
# 24: Scraping: 0.22% completed - Geka GmbH
# 25: Scraping: 0.23% completed - Koninklijke douwe egberts b.v
# 26: Scraping: 0.23% completed - Tcn
# 27: Scraping: 0.24% completed - Geko electronics ltd
# 28: Scraping: 0.25% completed - Postnord strålfors
# 29: Scraping: 0.26% completed - Prima industries srl
# 30: Scraping: 0.27% completed - Konstruktionen alt
# 31: Scraping: 0.28% completed - Bee Robotics
# 32: Scraping: 0.29% completed - Primes gmbh
# 33: Scraping: 0.3% completed - Power dynamic technology
# 34: Scraping: 0.31% completed - Konstruktörbüro huwer
# 35: Scraping: 0.32% completed - Kookaburra Bv
# 36: Scraping: 0.32% completed - Bayer ag
# 37: Scraping: 0.33% completed - Bayer
# 38: Scraping: 0.34% completed - Bay plastics
# 39: Scraping: 0.35% completed - Kopas
# 40: Scraping: 0.36% completed - Tdm
# 41: Scraping: 0.37% completed - Koppendorfer roboter-service & feinwerktechnik
# 42: Scraping: 0.38% completed - Bego gmbh & co. kg
# 43: Scraping: 0.39% completed - Baxter international inc.
# 44: Scraping: 0.4% completed - Acodeq kunststoffen
# 45: Scraping: 0.41% completed - Biemmegi spa
# 46: Scraping: 0.42% completed - Tech data
# 47: Scraping: 0.42% completed - Dannenman gmbh
# 48: Scraping: 0.43% completed - Lag spa
# 49: Scraping: 0.44% completed - Cs.ccoo
# 50: Scraping: 0.45% completed - Geometryfactory
# 51: Scraping: 0.46% completed - Lahnwerk gmbh
# 52: Scraping: 0.47% completed - Geopas s.a.c.
# 53: Scraping: 0.48% completed - Laing o'rourke
# 54: Scraping: 0.49% completed - Kellpla group
# 55: Scraping: 0.5% completed - DATA PLASTICS LTD
# 56: Scraping: 0.51% completed - Produmax
# 57: Scraping: 0.51% completed - Plastic manu. and reclying
# 58: Scraping: 0.52% completed - Data4image th. loth
# 59: Scraping: 0.53% completed - Proengin
# 60: Scraping: 0.54% completed - Technoconsult firenze
# 61: Scraping: 0.55% completed - Lambson
# 62: Scraping: 0.56% completed - Datacomp sp. z o.o.
# 63: Scraping: 0.57% completed - Plastcom s.r.o.
# 64: Scraping: 0.58% completed - Lamia
# 65: Scraping: 0.59% completed - Bhf aktiengesellschaft
# 66: Scraping: 0.6% completed - Georg fischer automobilguss gmbh
# 67: Scraping: 0.6% completed - Bhge
# 68: Scraping: 0.61% completed - Das-nano
# 69: Scraping: 0.62% completed - Product 4 ltd
# 70: Scraping: 0.63% completed - Techno sky
# 71: Scraping: 0.64% completed - Gabinete de ortopedia alcalá
# 72: Scraping: 0.65% completed - Gabel industria tessile
# 73: Scraping: 0.66% completed - Gã¼ntner
# 74: Scraping: 0.67% completed - Ga.ma srl
# 75: Scraping: 0.68% completed - Ga operation s.p.a.
# 76: Scraping: 0.69% completed - Labrox oy
# 77: Scraping: 0.7% completed - Labs planet
# 78: Scraping: 0.7% completed - DARIO DESIGN SARL
# 79: Scraping: 0.71% completed - Technische universität ilmenau production technology group
# 80: Scraping: 0.72% completed - Plasticos Tatay
# 81: Scraping: 0.73% completed - Barronkress
# 82: Scraping: 0.74% completed - Technisches büro gmbh
# 83: Scraping: 0.75% completed - Beurer gmbh
# 84: Scraping: 0.76% completed - Lacroix emballages
# 85: Scraping: 0.77% completed - Baron & verhoef materieel b.v.
# 86: Scraping: 0.78% completed - Prodiel
# 87: Scraping: 0.79% completed - Kenwood ltd
# 88: Scraping: 0.79% completed - Plasticon uk ltd
# 89: Scraping: 0.8% completed - Geolid
# 90: Scraping: 0.81% completed - Das kunststoff-zentrum skz
# 91: Scraping: 0.82% completed - kein Unternehmen
# 92: Scraping: 0.83% completed - Pizeta srl di peron e zerbato
# 93: Scraping: 0.84% completed - Pixers
# 94: Scraping: 0.85% completed - Profile consulting group
# 95: Scraping: 0.86% completed - PROFILS-SYSTEMES
# 96: Scraping: 0.87% completed - LAPP Group
# 97: Scraping: 0.88% completed - Abs precision limited
# 98: Scraping: 0.88% completed - Bank of england
# 99: Scraping: 0.89% completed - Future products ltd
# 100: Scraping: 0.9% completed - Dauphelec
# 101: Scraping: 0.91% completed - Talarmade ltd
# 102: Scraping: 0.92% completed - larderArch Srls
# 103: Scraping: 0.93% completed - pironex GmbH
# 104: Scraping: 0.94% completed - Talar made limited
# 105: Scraping: 0.95% completed - Furness college
# 106: Scraping: 0.96% completed - Crit
# 107: Scraping: 0.97% completed - Gerard perrier industrie
# 108: Scraping: 0.97% completed - Talentoo
# 109: Scraping: 0.98% completed - Fzi forschungszentrum informatik
# 110: Scraping: 0.99% completed - Technology product&application technology uponor gmbh
# 111: Scraping: 1.0% completed - Academy of fine arts in krakow
# 112: Scraping: 1.01% completed - Crp
# 113: Scraping: 1.02% completed - Georg fishcher
# 114: Scraping: 1.03% completed - Georg schlegel gmbh & co.kg
# 115: Scraping: 1.04% completed - Academia piramides
# 116: Scraping: 1.05% completed - Lanbide
# 117: Scraping: 1.06% completed - Crown Equipment Corporation
# 118: Scraping: 1.07% completed - Datagenius
# 119: Scraping: 1.07% completed - Ac2
# 120: Scraping: 1.08% completed - Lander automotive
# 121: Scraping: 1.09% completed - Plan.tec. gruppe
# 122: Scraping: 1.1% completed - Technology and production center switzerland ag
# 123: Scraping: 1.11% completed - Geosec srl
# 124: Scraping: 1.12% completed - Geotecnical consulting
# 125: Scraping: 1.13% completed - Placer y deseo
# 126: Scraping: 1.14% completed - Crompton technology group ltd
# 127: Scraping: 1.15% completed - Kea & partners
# 128: Scraping: 1.16% completed - Technische universität graz institut für fertigungstechnik
# 129: Scraping: 1.16% completed - Kyocera
# 130: Scraping: 1.17% completed - Techdata
# 131: Scraping: 1.18% completed - Techedge
# 132: Scraping: 1.19% completed - L gemeinschaft
# 133: Scraping: 1.2% completed - L&g ingeniería sostenible s.l.
# 134: Scraping: 1.21% completed - Proair gerätebau gmbh
# 135: Scraping: 1.22% completed - Proaltec
# 136: Scraping: 1.23% completed - L&s italia s.r.l di brugnera
# 137: Scraping: 1.24% completed - Acekare
# 138: Scraping: 1.25% completed - L.l. gioielli di luigi loddo
# 139: Scraping: 1.25% completed - Pmg füssen gmbh
# 140: Scraping: 1.26% completed - Cubidesign gehäuse gmbh individuelle kunststottgehäuse
# 141: Scraping: 1.27% completed - Technical services
# 142: Scraping: 1.28% completed - Keuco gmbh & co. kg
# 143: Scraping: 1.29% completed - Pm project services ltd
# 144: Scraping: 1.3% completed - Technical unfyersityof liberec
# 145: Scraping: 1.31% completed - Cubic inch
# 146: Scraping: 1.32% completed - Dansk am hub
# 147: Scraping: 1.33% completed - Basell deutschland gmbh
# 148: Scraping: 1.34% completed - Base 3d printing solutions gmbh
# 149: Scraping: 1.35% completed - La factoria 3d
# 150: Scraping: 1.35% completed - Technical university of denmark
# 151: Scraping: 1.36% completed - Ess engineering, services & solutions gmbh
# 152: Scraping: 1.37% completed - Tech-a ltd
# 153: Scraping: 1.38% completed - tech@housing
# 154: Scraping: 1.39% completed - Polamco limited
# 155: Scraping: 1.4% completed - Kunststoff-zentrum in leipzig ggmbh
# 156: Scraping: 1.41% completed - Et global exhibit group
# 157: Scraping: 1.42% completed - POK SAS
# 158: Scraping: 1.43% completed - Eta
# 159: Scraping: 1.44% completed - Berrilan ingenieria bim
# 160: Scraping: 1.44% completed - Kurz
# 161: Scraping: 1.45% completed - GAO operations
# 162: Scraping: 1.46% completed - Tech soft 3d
# 163: Scraping: 1.47% completed - Berufliches schulzentrum otto lilienthal
# 164: Scraping: 1.48% completed - Berthold sichert gmbh
# 165: Scraping: 1.49% completed - Keytec international b.v.
# 166: Scraping: 1.5% completed - Podoquiles
# 167: Scraping: 1.51% completed - Podfo
# 168: Scraping: 1.52% completed - Kvt-fastening
# 169: Scraping: 1.53% completed - Pobjeda technology gora?de d.d.
# 170: Scraping: 1.53% completed - Kw special projects
# 171: Scraping: 1.54% completed - Pny
# 172: Scraping: 1.55% completed - Pneumo, frankfurt
# 173: Scraping: 1.56% completed - Ess engineering, services &solutions gmbh
# 174: Scraping: 1.57% completed - Polamco limited second contact
# 175: Scraping: 1.58% completed - Gallina mario
# 176: Scraping: 1.59% completed - Kesseböhmer Beschlagsysteme GmbH & Co. KG
# 177: Scraping: 1.6% completed - Bestmedic
# 178: Scraping: 1.61% completed - Beta Robots
# 179: Scraping: 1.62% completed - Laboratoires m&l groupe l'occitane
# 180: Scraping: 1.62% completed - Betech
# 181: Scraping: 1.63% completed - Betech kunststoffen bv
# 182: Scraping: 1.64% completed - Beth-ei industries ndreas koege beth-ei zikhron yaaqov industries ltd.
# 183: Scraping: 1.65% completed - Talleres de escoriaza, s.a.u.
# 184: Scraping: 1.66% completed - Technische Hochschule Mittelhessen
# 185: Scraping: 1.67% completed - Technische universität berlin institut für mathematik sd-labor sekr.
# 186: Scraping: 1.68% completed - Gaeva promotores
# 187: Scraping: 1.69% completed - Between Technology
# 188: Scraping: 1.7% completed - Laboratorios almirall s.l.
# 189: Scraping: 1.71% completed - Etaja3d
# 190: Scraping: 1.72% completed - Prodelox
# 191: Scraping: 1.72% completed - Technische Universität Chemnitz
# 192: Scraping: 1.73% completed - Laboratorios normon
# 193: Scraping: 1.74% completed - Labor für allgemeine datenverarbeitung 3d-druck und -scan technische hochschule köln campus gummersbach technology
# 194: Scraping: 1.75% completed - Techniplas
# 195: Scraping: 1.76% completed - Best future
# 196: Scraping: 1.77% completed - Esne
# 197: Scraping: 1.78% completed - Accumotive gmbh & co kg
# 198: Scraping: 1.79% completed - Berufsbildendeschulen rinteln
# 199: Scraping: 1.8% completed - Gallardo&murillo
# 200: Scraping: 1.81% completed - Berufsbildungswerk neckargemünd gmbh
# 201: Scraping: 1.81% completed - Acciona infraestructuras
# 202: Scraping: 1.82% completed - Kessböhmer Gmbh
# 203: Scraping: 1.83% completed - Ctdi gmbh
# 204: Scraping: 1.84% completed - Galiciadreams
# 205: Scraping: 1.85% completed - Berufsförderungswerk schömberg
# 206: Scraping: 1.86% completed - Procter & gamble manufacturing gmbh
# 207: Scraping: 1.87% completed - Besaplast kunststoffe gmbh
# 208: Scraping: 1.88% completed - Procoplast
# 209: Scraping: 1.89% completed - La vie claire
# 210: Scraping: 1.9% completed - Accesorios Correo Neumático SL
# 211: Scraping: 1.9% completed - Player one
# 212: Scraping: 1.91% completed - Procter and gamble
# 213: Scraping: 1.92% completed - Bespak
# 214: Scraping: 1.93% completed - Labara s.r.o.
# 215: Scraping: 1.94% completed - Bespak europe limited
# 216: Scraping: 1.95% completed - Lab-lob
# 217: Scraping: 1.96% completed - Eso sud est
# 218: Scraping: 1.97% completed - Ct3 ingeniería
# 219: Scraping: 1.98% completed - Limacorporate s.p.a.
# 220: Scraping: 1.99% completed - Skanska
# 221: Scraping: 1.99% completed - Patia diabetes
# 222: Scraping: 2.0% completed - 3d printfabriek
# 223: Scraping: 2.01% completed - 3d prod platex
# 224: Scraping: 2.02% completed - Neher systeme
# 225: Scraping: 2.03% completed - To BE Anounced Later
# 226: Scraping: 2.04% completed - Ffl s.r.l.
# 227: Scraping: 2.05% completed - Neinver
# 228: Scraping: 2.06% completed - Negativedesign
# 229: Scraping: 2.07% completed - Camvac ltd
# 230: Scraping: 2.08% completed - Cifp someso
# 231: Scraping: 2.09% completed - Nemak
# 232: Scraping: 2.09% completed - Nemak Linz GmbH
# 233: Scraping: 2.1% completed - Nel technologies limited
# 234: Scraping: 2.11% completed - Faerch plast uk ltd
# 235: Scraping: 2.12% completed - Cice, s.a.
# 236: Scraping: 2.13% completed - 3D Manz
# 237: Scraping: 2.14% completed - NDT Global
# 238: Scraping: 2.15% completed - Mecmesin ltd
# 239: Scraping: 2.16% completed - 3d medical print kg
# 240: Scraping: 2.17% completed - Mechatronik system gmbh
# 241: Scraping: 2.18% completed - Candy italy
# 242: Scraping: 2.18% completed - Nedschroef
# 243: Scraping: 2.19% completed - Cieciefrezdwanie.pl produkcja/biuro
# 244: Scraping: 2.2% completed - Festo italy
# 245: Scraping: 2.21% completed - 3D Phoenix
# 246: Scraping: 2.22% completed - Neaforma
# 247: Scraping: 2.23% completed - Cice, la escuela profesional de nuevas tecnologías
# 248: Scraping: 2.24% completed - CIM GmbH Logistik-Systeme
# 249: Scraping: 2.25% completed - Facultés universitaires notre-dame de la paix
# 250: Scraping: 2.26% completed - Cis galicia - axencia galega de innovación - xunta de galicia
# 251: Scraping: 2.27% completed - Mdh sp.z o.o
# 252: Scraping: 2.27% completed - CIRP
# 253: Scraping: 2.28% completed - Netzsch gerätebau gmbh
# 254: Scraping: 2.29% completed - Ciser system slu
# 255: Scraping: 2.3% completed - Neurtek
# 256: Scraping: 2.31% completed - Cisme
# 257: Scraping: 2.32% completed - Calsonic kansei
# 258: Scraping: 2.33% completed - Factoría 5 hub
# 259: Scraping: 2.34% completed - Mdesign intl
# 260: Scraping: 2.35% completed - Neon lab
# 261: Scraping: 2.36% completed - Mds regensburg
# 262: Scraping: 2.37% completed - Fibrax ltd
# 263: Scraping: 2.37% completed - Fh dortmund
# 264: Scraping: 2.38% completed - Fh kiel
# 265: Scraping: 2.39% completed - Cameron-price ltd
# 266: Scraping: 2.4% completed - Fh würzburg- schweinfurt
# 267: Scraping: 2.41% completed - Fhecor
# 268: Scraping: 2.42% completed - Fibreco
# 269: Scraping: 2.43% completed - Cips
# 270: Scraping: 2.44% completed - Meanwhile
# 271: Scraping: 2.45% completed - Cámara de comercio
# 272: Scraping: 2.46% completed - Fibernet
# 273: Scraping: 2.46% completed - Factoria5hub
# 274: Scraping: 2.47% completed - Factoría 5 training hub
# 275: Scraping: 2.48% completed - Factorhia sl
# 276: Scraping: 2.49% completed - Fertig Motors GmbH
# 277: Scraping: 2.5% completed - Nbso
# 278: Scraping: 2.51% completed - Medlab media group
# 279: Scraping: 2.52% completed - Carboplast  s.a.s.
# 280: Scraping: 2.53% completed - Fagorederlangroup
# 281: Scraping: 2.54% completed - Christoph deiss
# 282: Scraping: 2.55% completed - Carbofibretec gmbh
# 283: Scraping: 2.55% completed - Mediktiv
# 284: Scraping: 2.56% completed - Carase 2787 s.l.
# 285: Scraping: 2.57% completed - Chopsticks studio
# 286: Scraping: 2.58% completed - Cardis sp. z o.o.
# 287: Scraping: 2.59% completed - 34914562937
# 288: Scraping: 2.6% completed - Naber plastics b.v
# 289: Scraping: 2.61% completed - Meine anhängsel gmbh
# 290: Scraping: 2.62% completed - Carestream health
# 291: Scraping: 2.63% completed - Medysalud
# 292: Scraping: 2.64% completed - Nachoviedo
# 293: Scraping: 2.64% completed - Megator
# 294: Scraping: 2.65% completed - Megasaber
# 295: Scraping: 2.66% completed - Nakama steam college
# 296: Scraping: 2.67% completed - Namthaja
# 297: Scraping: 2.68% completed - Meggitt sensing systems
# 298: Scraping: 2.69% completed - Cice
# 299: Scraping: 2.7% completed - Medicon eg
# 300: Scraping: 2.71% completed - Mediapro
# 301: Scraping: 2.72% completed - CIBO GmbH
# 302: Scraping: 2.73% completed - Navantia.sa
# 303: Scraping: 2.74% completed - Medartis
# 304: Scraping: 2.74% completed - Canterbury college
# 305: Scraping: 2.75% completed - Medanco bv
# 306: Scraping: 2.76% completed - Canterbury chemicals international llc
# 307: Scraping: 2.77% completed - 3d druck stahl
# 308: Scraping: 2.78% completed - Medica panamericana
# 309: Scraping: 2.79% completed - Caran d'ache
# 310: Scraping: 2.8% completed - Natec-medical ltd
# 311: Scraping: 2.81% completed - Medicea medica
# 312: Scraping: 2.82% completed - National oilwell varco
# 313: Scraping: 2.83% completed - 3d cadtor
# 314: Scraping: 2.83% completed - Captae digitalizado 3d, s.l.
# 315: Scraping: 2.84% completed - Capitel
# 316: Scraping: 2.85% completed - Capgemini
# 317: Scraping: 2.86% completed - Medica praha s.r.o.
# 318: Scraping: 2.87% completed - Meister strömungstechnik gmbh
# 319: Scraping: 2.88% completed - Nevicolor
# 320: Scraping: 2.89% completed - Citd engineering & technologies
# 321: Scraping: 2.9% completed - Nke cad systems
# 322: Scraping: 2.91% completed - Nke cad systems, s.l.
# 323: Scraping: 2.92% completed - First solution technologies limited
# 324: Scraping: 2.92% completed - Cll consulting
# 325: Scraping: 2.93% completed - Tknika
# 326: Scraping: 2.94% completed - 3d startup campus nrw
# 327: Scraping: 2.95% completed - Masterdor ltd
# 328: Scraping: 2.96% completed - Titon hardware ltd
# 329: Scraping: 2.97% completed - 3d startupcampus. nrw
# 330: Scraping: 2.98% completed - Clwyd compounders ltd
# 331: Scraping: 2.99% completed - Cad&lan s. a.
# 332: Scraping: 3.0% completed - 3d shopnl
# 333: Scraping: 3.01% completed - Clevedon fasteners
# 334: Scraping: 3.01% completed - Fip
# 335: Scraping: 3.02% completed - Cadac
# 336: Scraping: 3.03% completed - Tmg
# 337: Scraping: 3.04% completed - Nke cad systemes
# 338: Scraping: 3.05% completed - Matricel GmbH
# 339: Scraping: 3.06% completed - Fire angel / sprue safety products
# 340: Scraping: 3.07% completed - Clickthegear
# 341: Scraping: 3.08% completed - Nissan motor ibérica, s.a.
# 342: Scraping: 3.09% completed - Climarqtec
# 343: Scraping: 3.1% completed - Materials Research Institute Aalen
# 344: Scraping: 3.11% completed - Fischbach uk ltd
# 345: Scraping: 3.11% completed - Titk e.v.
# 346: Scraping: 3.12% completed - Cab automotive
# 347: Scraping: 3.13% completed - Nokia tecss
# 348: Scraping: 3.14% completed - Mas consulting
# 349: Scraping: 3.15% completed - Ca digital
# 350: Scraping: 3.16% completed - Fives landis limited
# 351: Scraping: 3.17% completed - C95 creative
# 352: Scraping: 3.18% completed - Marty sports
# 353: Scraping: 3.19% completed - Martor kg
# 354: Scraping: 3.2% completed - Nölle nodeko betriebs-gmbh
# 355: Scraping: 3.2% completed - Martini & rossi s.p.a
# 356: Scraping: 3.21% completed - Tine
# 357: Scraping: 3.22% completed - Martor martor kg
# 358: Scraping: 3.23% completed - Cm advanded printing iberia, s.a
# 359: Scraping: 3.24% completed - Noelle + von campe
# 360: Scraping: 3.25% completed - Cm tools
# 361: Scraping: 3.26% completed - Titgemeyer uk ltd
# 362: Scraping: 3.27% completed - Titanium generation gmbh
# 363: Scraping: 3.28% completed - Massmould ltd
# 364: Scraping: 3.29% completed - Fischer elektromotoren gmbh
# 365: Scraping: 3.29% completed - Fischer elektronik
# 366: Scraping: 3.3% completed - Cmp marketing limited
# 367: Scraping: 3.31% completed - No climb products limited
# 368: Scraping: 3.32% completed - Fischer italia
# 369: Scraping: 3.33% completed - Fishercast (uk) ltd
# 370: Scraping: 3.34% completed - Noba consultores
# 371: Scraping: 3.35% completed - Cad global consultors
# 372: Scraping: 3.36% completed - Cad & bim services
# 373: Scraping: 3.37% completed - Cabot switzerland gmbh
# 374: Scraping: 3.38% completed - No nome yet
# 375: Scraping: 3.39% completed - Fichet
# 376: Scraping: 3.39% completed - Matthias kolb und volker scheibe gbr
# 377: Scraping: 3.4% completed - Fachhochschule augsburg
# 378: Scraping: 3.41% completed - Cair lgl
# 379: Scraping: 3.42% completed - Mca engineering / eos
# 380: Scraping: 3.43% completed - Mc orthopädietechnik gmbh
# 381: Scraping: 3.44% completed - Cixa
# 382: Scraping: 3.45% completed - Cixa design
# 383: Scraping: 3.46% completed - Nexans france
# 384: Scraping: 3.47% completed - Ck charles kieffer group
# 385: Scraping: 3.48% completed - Mbs sulzbach
# 386: Scraping: 3.48% completed - Ngi
# 387: Scraping: 3.49% completed - Filon products ltd
# 388: Scraping: 3.5% completed - Nicholson's aircraft seals limited
# 389: Scraping: 3.51% completed - NG Plastics
# 390: Scraping: 3.52% completed - News innovation
# 391: Scraping: 3.53% completed - Newgate clocks
# 392: Scraping: 3.54% completed - Citd, engineering & technologies
# 393: Scraping: 3.55% completed - Fachhochschule würzburg-schweinfurt
# 394: Scraping: 3.56% completed - New model in technology & engineering
# 395: Scraping: 3.57% completed - Fieldmade as
# 396: Scraping: 3.57% completed - Callfersa
# 397: Scraping: 3.58% completed - Fachhochschule nordwestschweiz
# 398: Scraping: 3.59% completed - Calleadesign snc
# 399: Scraping: 3.6% completed - Newarc limited
# 400: Scraping: 3.61% completed - Mclaren applied technologies
# 401: Scraping: 3.62% completed - Mcl control usa
# 402: Scraping: 3.63% completed - Finsa
# 403: Scraping: 3.64% completed - Nicomatic
# 404: Scraping: 3.65% completed - Nidec control techniques dynamics
# 405: Scraping: 3.66% completed - Max planck institute for brain research
# 406: Scraping: 3.66% completed - F-iniciativas
# 407: Scraping: 3.67% completed - Clean tech uk ltd
# 408: Scraping: 3.68% completed - Clece
# 409: Scraping: 3.69% completed - Nimrana ltd
# 410: Scraping: 3.7% completed - Fink chem+tec, bad dürrheim
# 411: Scraping: 3.71% completed - Nioco, s.l.
# 412: Scraping: 3.72% completed - Fabs robotics slu
# 413: Scraping: 3.73% completed - Maurer & wirtz house of perfumes
# 414: Scraping: 3.74% completed - Fabrinet uk limited
# 415: Scraping: 3.75% completed - Cadems s.l
# 416: Scraping: 3.76% completed - Mb tecnology
# 417: Scraping: 3.76% completed - Clausell studio
# 418: Scraping: 3.77% completed - Nilfisk spa
# 419: Scraping: 3.78% completed - Filtrec spa
# 420: Scraping: 3.79% completed - Face
# 421: Scraping: 3.8% completed - Mb group fischer vertriebs gmbh
# 422: Scraping: 3.81% completed - Mazzergrip gd
# 423: Scraping: 3.82% completed - Fimark
# 424: Scraping: 3.83% completed - Nietfeld gmbh
# 425: Scraping: 3.84% completed - Nifco
# 426: Scraping: 3.85% completed - Nikkiso europe gmbh
# 427: Scraping: 3.85% completed - Cadmium
# 428: Scraping: 3.86% completed - Maxilaria
# 429: Scraping: 3.87% completed - FABULOUS 3D
# 430: Scraping: 3.88% completed - Financiera maderera
# 431: Scraping: 3.89% completed - Timmerije bv
# 432: Scraping: 3.9% completed - Mejorando
# 433: Scraping: 3.91% completed - Chinook sciences
# 434: Scraping: 3.92% completed - Modula
# 435: Scraping: 3.93% completed - Mht ag
# 436: Scraping: 3.94% completed - Fcaixeiro
# 437: Scraping: 3.94% completed - To Be Informed Later
# 438: Scraping: 3.95% completed - Mojalefalahakoloi suppliers
# 439: Scraping: 3.96% completed - Cci meuse
# 440: Scraping: 3.97% completed - Fanuc benelux bvba
# 441: Scraping: 3.98% completed - Cerlux kft
# 442: Scraping: 3.99% completed - Cci 52
# 443: Scraping: 4.0% completed - Fanuc
# 444: Scraping: 4.01% completed - CERES E&P GmbH
# 445: Scraping: 4.02% completed - Modeltek s.n.c.
# 446: Scraping: 4.03% completed - Modelark
# 447: Scraping: 4.04% completed - Michell bearings limited
# 448: Scraping: 4.04% completed - Modell- und formenbau stefan dreher
# 449: Scraping: 4.05% completed - Tofco enterprises limited
# 450: Scraping: 4.06% completed - Tods aerospace ltd
# 451: Scraping: 4.07% completed - Modern combat gear
# 452: Scraping: 4.08% completed - Michail dimou
# 453: Scraping: 4.09% completed - Tobit.software
# 454: Scraping: 4.1% completed - MICADO SMART ENGINEERING GmbH
# 455: Scraping: 4.11% completed - Centurion safety products ltd
# 456: Scraping: 4.12% completed - Miar additive manufacturing
# 457: Scraping: 4.13% completed - Todograf s.a.
# 458: Scraping: 4.13% completed - Monterrubio arquitectura
# 459: Scraping: 4.14% completed - Moore stpehens
# 460: Scraping: 4.15% completed - Moosing
# 461: Scraping: 4.16% completed - Cesyco
# 462: Scraping: 4.17% completed - Caterpillar inc.
# 463: Scraping: 4.18% completed - Metzconnect
# 464: Scraping: 4.19% completed - Ccc
# 465: Scraping: 4.2% completed - MFD GmbH
# 466: Scraping: 4.21% completed - Mga technologies
# 467: Scraping: 4.22% completed - Molotov raw
# 468: Scraping: 4.22% completed - Catuav
# 469: Scraping: 4.23% completed - Cc+rr
# 470: Scraping: 4.24% completed - Monosol af ltd
# 471: Scraping: 4.25% completed - Monsieur eric manteau
# 472: Scraping: 4.26% completed - Mg mike gascoyne int.
# 473: Scraping: 4.27% completed - Fange aps
# 474: Scraping: 4.28% completed - Mondi scunthorpe ltd
# 475: Scraping: 4.29% completed - Morgan advanced marterials
# 476: Scraping: 4.3% completed - Faro
# 477: Scraping: 4.31% completed - Mod
# 478: Scraping: 4.31% completed - Fastweb
# 479: Scraping: 4.32% completed - Fath gmbh
# 480: Scraping: 4.33% completed - Cendres+Métaux SA
# 481: Scraping: 4.34% completed - Ministry of puplic works
# 482: Scraping: 4.35% completed - Minitec españa
# 483: Scraping: 4.36% completed - Celsa
# 484: Scraping: 4.37% completed -  abb ag
# 485: Scraping: 4.38% completed - Minoko design as
# 486: Scraping: 4.39% completed - Torque-jet gmbh
# 487: Scraping: 4.4% completed -  johnson matthey technology centre
# 488: Scraping: 4.41% completed - Fau
# 489: Scraping: 4.41% completed - Mikrocentrum
# 490: Scraping: 4.42% completed -  lumi industries
# 491: Scraping: 4.43% completed - Central scanning worcester
# 492: Scraping: 4.44% completed - Minsait
# 493: Scraping: 4.45% completed - Mill precision engineers ltd
# 494: Scraping: 4.46% completed - Mimeos
# 495: Scraping: 4.47% completed - Cemengal
# 496: Scraping: 4.48% completed - Celwise ab
# 497: Scraping: 4.49% completed - Torus technology group
# 498: Scraping: 4.5% completed - Cemk
# 499: Scraping: 4.5% completed - Modelar solutions
# 500: Scraping: 4.51% completed - Miguel haro
# 501: Scraping: 4.52% completed - Torneria automatica faentina
# 502: Scraping: 4.53% completed - Centro ortopedico tecnologico
# 503: Scraping: 4.54% completed - MICROSOFT
# 504: Scraping: 4.55% completed - Ceetak ltd
# 505: Scraping: 4.56% completed - Centro ortopedico torrejon,s.l.
# 506: Scraping: 4.57% completed - Mm m  a member of daikin group aaf-international b.v.
# 507: Scraping: 4.58% completed - Centro ortopedico extremeño
# 508: Scraping: 4.59% completed - Centro ortopedico venezuela s.l.
# 509: Scraping: 4.59% completed - Microhelis.de
# 510: Scraping: 4.6% completed - Cecosa
# 511: Scraping: 4.61% completed - Microdrones
# 512: Scraping: 4.62% completed - Microdesk
# 513: Scraping: 4.63% completed - Faza s.r.l.
# 514: Scraping: 4.64% completed - Microsonic gmbh
# 515: Scraping: 4.65% completed - Misumi
# 516: Scraping: 4.66% completed - Tornejats i mecanitzats sl
# 517: Scraping: 4.67% completed -  strahl kraft metalltechnik schmidt gmbh & co. kg
# 518: Scraping: 4.68% completed - Mitsubishi electric europe
# 519: Scraping: 4.68% completed - Mitsubishi Electric Europe B.V. Polish Branch
# 520: Scraping: 4.69% completed - Centro ortopedico cuadrado
# 521: Scraping: 4.7% completed - Top3dshop
# 522: Scraping: 4.71% completed - Centre r&d nestle purina
# 523: Scraping: 4.72% completed - Top. light
# 524: Scraping: 4.73% completed - Mivetek
# 525: Scraping: 4.74% completed - Top light
# 526: Scraping: 4.75% completed - Middlesex university trent park campus
# 527: Scraping: 4.76% completed - Cariotipo
# 528: Scraping: 4.77% completed - Morph
# 529: Scraping: 4.78% completed - Carmengarciavfx
# 530: Scraping: 4.78% completed - Carmen toro
# 531: Scraping: 4.79% completed - Müller erfindungen
# 532: Scraping: 4.8% completed - 2acad
# 533: Scraping: 4.81% completed - Müller systeme gmbh
# 534: Scraping: 4.82% completed - Mühlbauer gmbh & co. kg
# 535: Scraping: 4.83% completed - Meritaistelukeikus Merivoimat
# 536: Scraping: 4.84% completed - Charpak ltd
# 537: Scraping: 4.85% completed - Carlos jose canut roldan
# 538: Scraping: 4.86% completed - Multirotor
# 539: Scraping: 4.87% completed - 2acad global group
# 540: Scraping: 4.87% completed - Merck
# 541: Scraping: 4.88% completed - Carlos núñez
# 542: Scraping: 4.89% completed - 2acad global group s.l.
# 543: Scraping: 4.9% completed - Charles kieffer group
# 544: Scraping: 4.91% completed - Mtu friedrichshafen gmbh royce power systems company
# 545: Scraping: 4.92% completed - To be determined later
# 546: Scraping: 4.93% completed - Mt ortho
# 547: Scraping: 4.94% completed - Mta prototyping gmbh
# 548: Scraping: 4.95% completed - Chalmers university
# 549: Scraping: 4.96% completed - 24studiobim
# 550: Scraping: 4.96% completed - Chamber of commerce and industry of belarus
# 551: Scraping: 4.97% completed - Chaneco
# 552: Scraping: 4.98% completed - Mtu aero engines ag
# 553: Scraping: 4.99% completed - Msl control.usa
# 554: Scraping: 5.0% completed - Mundos digitales
# 555: Scraping: 5.01% completed - Municipalité d'ecully
# 556: Scraping: 5.02% completed - 2shapes technologies slu
# 557: Scraping: 5.03% completed - Myeasy3d
# 558: Scraping: 5.04% completed - Meljac
# 559: Scraping: 5.05% completed - Faiveley (wabtec)
# 560: Scraping: 5.06% completed - China-Euro Vehicle Technology
# 561: Scraping: 5.06% completed - 2shapes
# 562: Scraping: 5.07% completed - Melba products ltd
# 563: Scraping: 5.08% completed - Carl wittkopp
# 564: Scraping: 5.09% completed - Mekverken tool
# 565: Scraping: 5.1% completed - Faithful+gould
# 566: Scraping: 5.11% completed - 3 consulting
# 567: Scraping: 5.12% completed - My travel
# 568: Scraping: 5.13% completed - Menasco
# 569: Scraping: 5.14% completed - Chelsea22
# 570: Scraping: 5.15% completed - Chelsea22, slu
# 571: Scraping: 5.15% completed - Mercedes-amg gmbh
# 572: Scraping: 5.16% completed - Feronyl nv
# 573: Scraping: 5.17% completed - Muodonmuutos oy
# 574: Scraping: 5.18% completed - Muovipoli
# 575: Scraping: 5.19% completed - Chief technology elektronische geräte-gesellschaft m.b.h. riedelbach technologiepark
# 576: Scraping: 5.2% completed - Mercadona
# 577: Scraping: 5.21% completed - Musi lublin
# 578: Scraping: 5.22% completed - Muuntosaâ¤hko oy trafox
# 579: Scraping: 5.23% completed - Mvn arquitectos
# 580: Scraping: 5.24% completed - Ferralca
# 581: Scraping: 5.24% completed - To be identified later
# 582: Scraping: 5.25% completed - Catepillar
# 583: Scraping: 5.26% completed - Metalsoto
# 584: Scraping: 5.27% completed - Famag s.r.l.
# 585: Scraping: 5.28% completed - Castor technologies ltd.
# 586: Scraping: 5.29% completed - 1a ingenieros
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-e4d6fe09b7ec> in <module>
#      27     elementID.send_keys(Keys.BACKSPACE)
#      28     elementID.send_keys(company)
# ---> 29     elementID.submit()
#      30
#      31
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in submit(self)
#      87                 "var e = arguments[0].ownerDocument.createEvent('Event');"
#      88                 "e.initEvent('submit', true, true);"
# ---> 89                 "if (arguments[0].dispatchEvent(e)) { arguments[0].submit() }", form)
#      90         else:
#      91             self._execute(Command.SUBMIT_ELEMENT)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
companies_list

grid_header = ['Name','Sitio web', 'Sede', 'Tamaño', 'Fundada en', 'Tipo', 'Sector', 'Ingresos']
dataframe = []

for k in range(0,companies_count):
    j = 0
    i = 0
    lista = []

    while i< len(grid_header):
        try:
            if grid_header[i] == companies_list[0+k*2][j]:
                field = companies_list[1+k*2][j]
            else:
                field = None
                j -= 1
            lista.append(field)
            j +=1

        except:
            lista.append(None)
        i += 1    
    dataframe.append(lista)
    
df = pd.DataFrame.from_records(dataframe,columns=grid_header)
print(df[df['Ingresos']!=None].count()[7]/companies_count*100)
df
# Out:
# 28.327645051194537
#                          Name                         Sitio web                   Sede                  Tamaño      Fundada en                               Tipo                                     Sector                          Ingresos
# 0                Daimler corp                              None                   None                    None            None                               None                                       None                              None
# 1      Curt nicolin gymnasiet                              None                   None                    None            None                               None                                       None                              None
# 2          Kongsberg maritime                 www.kongsberg.com    Kongsberg (Noruega)   De 51 a 200 empleados  Desconocido(a)       Filial o segmento de negocio  Servicios derivados del gas y el petróleo  Desconocido/No aplicable por año
# 3                   Ad adenta                              None                   None                    None            None                               None                                       None                              None
# 4                      Prisca  www.priscabeautyandcosmetics.com  Cebu City (Filipinas)             Desconocido  Desconocido(a)                    Empresa privada                             Desconocido(a)  Desconocido/No aplicable por año
# ..                        ...                               ...                    ...                     ...             ...                                ...                                        ...                               ...
# 581                Catepillar                              None                   None                    None            None                               None                                       None                              None
# 582                 Metalsoto                              None                   None                    None            None                               None                                       None                              None
# 583              Famag s.r.l.                  www.neitraco.com  Bunnik (Países Bajos)  De 201 a 500 empleados            1961                     Desconocido(a)                             Desconocido(a)  Desconocido/No aplicable por año
# 584  Castor technologies ltd.                              None                   None                    None            None                               None                                       None                              None
# 585             1a ingenieros              www.1aingenieros.com             Valladolid             Desconocido  Desconocido(a)  Empresa privada (cotiza en bolsa)                             Desconocido(a)  Desconocido/No aplicable por año
#
# [586 rows x 8 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#############################################
focus_on = 'Ingresos'
#############################################

sns.set(style="darkgrid")
plt.figure(figsize=(15,20))
sns.set(font_scale = 1.5)
sns.countplot(y=focus_on, data=df, color="b", order = df[focus_on].value_counts().index)
plt.show()

# %%
df.to_excel("Scrapping revenue neg (10130-10716).xlsx")
