# %%
import os, random, sys, time
# from urllib.parse import urlparse
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.common.exceptions import NoSuchElementException

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
### LOGIN
##############################################################
browser = webdriver.Chrome('driver/chromedriver.exe')
browser.get('https://www.glassdoor.es/profile/login_input.htm?userOriginHook=HEADER_SIGNIN_LINK')

# %%
file = open('config_glassdoor.txt')
lines = file.readlines()
username = lines[0]
password = lines[1]

time.sleep(round(random.uniform(1, 2),2))

##############################################################
elementID = browser.find_element_by_id('userEmail')
elementID.send_keys(username)
time.sleep(round(random.uniform(1, 1.3),2))

elementID = browser.find_element_by_id('userPassword')
elementID.send_keys(password)
time.sleep(round(random.uniform(1, 2),2))

elementID.submit()

# %%
# READ
##############################################################
leads_df = pd.read_csv('data2.csv')
leads_df = leads_df.sort_values(by=['FYQ Created On Correct'], ascending=False)
leads_df = leads_df[leads_df['Lead Status']!='Qualified']

company_list = leads_df['Company']
company_list = company_list.dropna() 
company_list = company_list.drop_duplicates()
company_list = company_list.tolist()

##############################################################
companies = company_list[1618:]
##############################################################
companies
# Out:
# ['Salli',
#  'Artdenteck',
#  'Kongsberg automotive',
#  'Gaiker',
#  'Prinemo, Lda.',
#  'Sugu printers and stationers',
#  'AVINENT IMPLANT SYSTEM',
#  'Dubex bv',
#  'Laser instruments',
#  'Ggk gmbh & co. kg',
#  'Dow',
#  'Avm bvba',
#  'Süss microtec ag',
#  'Art meets science',
#  'Avoset',
#  'Eco concept 3d',
#  'Ghesa',
#  'Gammaplast-italia',
#  'Kuka systems uk limited',
#  'SAlesianos DEsuto',
#  'Konia s.r.l.',
#  'Sujan CooperStandard',
#  'Aufratech',
#  'Avanti wind systems sl',
#  'Nexion engineering',
#  'Nexgen plasstek',
#  'Ave spa',
#  'Nour packaging',
#  'Saarstahl (gbq)',
#  'Print 3d',
#  'Le quay orthopédie',
#  'ECKA GRANULES GERMANY',
#  'Salermac s.r.l.',
#  'Auditel Ingenueria',
#  'Nexans',
#  'Tai smart factory',
#  'Taif',
#  'Desma gmbh',
#  'Eco tallers',
#  'Ghigu- sistemas de seguridad',
#  'S.p.e.r. srl',
#  'Dopak sp. z o.o.',
#  'Gabriele panciera',
#  'Axial 3d',
#  'Koenigsegg automotive ab',
#  'Axilib',
#  'AXILONE METAL',
#  "Ecole des mines d'alès",
#  'Süss microtec se',
#  'Talisman plastics',
#  'Axiome',
#  'Project engineering & contracting nv',
#  'Lecante',
#  'G.p.i. elektrotechniek b.v.',
#  'Aselsan',
#  'Ecom instruments gmbh',
#  'Ledisson a&it',
#  'Arrizabalaga consulting',
#  'Prime medical solutions bvba',
#  'AVX GmbH',
#  'Axelent engineering ab',
#  'Dotto Jewelry',
#  'Salvatore perchinelli',
#  'Comau s.p.a.',
#  'Awl',
#  'Primeast',
#  'Dornbusch GmbH',
#  'Dorna',
#  'Axa seguros',
#  'Dorica srl',
#  'e-cobot',
#  'Newton automation',
#  'Samaplast',
#  'Gamo fahrzeugwerke gmbh',
#  'Samdoc medical technologies',
#  'GAF-Zerbst mbH',
#  'Aucxis cvba',
#  'Aucune',
#  'Sumiriko industry france',
#  'Taengineering AB',
#  'ArcelorMittal Global R&D',
#  'Ngk europe gmbh',
#  'Automechanika birmingham',
#  'Kriskadecor',
#  'Kreol',
#  'Automotive campus brainport',
#  'Automotive components floby ab',
#  'Arvesta',
#  'Arus andalucía racing team',
#  "T.p.a. tecnologie e prodotti per l'automazione s.r.l.",
#  'Automotive research and consulting group',
#  'KraussMaffei Group',
#  'GEZE Iberia',
#  'Lauretti automazioni industrialis.r.l.',
#  'Arup',
#  'Gerflor',
#  'Gerhard Schubert GmbH',
#  'Druck- und verlagshaus zarbock gmbh',
#  'Kranendonk',
#  'Lavin business s.l.u.',
#  'Nordiccad AS',
#  'Nordic vehicle',
#  'Launhardtgmbh',
#  'Automation-technique-industrie sa',
#  'Aurora marlin co., ltd',
#  'None',
#  'Privato',
#  'Autec srl',
#  'Lattice medical',
#  'Ksv koblenzer steuerungs- und verteilungsbau gmbh',
#  'SURFACES SYNERGIE groupe',
#  'Generalitat de catalunya',
#  'Autocraft solutions group',
#  'Safran Helicopter Engines',
#  'Latuz energy',
#  'Kuhn farm machinery',
#  'Kuka automatisering + robots nv',
#  'ebm-papst Mulfingen GmbH & Co. KG',
#  'Autoliv',
#  'Automata gmbh & co. kg',
#  'Geo-groep nv',
#  'Sagitario lighting',
#  'Galmetec, SL',
#  'Kramp',
#  'Kraken 3D Studios',
#  'eb-Tec',
#  'Sunfab hydraulics ab',
#  'Laxo mekan ab',
#  'Gallerengineering',
#  'Autoscuoledesensi',
#  'Kostal',
#  'Gallax ooo',
#  'Laser Zentrum Hannover e. V.',
#  'Artkb',
#  'Getadroner',
#  'Saber s.r.l.',
#  'Saarstahl(gbq)',
#  'Korrels',
#  'Tacones prats, sl',
#  'Dr. langer medical gmbh',
#  'Kontaktdaten',
#  'Sundyne',
#  'T. Campiños SL',
#  'NICHIRIN SPAIN SLU',
#  'Kuka pirk',
#  'Suomen amputoidut ry',
#  'Nort3D',
#  'Lastfordonsgruppen Association',
#  'Dro succ lenoir',
#  'Galliker 3d-druck',
#  'Saint-Gobain',
#  'Printing',
#  'Gestamp biw',
#  'autónomo',
#  'PROFIDTP, d. o. o.',
#  'Dreiling maschinenbau',
#  'Sunnmore MR-Klinikk',
#  'Nicoll',
#  'Koenig & bauer sheetfed ag & co. kg',
#  'Ecometeo italia',
#  'King Faisal Specialist Hospital & Research Centre',
#  'Nevs ab',
#  'BAHSYS GmbH',
#  'NRU GmbH',
#  'Nevs',
#  'S. & l. di carletti mauro & c.sas',
#  'Promens as member of berry | bramlage',
#  'Giornale di brescia',
#  'Gioseppo',
#  'Baker',
#  'Bakic',
#  'S.el.me.c.s.r.l.',
#  'Gelmini geom. walter',
#  'Safran Additive Manufacturing',
#  'Kima process control gmbh',
#  'Distretto aerospaziale della campania - dac',
#  'Lendlease',
#  'Giurgola',
#  'Atos',
#  'Edalis',
#  'Studio facchetti',
#  'Pretcorr computers',
#  'Studio mango b.v.',
#  'Bada',
#  'Tama',
#  'SAFRAN AIRCARFT ENGINES',
#  'Noxifer',
#  'Npk',
#  'Leiden University',
#  'Studio ing. mauro parolini',
#  'Edag',
#  'Studio giotto associato',
#  'Area-progetto urban modu',
#  'Dma group',
#  'Promecc srl',
#  'San. tic. ltd. §ti.',
#  'Gimltd',
#  'No Metal 3D',
#  'Gividi fabrics s.r.l.',
#  'SAFRAN',
#  'Taurus',
#  "Studio d'architettura",
#  'Kh lloreda, sa',
#  'RYSIA',
#  'Kh engineering b.v.',
#  'Studio cairoli',
#  'Studio associato oikos',
#  'Nts',
#  'Premium food concept',
#  'Studio architetto cabrini davide',
#  'Nubotica factory',
#  'Arcelormittal innovación investigación e inversión',
#  'Num s.p.a.',
#  'Barco nv',
#  'Kibus Petcare',
#  'Architetto',
#  'Lenoir dro',
#  "L\\'usine3d",
#  'Ballo',
#  'Gefeg-neckar antriebssysteme gmbh',
#  'Studio di architettura',
#  'Disoccupato',
#  'Ntis',
#  'Systech',
#  'Baluer, sl',
#  'Duplomatic ms',
#  'Premo group',
#  'kic',
#  'BAM GmbH',
#  'Gardenia onlus',
#  'Architetto boris zlatkov',
#  'Fundación IDONIAL',
#  'Nowitec ag',
#  'Back quality ergonomics b.v.',
#  'Bacher virtual tour',
#  'Newmatec',
#  'Ecotelea s.r.l.',
#  'Suture',
#  'Studio tecnico di progettazione',
#  'Kmw',
#  'Gigames',
#  'Kms meyer',
#  'Newelec sa',
#  'Newcut,s.l.',
#  'Samson nv',
#  'Km soltec',
#  'Kluthe',
#  'Studio tecnico',
#  'Lego',
#  'NEWCO Safety Technologies',
#  'Attività commerciale di articoli tecnici industriali e nautici/navali',
#  'Studio tecnico piazza',
#  'Doga gestio',
#  'NOVATTIA DESARROLLOS',
#  'DONE Lab',
#  'Eaton industries (belgium) bvba',
#  'Leds & components experts',
#  'Axon cable',
#  'Kobe innovation engineering',
#  'Leds c4',
#  'Axxicon moulds eindhoven b.v.',
#  'Axyal',
#  'Novatech Engineering',
#  'Ayrox',
#  'Atusa',
#  'Studio zerbini',
#  'SAFRAN AIRCRAFT ENGINES',
#  'Knipex-Werk',
#  'Arkema',
#  'AZ Maria Middelares',
#  'Kliniken Maria Hilf GmbH',
#  'Kjærgaard A/S',
#  'Giglio orthopedie',
#  'Aries',
#  'Giglio Orthopédie SA',
#  'B.p.e.elettronica',
#  'Klaudia koziet',
#  'B.v. aannemingsbedrijf h. verwater & zonen',
#  'Studio rotor',
#  'Tallinn university of technology',
#  'Dobit nv',
#  'Novolux',
#  'Novoscen ab',
#  'Novotic',
#  'Novotic s.r.l.',
#  'kuunda3d',
#  'DNV GL',
#  'Studio pma',
#  'Novotic srl',
#  'Pro2 automotive engineering limited',
#  'Leichtbauzentrum Sachsen',
#  'Ecv sa',
#  'Pro med instruments gmbh',
#  'Doesburg components',
#  'Documentación e Imagen del Noroeste (GRUPO SOLITIUM)',
#  'G&W Joos GmbH',
#  'Duepi',
#  'B&c systems',
#  'Duepi srl',
#  'Kupron prototypes bv',
#  'Neways technologies',
#  'B&m longworth (edgworth) ltd',
#  'B&m maschinenbau gmbh',
#  'B&w engineering gmbh',
#  'Novo nordisk',
#  'B. braun surgical',
#  'G&W Joos',
#  'Klenke druck gmbh & co. kg',
#  'B. naaktgeboren b.v',
#  'B. y g. suministros ortopedicos',
#  'Klaveness footwear oy',
#  'B.c.e.s.r.l.',
#  'Gino gmbh elektrotechnische fabrik',
#  'Innome gmbh',
#  'John deere',
#  'Palemo electronics',
#  'Coventry university',
#  'Cejn ab',
#  'Hf gmbh elektroplanung',
#  'Pallmann.eu',
#  'Cel sa',
#  'Coty',
#  'Cellier orthopédie',
#  'Hh',
#  'Celo fijaciones',
#  'Celo, sa',
#  'Costruzioni elettroniche canavesane di dr. marco monateri e c.s.a.s.',
#  'Celsa group',
#  'Celulosa fabril',
#  'Costruzione e manutenzione stampi',
#  'Selmec srl',
#  'Cemas germany',
#  'Planlicht gmbh & co kg',
#  'COSNTRUCCIONES Y REFORMAS ZAER S.L.',
#  'Cosmolux',
#  'Panorámica latinoamericana - ue',
#  'Cenim-csic',
#  'IMG Pharma Biotech',
#  'Sit - metering division (metersit)',
#  'Center of Oncology - Cracow Division',
#  'Sistemi automatici',
#  'Imprimakers',
#  'Coventya gmbh',
#  'Heuille',
#  'Paccar parts europe',
#  'Cci indre',
#  'skytendersolutions',
#  'Plasti ouest',
#  'Cdi',
#  'Sks industrielackierungen gmbh & co. kg',
#  'Plastcorner',
#  'Inalfa',
#  'Skoda auto a.s.',
#  'Inacorte, Lda.',
#  'Skoberne',
#  'Cea',
#  'Hexonia GmbH',
#  'Cea tech',
#  'In industrie und handwerk an der rwth aachen',
#  'In cerca di occupazione',
#  'Hevert arzneimittel gmbh & co. kg',
#  'Plasma-kunststofftechnik.de',
#  'Hexadrone',
#  'Skf sverige ab',
#  'IMS Production Automation',
#  'Ims medical bv',
#  "Covestro'",
#  'Selectra srl',
#  'Hexcel corporation / skechers',
#  'Central',
#  'Cosmind s.r.l.',
#  'Herzog+heymann gmbh & co. kg',
#  'Pladetec C.A',
#  'Particular',
#  'CORETI',
#  'Ika gmbh',
#  'Cerrajeria fraile, s.l',
#  'Sinterpres, s.l.',
#  'Ik multimedia productions',
#  'Particuler',
#  'Certitudo srl',
#  'Singer-Spritzguss',
#  'Cesol',
#  'CETEC',
#  'Sensor city liverpool limited',
#  'Iis cossatese e vallestrona',
#  'Particulier',
#  'Ihi europe ltd',
#  'Parvis systems and services s.p.a.',
#  'Cevt',
#  'Cevt\xa0',
#  'Pastor Ingeniería Automática',
#  'Separafilt, sl',
#  'Sepleex - industrie sa',
#  'Cepsa',
#  'Sioux technologies',
#  'Ima s.p.a',
#  'Imdea materials',
#  'High value manufacturing catapult',
#  'IMASYS',
#  'Semios',
#  'Semper decorus intentio ltd',
#  'Sistel vallès, sl',
#  'Sis.te.ma. s.r.l. automazione processi industriali',
#  'Centre professionnel du nord vaudois',
#  'Coruñesa de Etiquetas, SL',
#  'Hightech industries s.r.o.',
#  'Imants bv',
#  'Corrotherm international ltd',
#  'Pizzardi srl',
#  'Sipro s.r.l.',
#  'CORPORACIÓN DE COMUNICACIONES - CdeC',
#  'Iluminación Nigrán, SL',
#  'Senet',
#  'Ilpea garvaplast',
#  'Centro studi impara digitale',
#  'Centro tecnológico aimen',
#  'Ilpea galvarplast automotive spain',
#  'Coriolis-composites',
#  'Sl tech2 gmbh',
#  'Ccdfibre',
#  'Patient lifting solutions pls bv',
#  'Carpinteria jinamar',
#  'Smo bvba',
#  'Carital oy / medimattress oy',
#  'Carl ostermann erben gmbh',
#  'Smmt - industry forum',
#  'Croda ibérica',
#  'Heijmans NV',
#  'Smmt',
#  'Croda',
#  'Heijmans utiliteit metaal b.v.',
#  'Industrie ilpea españa, sa',
#  'Plásticos Clossa',
#  'Carlibur',
#  'Oxectur, SL',
#  'Carlo polini',
#  'Carlo ratti associati',
#  'Industrias rehau, sa',
#  'Hella',
#  'Smithers mse ltd',
#  'Carminati s.r.l',
#  'Industrias itte',
#  'Plásticos flome s.l.',
#  'Plásticos flome, sl',
#  'ineos',
#  'Otto-hofstetter.ch',
#  'Csic',
#  'Csem',
#  'Cs',
#  'He2b',
#  'Head office',
#  'Plasticos ruperez sl',
#  'SMRC Automotive Interiors Spain, SLU',
#  'Caracol am',
#  'SMRC Automotive',
#  'Ouest composites industries',
#  'Plásticos Irastorza, SA',
#  'Crp',
#  'Plásticos Mollarri',
#  'Hedgehog oü',
#  'Ö-varvet',
#  'Carbon propulsion',
#  'OVB',
#  'Carburos metálicos',
#  'Cardiatis',
#  'Smp',
#  'Inetronic ag',
#  'Inespasa',
#  'Care comfort bvba',
#  'Helvoet rubber & plastic technologies b.v.',
#  'Oxxid',
#  'Sleep and feel slu',
#  'Creaplast',
#  'Indra sistemas',
#  'Indra',
#  'Hermann reckers gmbh & co. kg',
#  'Hermanos Alfaro',
#  'Segula technologies bv',
#  'Hermanos Julian M. S.L.',
#  'Hermetic-pumpen gmbh',
#  'indOnor AB',
#  'Catino',
#  'indimise',
#  'Herrajes bermi sl',
#  'Plastibor',
#  'Caviti sl',
#  'Caviti, Sl',
#  'Indépendant',
#  'Cavt ltd',
#  'Cbarchitects',
#  'Herrmann Ultraschalltechnik',
#  'Cbre gws',
#  'Sleever machines',
#  'paccalini srl',
#  'Cq',
#  'Creapress',
#  'Segula matra automotive',
#  'P. i. montecicos, calle a s/n  poliuretanosrivas',
#  'Hemos machinebouw bv',
#  'Industrias cosmic sl',
#  'Industrias cosmic',
#  'Seebacher - die experten',
#  'Cartakeback',
#  'Cresme',
#  'industrialfairs',
#  'Creopp-tec',
#  'Creo Interactive s.a.s.',
#  'Caru containers',
#  'Casals cardona industrial, sa',
#  'SMAY',
#  'P t',
#  'SmartPeme - Deputacion de Pontevedra',
#  'P&g service gmbh',
#  'Industral supply lnc',
#  'casting design',
#  'P. Ferro GPF, S.L.',
#  'Indual mobiliario, slu',
#  'Cgi belgium nv',
#  'Sms group gmbh',
#  'Petrima gmbh',
#  'Sidel',
#  'Hombach Kunststofftechnik',
#  'CMC & E',
#  'Cmc ab',
#  'Comune di milano',
#  'Cmevolution',
#  'Pessoal',
#  'Piab',
#  'Cmpuk',
#  'Computronic 5000',
#  'Pi',
#  'Phytec messtechnik gmbh',
#  'Honeywell nv',
#  'Hydra s.r.l.',
#  'Hôpitaux de st maurier',
#  'Hydesign',
#  'Peters surgical',
#  'Hyde aero products',
#  'Hydacfluidcare center',
#  'Cnhind',
#  'Compressor and machine controls nv',
#  'Hydac',
#  'Composites torlop, sl',
#  'Cloudif.ai',
#  'Clorofila digital',
#  'Sides',
#  'Cla s.r.l.',
#  'Höganäs ibérica',
#  'Siemens Gamesa',
#  'Clarke energy',
#  'Siegers technics nv',
#  'Claudio grossi',
#  'Pernoud',
#  'Conform collection ab',
#  'Perron tortay',
#  'I.p.c. europe sprl',
#  'Persiana Barcelona',
#  'Hypermotive',
#  'Hyundai Motor Europe',
#  'Högskolan i halmstad, fab lab halmstad',
#  'Sidel spa',
#  'Pidikei',
#  'Clinica dental',
#  'Sidel blowing & services',
#  'Condor Custom Solutions',
#  'Clinique romande de réadaptation',
#  'Clinique romande de réadatation',
#  'Sic',
#  'Pieni sänkypaja',
#  'Completproject',
#  'Codogno srl',
#  'Humbaur gmbh',
#  'hospital povisa',
#  'Humanitarian prosthetists and orthotists',
#  'Shin-etsu polymer europe b.v.',
#  'Hospital Povisa, SA',
#  'COMEXIGROUP',
#  'Shel',
#  'Hug ag',
#  'Comerio ercole',
#  'Pfm automazioni s.r.l.',
#  'Huber Frau',
#  'Comercial prova sa',
#  'Sfm technology limited',
#  'Comercial de soldadura s.a.',
#  'SGA',
#  'Coloplast a/s',
#  'Coloreel group ab',
#  'Hso herbert schmidt gmbh & co. kg',
#  'Sgm lektra srl',
#  'Shakespeare martineau',
#  'Comatex',
#  'HRC',
#  'hpc',
#  'Cobo s.p.a.',
#  "Coac - col.legi d'arquitectes de catalunya",
#  'Peugeot Citroën Automóviles España, SA',
#  'Company',
#  'Siba gmbh & co. kg',
#  'Siba gmbh',
#  'Compañía de tapones irrellenables torrent',
#  'Husqvarna group',
#  'Siad spa',
#  'Cobo s.p.a',
#  'Commerce',
#  'COC Additive Manufacturing Opel-Vauxhall',
#  'Coca cola italia',
#  'Husqvarna ab',
#  'Hurner schweisstechnik',
#  'Commiotec ab',
#  'Hosokawa Kolb',
#  'Hur',
#  'Hosokawa micron ltd',
#  'Code Product Solutions BV',
#  'Codematica',
#  'Consilium m&s',
#  'Sig',
#  'Hitachi Healthcare',
#  'Ideafactory srl',
#  'Chisco transport nigeria ltd',
#  'Chocal Packaging Solutions',
#  'Ids (industrial decorating solutions)',
#  'Idrosanitaria bonomi s.p.a.',
#  'PCMAYMA',
#  'Simonelectric',
#  'Pintrade',
#  'IDONIAL',
#  'Chromos AG',
#  'Hochschule Albstadt-Sigmaringen',
#  'Chu de montpellier maxilaufacial',
#  'Pdm',
#  'Hochschule coburg',
#  'Pinti inox s.p.a.',
#  'Pdo',
#  'Idi servicios empresariales',
#  'Simon lazaro alcala',
#  'Pininfarina spa',
#  'Contiweb',
#  'Ideenion',
#  'Ideatubo',
#  'Peer energy gmbh',
#  'Pegasus solutions slu',
#  'Simon',
#  'CIDETEC',
#  'Cidori',
#  'Chirurgische kleintierklinik',
#  'Cooerion k tron gmbh',
#  'Chiron group',
#  'Hitonplast',
#  'Chambon',
#  'Sepro robotique',
#  'Hitahh',
#  'Sepro robotique GmbH',
#  'Chapman Black',
#  'ifm electronic',
#  'Hiton plast 2',
#  'Charpak ltd',
#  'Hiway technologies',
#  'HKK Bionics GmbH',
#  'Pbc-ks',
#  'Piombo',
#  'Simon-kucher & partners italia srl',
#  'Sercel',
#  'Chetoni s.r.l.',
#  'CHG-Meridian',
#  'Chiesi farmaceutici s.p.a.',
#  'Ie management gmbh',
#  'China-Euro Vehicle Technology',
#  'ContiTech Fluidtechnik',
#  'Sigit automotive s.l.',
#  'Contitech',
#  'Cirfap',
#  'Cirnapro',
#  'Servicios integrales de mecanizado y mantenimiento fraga sl -simmfrasl-',
#  'Icade',
#  'CIRP',
#  'Signify Netherlands B.V.',
#  'Signify france',
#  'Signify',
#  'Pepperl Fuchs Gmbh',
#  'Consulente ambientale chimico',
#  'Pepsico',
#  'Per spets innovation ab',
#  'Sigmaphi',
#  'Iberpoligraph',
#  'Consulente',
#  'Iberespacio',
#  'Citel',
#  'Ibec',
#  'IBBWMWW',
#  'Città metropolitana di milano',
#  'Performance specialty products ibérica, slu',
#  'Ibarmia',
#  'HOFMANN',
#  "Circolo dell'innovazione",
#  'Cipsa circuits',
#  'Icam',
#  'Contag ag',
#  'Hochschule hamm-lippstadt',
#  'SIMBB HOPITAL PRIVE DE BOIS BERNARD',
#  'Simat s.r.l.',
#  'Idasa aranda, s.l',
#  'Pimas s.r.l.',
#  'Continental - Benecke-Hornschuch Surface Group',
#  'Icube commodities & trading fzc',
#  'Pilze wohlrab gmbh & co. kg',
#  'Contec cvba',
#  'Silvadec',
#  'Cihan',
#  'Pilipili nv',
#  'ICOIIG',
#  'Piline services gmbh & co. kg',
#  'Silencions',
#  'Sikora',
#  'ICINSA, S.A.',
#  'ic-automation Gmbh',
#  'Ciobani e c srl',
#  'CIP ETI Tudela',
#  'Hoda uab',
#  'Icapautomation s.r.l.',
#  'Pentamatik scp',
#  'Cap holding',
#  'Havenhill synergy limited, abuja',
#  'Startup',
#  'Oped gmbh',
#  'spiess + kühne ag',
#  'Spie belgium sa-nv',
#  'Spi service parts',
#  'Ong oadcph',
#  'Spi',
#  'Politecnico di milano',
#  'Online',
#  'Decoinstal',
#  'Schehrer',
#  'Schein orthopadie service kg',
#  'Itainnova',
#  'Borås stad, sven eriksonsgymnasiet',
#  'Borgers',
#  'BORGinsole',
#  'Specma group',
#  'Oostwoud international bv',
#  'Debremarkos university',
#  'Boris zlatkoc',
#  'Bormann EDV',
#  'Deafmetal',
#  'Specma ab',
#  'Borouge',
#  'Bombes psh barcelona s.l.',
#  'Spiessens machinebouw',
#  'Itap spa',
#  'Boge elastmetall gmbh',
#  'Bmw ag niederlassung hannover',
#  'Groupe renault',
#  'Spraying systems autojet europe bvba',
#  'Boc gases',
#  'Omron electronics spa',
#  'Schaeffler france',
#  'Groupe sam',
#  'Schaeffler Italia Srl',
#  'Boehringer-Ingelheim SA',
#  'Splast',
#  'Bofrag',
#  'Boikon',
#  'SPII S.p.A',
#  'Politecnico di Torino',
#  'Deforche engineering nv',
#  'Deeper',
#  'Deep innovations b.v',
#  'Dedime packing',
#  'Bombardier transport france & benelux',
#  'Schafer',
#  'Schako',
#  'Dedan kimathiuniversity',
#  'Isyteg international synergy technology group s.r.l.',
#  'Special mobility bv',
#  'Schaeffler',
#  'Grupo Trinity',
#  'Polinyte',
#  'Schneider Electric',
#  'Polimi',
#  'ISF',
#  'Bowmans',
#  'Isegno srl',
#  'Spa',
#  'David recio s.l.',
#  'Gsk',
#  'Policlinico',
#  'Isc plastic parts',
#  'Gsk - consumer healthcare',
#  'BQ',
#  'BQ Engeneering',
#  'Souriau',
#  'Isaberg rapid ab',
#  'Bracker',
#  'Bräcker AG',
#  'Brady',
#  'Isabellenhütte heusler gmbh & co. kg',
#  'Gsm',
#  'optima packaging',
#  'Brain innovation',
#  'Polirrós, SL',
#  'Isiflo as',
#  'Grupo torrent',
#  'Grupo novolux',
#  'De roeve engineering bvba',
#  'Istituto italiano di tecnologia',
#  'De meyer',
#  'Grupo Herme',
#  'Istanbul/turkey',
#  'Opentext',
#  'Israel',
#  'Isowat Made, SL (Fábrica Isowat)',
#  'GRUPO NEA (SOLITIUM)',
#  'POLITECNICO',
#  'Dcg srl',
#  'Schmersal',
#  'Opin kerfi',
#  'Isoloc',
#  'Grupo sesé',
#  'Botondor',
#  'Bott gmbh & co. kg',
#  'Bottcher systems',
#  'Bottega 4.0',
#  'Schmidbauer transformatoren und gerätebau gmbh',
#  'Groupe PSA',
#  'Gss',
#  'Scania gb',
#  'BIOMODEX',
#  'Bioner',
#  'Jenks & cattell engineering',
#  'Scaglia indeva s.p.a.',
#  'Dentaurum gmbh & co. kg',
#  'Stampaggio termoplastici ad iniezione',
#  'Jcparis (en création)',
#  'Bip',
#  'Dental cap ocean',
#  'Stahl cranesystems',
#  'Birziplastic',
#  'Stagemotion',
#  'Bit Galicia SL',
#  'Scandinova',
#  'Olivia meyer',
#  'Polymercenter',
#  'Polymer system solutions',
#  'Scania CV AB - IT',
#  'Bitron',
#  'Polymecanic',
#  'Bitzer Electronics A/S',
#  'Stanislaw Glowacki',
#  'Jesuïtes el clot',
#  'Jet press',
#  'Sawani alaker',
#  'Desma',
#  'John crane',
#  'Savimex',
#  'Johansen & co produksjon as',
#  'Designofparis',
#  'Polyvlies',
#  'Jogam composants',
#  'Grant thorton uk llp',
#  'Bil sweden association',
#  'Bilfinger tebodin bv',
#  'Joao castro llc',
#  'Poly-Shape',
#  'Graphene green tech, s.l.',
#  'Star group belgium',
#  'Polytype ag',
#  'Jmm skärteknik ab',
#  'Ohl industrial mining & cement',
#  'Öhlins racing ab',
#  'DesignBüro Wenisch & Partner',
#  'Bimec Srl',
#  'Graphisoft',
#  'Binder',
#  'Derungs Licht AG',
#  'Janssen',
#  'Bizzotto giovanni automation s.r.l.',
#  'Ittlab',
#  'Stadele engineering',
#  'Groupe bel',
#  'Iwt',
#  'IWK (an ATS Company)',
#  'Iwk',
#  'Omni-moulage',
#  'Sr',
#  'Ivascular',
#  'Squire patton boggs uk llp',
#  'Schaefer gmbh &amp; co. kg',
#  'Omp srl',
#  'Omron',
#  'Iurreta lhi',
#  'Itwmedical',
#  'Delphi automotive systems luxembourg s.a',
#  'Springer systems plastics gmbh',
#  'Groupe g2m',
#  'BMF Precision Inc',
#  'Bmo',
#  'Nenhuma',
#  'Bms progetti',
#  'Group company',
#  'Delta dore',
#  'Omas s.r.l.',
#  'Bjb procesa',
#  'Janitza electronics gmbh',
#  'BKS GmbH',
#  'Grewus gmbh',
#  'Jan-hendri k.rathmannoalbis com albis',
#  'Grifell pons sl',
#  'Stacem',
#  'Denadai',
#  'Demeure orthopédie / groupe g2m',
#  'Dematic nv',
#  'Dematic',
#  'Jaguar land rover',
#  'Omcometals',
#  'Omefa european plastics & tooling',
#  'Grob gmbh antriebstechnik',
#  'Dema spa',
#  'Jackys business solutions',
#  'Groots',
#  'Ssm',
#  'Srm',
#  'Delta kunststoffe ag',
#  'Iron steel financial company srl',
#  'Gt',
#  'Cantieri di pisa srl',
#  'Oscatech microinyección, sl',
#  'Dac',
#  'Haltija group oy, helsinki',
#  'Haltija group oy, vaasa',
#  'Hamad Medical Corporation',
#  'Score b.v.',
#  'Insal nv',
#  'cab Produkttechnik',
#  'Cabinet dentaire deudon sa',
#  'Cabiomede',
#  'Scott automation',
#  'D.w electronics',
#  'INPLANOR, SL',
#  'scpf',
#  'Soenen NV',
#  'Cad services',
#  'Cad technologie möslein gmbh',
#  'Innowita',
#  'D. cloostermans-huwaert nv',
#  'Platinium 3d',
#  'Sodeca',
#  'Scuola',
#  'Plata cordobesa',
#  'Innova industrial design',
#  'CADE SOLUCIONES',
#  'Cadenas italiana s.r.l.',
#  'Soft-futur sol. inf. sl',
#  'Softronica sa',
#  'Dac (distretto aerospaziale della campania)',
#  'orthoteh',
#  'Haldex',
#  'Orthoway lille',
#  'Bw-papersystems stuttgart',
#  'Bwt-group',
#  'Solidmakarna ab',
#  'Scm images',
#  'Institut llobregat',
#  'Ploeger machines bv',
#  'Solid Idea',
#  'Institut für kunststofftechnik uni. stuttgart',
#  'Solergon',
#  'INSTITUT FUR KUNSTSTOFF- TECHNIK DARMSTADT',
#  'DAF Trucks N.V.',
#  'Sohatex gmbh',
#  'PlK',
#  'Plejd ab',
#  'Plejd',
#  'Sogal',
#  'Cadenas italiana srl',
#  'Socomec',
#  'Buzzer',
#  'Ot4 orthopädietechnik gmbh',
#  'Harry-brot gmbh',
#  'Cubéco',
#  'Plastikakritis',
#  'Sealed air',
#  'Harting Electric',
#  'Plastiflex group nv',
#  'Ing. luca baffoni',
#  'Plastidue srl',
#  'Ing. giordano zappa',
#  'Campa',
#  'Sna Europe',
#  'Ing. francesco giani',
#  'CTAG',
#  'Ing. enrico salama',
#  'campetella robotic center',
#  'Campiños',
#  'SmurfyLanComputer',
#  'Haug gmbh & co.kg',
#  'Ing marchetti antonio',
#  'Plastidue s.r.l.',
#  'Hautes etudes ingenieurs',
#  ...]

# %%
### LOOP
##############################################################

companies_list = []
companies_count = 0

browser.get('https://www.glassdoor.es/Opiniones/hp-inc-opiniones-SRCH_KE0,6.htm')

for company in companies:
    error = False
    inside_page = False
    headers_list = []
    comp_data_list = []
    
    headers_list.append('Name')
    comp_data_list.append(company)
    
    time.sleep(round(random.uniform(3, 4),2))

    elementID = browser.find_element_by_id('sc.keyword')
    elementID.send_keys(Keys.CONTROL, 'a')
    elementID.send_keys(Keys.BACKSPACE)
    elementID.send_keys(company)
    elementID.submit()
    
#     comp_search = "https://www.glassdoor.es/Opiniones/"
#     fullLink_search = comp_search + company + '-opiniones-SRCH_KE0,7.htm'
#     browser.get(fullLink_search)
    
    time.sleep(round(random.uniform(5, 7),2))
    
    ### SOMETIMES IT ENTERS THE PAGE DIRECTLY
    try:
        browser.find_element_by_xpath("//span[@class='sqLogo tighten lgSqLogo logoOverlay']//img").click()
        inside_page = True
    except:
        pass
    
    # IF COMPANY NOT FOUND, CATCH.
    if inside_page == False:
        try:
            browser.find_element_by_xpath("//body[contains(@class,'_initOk noTouch tablet mobileFF')]/div[contains(@class,'pageContentWrapper')]/div[@id='PageContent']/div[@id='PageBodyContents']/div[contains(@class,'pageInsideContent cf')]/div[@id='EI-Srch']/div[@id='SearchResults']/div[@id='ReviewSearchResults']/article[@id='MainCol']/div[contains(@class,'module')]/div[2]/div[1]/div[2]/div[1]").click()  
        except NoSuchElementException:  #spelling error making this code not work as expected
            error = True
            
    time.sleep(round(random.uniform(5, 6),2))    
    
    if error==False:    
        src = browser.page_source
        soup = BeautifulSoup(src, 'lxml')
        
        try:
            company_div = soup.find('div', {'class': 'info flexbox row col-hh'})
            header = company_div.find_all('label')
            info = company_div.find_all('span')
        except:
            pass

        for i in range(0,len(header)):
            headers_list.append(header[i].get_text().strip())
            comp_data_list.append(info[i].get_text().strip())

    companies_list.append(headers_list)
    companies_list.append(comp_data_list)

    companies_count = companies_count+1
    if companies_count % 250 == 0:
        time.sleep(round(random.uniform(65, 90),2))
    print('{}: Scraping: {}% completed - {}'.format(companies_count,round(companies_count/len(companies)*100,2),company))
# Out:
# 1: Scraping: 0.0% completed - Salli
# 2: Scraping: 0.01% completed - Artdenteck
# 3: Scraping: 0.01% completed - Kongsberg automotive
# 4: Scraping: 0.02% completed - Gaiker
# 5: Scraping: 0.02% completed - Prinemo, Lda.
# 6: Scraping: 0.03% completed - Sugu printers and stationers
# 7: Scraping: 0.03% completed - AVINENT IMPLANT SYSTEM
# 8: Scraping: 0.04% completed - Dubex bv
# 9: Scraping: 0.04% completed - Laser instruments
# 10: Scraping: 0.05% completed - Ggk gmbh & co. kg
# 11: Scraping: 0.05% completed - Dow
# 12: Scraping: 0.06% completed - Avm bvba
# 13: Scraping: 0.06% completed - Süss microtec ag
# 14: Scraping: 0.06% completed - Art meets science
# 15: Scraping: 0.07% completed - Avoset
# 16: Scraping: 0.07% completed - Eco concept 3d
# 17: Scraping: 0.08% completed - Ghesa
# 18: Scraping: 0.08% completed - Gammaplast-italia
# 19: Scraping: 0.09% completed - Kuka systems uk limited
# 20: Scraping: 0.09% completed - SAlesianos DEsuto
# 21: Scraping: 0.1% completed - Konia s.r.l.
# 22: Scraping: 0.1% completed - Sujan CooperStandard
# 23: Scraping: 0.11% completed - Aufratech
# 24: Scraping: 0.11% completed - Avanti wind systems sl
# 25: Scraping: 0.12% completed - Nexion engineering
# 26: Scraping: 0.12% completed - Nexgen plasstek
# 27: Scraping: 0.12% completed - Ave spa
# 28: Scraping: 0.13% completed - Nour packaging
# 29: Scraping: 0.13% completed - Saarstahl (gbq)
# 30: Scraping: 0.14% completed - Print 3d
# 31: Scraping: 0.14% completed - Le quay orthopédie
# 32: Scraping: 0.15% completed - ECKA GRANULES GERMANY
# 33: Scraping: 0.15% completed - Salermac s.r.l.
# 34: Scraping: 0.16% completed - Auditel Ingenueria
# 35: Scraping: 0.16% completed - Nexans
# 36: Scraping: 0.17% completed - Tai smart factory
# 37: Scraping: 0.17% completed - Taif
# 38: Scraping: 0.18% completed - Desma gmbh
# 39: Scraping: 0.18% completed - Eco tallers
# 40: Scraping: 0.18% completed - Ghigu- sistemas de seguridad
# 41: Scraping: 0.19% completed - S.p.e.r. srl
# 42: Scraping: 0.19% completed - Dopak sp. z o.o.
# 43: Scraping: 0.2% completed - Gabriele panciera
# 44: Scraping: 0.2% completed - Axial 3d
# 45: Scraping: 0.21% completed - Koenigsegg automotive ab
# 46: Scraping: 0.21% completed - Axilib
# 47: Scraping: 0.22% completed - AXILONE METAL
# 48: Scraping: 0.22% completed - Ecole des mines d'alès
# 49: Scraping: 0.23% completed - Süss microtec se
# 50: Scraping: 0.23% completed - Talisman plastics
# 51: Scraping: 0.24% completed - Axiome
# 52: Scraping: 0.24% completed - Project engineering & contracting nv
# 53: Scraping: 0.24% completed - Lecante
# 54: Scraping: 0.25% completed - G.p.i. elektrotechniek b.v.
# 55: Scraping: 0.25% completed - Aselsan
# 56: Scraping: 0.26% completed - Ecom instruments gmbh
# 57: Scraping: 0.26% completed - Ledisson a&it
# 58: Scraping: 0.27% completed - Arrizabalaga consulting
# 59: Scraping: 0.27% completed - Prime medical solutions bvba
# 60: Scraping: 0.28% completed - AVX GmbH
# 61: Scraping: 0.28% completed - Axelent engineering ab
# 62: Scraping: 0.29% completed - Dotto Jewelry
# 63: Scraping: 0.29% completed - Salvatore perchinelli
# 64: Scraping: 0.29% completed - Comau s.p.a.
# 65: Scraping: 0.3% completed - Awl
# 66: Scraping: 0.3% completed - Primeast
# 67: Scraping: 0.31% completed - Dornbusch GmbH
# 68: Scraping: 0.31% completed - Dorna
# 69: Scraping: 0.32% completed - Axa seguros
# 70: Scraping: 0.32% completed - Dorica srl
# 71: Scraping: 0.33% completed - e-cobot
# 72: Scraping: 0.33% completed - Newton automation
# 73: Scraping: 0.34% completed - Samaplast
# 74: Scraping: 0.34% completed - Gamo fahrzeugwerke gmbh
# 75: Scraping: 0.35% completed - Samdoc medical technologies
# 76: Scraping: 0.35% completed - GAF-Zerbst mbH
# 77: Scraping: 0.35% completed - Aucxis cvba
# 78: Scraping: 0.36% completed - Aucune
# 79: Scraping: 0.36% completed - Sumiriko industry france
# 80: Scraping: 0.37% completed - Taengineering AB
# 81: Scraping: 0.37% completed - ArcelorMittal Global R&D
# 82: Scraping: 0.38% completed - Ngk europe gmbh
# 83: Scraping: 0.38% completed - Automechanika birmingham
# 84: Scraping: 0.39% completed - Kriskadecor
# 85: Scraping: 0.39% completed - Kreol
# 86: Scraping: 0.4% completed - Automotive campus brainport
# 87: Scraping: 0.4% completed - Automotive components floby ab
# 88: Scraping: 0.41% completed - Arvesta
# 89: Scraping: 0.41% completed - Arus andalucía racing team
# 90: Scraping: 0.41% completed - T.p.a. tecnologie e prodotti per l'automazione s.r.l.
# 91: Scraping: 0.42% completed - Automotive research and consulting group
# 92: Scraping: 0.42% completed - KraussMaffei Group
# 93: Scraping: 0.43% completed - GEZE Iberia
# 94: Scraping: 0.43% completed - Lauretti automazioni industrialis.r.l.
# 95: Scraping: 0.44% completed - Arup
# 96: Scraping: 0.44% completed - Gerflor
# 97: Scraping: 0.45% completed - Gerhard Schubert GmbH
# 98: Scraping: 0.45% completed - Druck- und verlagshaus zarbock gmbh
# 99: Scraping: 0.46% completed - Kranendonk
# 100: Scraping: 0.46% completed - Lavin business s.l.u.
# 101: Scraping: 0.47% completed - Nordiccad AS
# 102: Scraping: 0.47% completed - Nordic vehicle
# 103: Scraping: 0.47% completed - Launhardtgmbh
# 104: Scraping: 0.48% completed - Automation-technique-industrie sa
# 105: Scraping: 0.48% completed - Aurora marlin co., ltd
# 106: Scraping: 0.49% completed - None
# 107: Scraping: 0.49% completed - Privato
# 108: Scraping: 0.5% completed - Autec srl
# 109: Scraping: 0.5% completed - Lattice medical
# 110: Scraping: 0.51% completed - Ksv koblenzer steuerungs- und verteilungsbau gmbh
# 111: Scraping: 0.51% completed - SURFACES SYNERGIE groupe
# 112: Scraping: 0.52% completed - Generalitat de catalunya
# 113: Scraping: 0.52% completed - Autocraft solutions group
# 114: Scraping: 0.53% completed - Safran Helicopter Engines
# 115: Scraping: 0.53% completed - Latuz energy
# 116: Scraping: 0.53% completed - Kuhn farm machinery
# 117: Scraping: 0.54% completed - Kuka automatisering + robots nv
# 118: Scraping: 0.54% completed - ebm-papst Mulfingen GmbH & Co. KG
# 119: Scraping: 0.55% completed - Autoliv
# 120: Scraping: 0.55% completed - Automata gmbh & co. kg
# 121: Scraping: 0.56% completed - Geo-groep nv
# 122: Scraping: 0.56% completed - Sagitario lighting
# 123: Scraping: 0.57% completed - Galmetec, SL
# 124: Scraping: 0.57% completed - Kramp
# 125: Scraping: 0.58% completed - Kraken 3D Studios
# 126: Scraping: 0.58% completed - eb-Tec
# 127: Scraping: 0.59% completed - Sunfab hydraulics ab
# 128: Scraping: 0.59% completed - Laxo mekan ab
# 129: Scraping: 0.59% completed - Gallerengineering
# 130: Scraping: 0.6% completed - Autoscuoledesensi
# 131: Scraping: 0.6% completed - Kostal
# 132: Scraping: 0.61% completed - Gallax ooo
# 133: Scraping: 0.61% completed - Laser Zentrum Hannover e. V.
# 134: Scraping: 0.62% completed - Artkb
# 135: Scraping: 0.62% completed - Getadroner
# 136: Scraping: 0.63% completed - Saber s.r.l.
# 137: Scraping: 0.63% completed - Saarstahl(gbq)
# 138: Scraping: 0.64% completed - Korrels
# 139: Scraping: 0.64% completed - Tacones prats, sl
# 140: Scraping: 0.65% completed - Dr. langer medical gmbh
# 141: Scraping: 0.65% completed - Kontaktdaten
# 142: Scraping: 0.65% completed - Sundyne
# 143: Scraping: 0.66% completed - T. Campiños SL
# 144: Scraping: 0.66% completed - NICHIRIN SPAIN SLU
# 145: Scraping: 0.67% completed - Kuka pirk
# 146: Scraping: 0.67% completed - Suomen amputoidut ry
# 147: Scraping: 0.68% completed - Nort3D
# 148: Scraping: 0.68% completed - Lastfordonsgruppen Association
# 149: Scraping: 0.69% completed - Dro succ lenoir
# 150: Scraping: 0.69% completed - Galliker 3d-druck
# 151: Scraping: 0.7% completed - Saint-Gobain
# 152: Scraping: 0.7% completed - Printing
# 153: Scraping: 0.71% completed - Gestamp biw
# 154: Scraping: 0.71% completed - autónomo
# 155: Scraping: 0.71% completed - PROFIDTP, d. o. o.
# 156: Scraping: 0.72% completed - Dreiling maschinenbau
# 157: Scraping: 0.72% completed - Sunnmore MR-Klinikk
# 158: Scraping: 0.73% completed - Nicoll
# 159: Scraping: 0.73% completed - Koenig & bauer sheetfed ag & co. kg
# 160: Scraping: 0.74% completed - Ecometeo italia
# 161: Scraping: 0.74% completed - King Faisal Specialist Hospital & Research Centre
# 162: Scraping: 0.75% completed - Nevs ab
# 163: Scraping: 0.75% completed - BAHSYS GmbH
# 164: Scraping: 0.76% completed - NRU GmbH
# 165: Scraping: 0.76% completed - Nevs
# 166: Scraping: 0.77% completed - S. & l. di carletti mauro & c.sas
# 167: Scraping: 0.77% completed - Promens as member of berry | bramlage
# 168: Scraping: 0.77% completed - Giornale di brescia
# 169: Scraping: 0.78% completed - Gioseppo
# 170: Scraping: 0.78% completed - Baker
# 171: Scraping: 0.79% completed - Bakic
# 172: Scraping: 0.79% completed - S.el.me.c.s.r.l.
# 173: Scraping: 0.8% completed - Gelmini geom. walter
# 174: Scraping: 0.8% completed - Safran Additive Manufacturing
# 175: Scraping: 0.81% completed - Kima process control gmbh
# 176: Scraping: 0.81% completed - Distretto aerospaziale della campania - dac
# 177: Scraping: 0.82% completed - Lendlease
# 178: Scraping: 0.82% completed - Giurgola
# 179: Scraping: 0.82% completed - Atos
# 180: Scraping: 0.83% completed - Edalis
# 181: Scraping: 0.83% completed - Studio facchetti
# 182: Scraping: 0.84% completed - Pretcorr computers
# 183: Scraping: 0.84% completed - Studio mango b.v.
# 184: Scraping: 0.85% completed - Bada
# 185: Scraping: 0.85% completed - Tama
# 186: Scraping: 0.86% completed - SAFRAN AIRCARFT ENGINES
# 187: Scraping: 0.86% completed - Noxifer
# 188: Scraping: 0.87% completed - Npk
# 189: Scraping: 0.87% completed - Leiden University
# 190: Scraping: 0.88% completed - Studio ing. mauro parolini
# 191: Scraping: 0.88% completed - Edag
# 192: Scraping: 0.88% completed - Studio giotto associato
# 193: Scraping: 0.89% completed - Area-progetto urban modu
# 194: Scraping: 0.89% completed - Dma group
# 195: Scraping: 0.9% completed - Promecc srl
# 196: Scraping: 0.9% completed - San. tic. ltd. §ti.
# 197: Scraping: 0.91% completed - Gimltd
# 198: Scraping: 0.91% completed - No Metal 3D
# 199: Scraping: 0.92% completed - Gividi fabrics s.r.l.
# 200: Scraping: 0.92% completed - SAFRAN
# 201: Scraping: 0.93% completed - Taurus
# 202: Scraping: 0.93% completed - Studio d'architettura
# 203: Scraping: 0.94% completed - Kh lloreda, sa
# 204: Scraping: 0.94% completed - RYSIA
# 205: Scraping: 0.94% completed - Kh engineering b.v.
# 206: Scraping: 0.95% completed - Studio cairoli
# 207: Scraping: 0.95% completed - Studio associato oikos
# 208: Scraping: 0.96% completed - Nts
# 209: Scraping: 0.96% completed - Premium food concept
# 210: Scraping: 0.97% completed - Studio architetto cabrini davide
# 211: Scraping: 0.97% completed - Nubotica factory
# 212: Scraping: 0.98% completed - Arcelormittal innovación investigación e inversión
# 213: Scraping: 0.98% completed - Num s.p.a.
# 214: Scraping: 0.99% completed - Barco nv
# 215: Scraping: 0.99% completed - Kibus Petcare
# 216: Scraping: 1.0% completed - Architetto
# 217: Scraping: 1.0% completed - Lenoir dro
# 218: Scraping: 1.0% completed - L\'usine3d
# 219: Scraping: 1.01% completed - Ballo
# 220: Scraping: 1.01% completed - Gefeg-neckar antriebssysteme gmbh
# 221: Scraping: 1.02% completed - Studio di architettura
# 222: Scraping: 1.02% completed - Disoccupato
# 223: Scraping: 1.03% completed - Ntis
# 224: Scraping: 1.03% completed - Systech
# 225: Scraping: 1.04% completed - Baluer, sl
# 226: Scraping: 1.04% completed - Duplomatic ms
# 227: Scraping: 1.05% completed - Premo group
# 228: Scraping: 1.05% completed - kic
# 229: Scraping: 1.06% completed - BAM GmbH
# 230: Scraping: 1.06% completed - Gardenia onlus
# 231: Scraping: 1.06% completed - Architetto boris zlatkov
# 232: Scraping: 1.07% completed - Fundación IDONIAL
# 233: Scraping: 1.07% completed - Nowitec ag
# 234: Scraping: 1.08% completed - Back quality ergonomics b.v.
# 235: Scraping: 1.08% completed - Bacher virtual tour
# 236: Scraping: 1.09% completed - Newmatec
# 237: Scraping: 1.09% completed - Ecotelea s.r.l.
# 238: Scraping: 1.1% completed - Suture
# 239: Scraping: 1.1% completed - Studio tecnico di progettazione
# 240: Scraping: 1.11% completed - Kmw
# 241: Scraping: 1.11% completed - Gigames
# 242: Scraping: 1.12% completed - Kms meyer
# 243: Scraping: 1.12% completed - Newelec sa
# 244: Scraping: 1.12% completed - Newcut,s.l.
# 245: Scraping: 1.13% completed - Samson nv
# 246: Scraping: 1.13% completed - Km soltec
# 247: Scraping: 1.14% completed - Kluthe
# 248: Scraping: 1.14% completed - Studio tecnico
# 249: Scraping: 1.15% completed - Lego
# 250: Scraping: 1.15% completed - NEWCO Safety Technologies
# 251: Scraping: 1.16% completed - Attività commerciale di articoli tecnici industriali e nautici/navali
# 252: Scraping: 1.16% completed - Studio tecnico piazza
# 253: Scraping: 1.17% completed - Doga gestio
# 254: Scraping: 1.17% completed - NOVATTIA DESARROLLOS
# 255: Scraping: 1.18% completed - DONE Lab
# 256: Scraping: 1.18% completed - Eaton industries (belgium) bvba
# 257: Scraping: 1.18% completed - Leds & components experts
# 258: Scraping: 1.19% completed - Axon cable
# 259: Scraping: 1.19% completed - Kobe innovation engineering
# 260: Scraping: 1.2% completed - Leds c4
# 261: Scraping: 1.2% completed - Axxicon moulds eindhoven b.v.
# 262: Scraping: 1.21% completed - Axyal
# 263: Scraping: 1.21% completed - Novatech Engineering
# 264: Scraping: 1.22% completed - Ayrox
# 265: Scraping: 1.22% completed - Atusa
# 266: Scraping: 1.23% completed - Studio zerbini
# 267: Scraping: 1.23% completed - SAFRAN AIRCRAFT ENGINES
# 268: Scraping: 1.24% completed - Knipex-Werk
# 269: Scraping: 1.24% completed - Arkema
# 270: Scraping: 1.24% completed - AZ Maria Middelares
# 271: Scraping: 1.25% completed - Kliniken Maria Hilf GmbH
# 272: Scraping: 1.25% completed - Kjærgaard A/S
# 273: Scraping: 1.26% completed - Giglio orthopedie
# 274: Scraping: 1.26% completed - Aries
# 275: Scraping: 1.27% completed - Giglio Orthopédie SA
# 276: Scraping: 1.27% completed - B.p.e.elettronica
# 277: Scraping: 1.28% completed - Klaudia koziet
# 278: Scraping: 1.28% completed - B.v. aannemingsbedrijf h. verwater & zonen
# 279: Scraping: 1.29% completed - Studio rotor
# 280: Scraping: 1.29% completed - Tallinn university of technology
# 281: Scraping: 1.29% completed - Dobit nv
# 282: Scraping: 1.3% completed - Novolux
# 283: Scraping: 1.3% completed - Novoscen ab
# 284: Scraping: 1.31% completed - Novotic
# 285: Scraping: 1.31% completed - Novotic s.r.l.
# 286: Scraping: 1.32% completed - kuunda3d
# 287: Scraping: 1.32% completed - DNV GL
# 288: Scraping: 1.33% completed - Studio pma
# 289: Scraping: 1.33% completed - Novotic srl
# 290: Scraping: 1.34% completed - Pro2 automotive engineering limited
# 291: Scraping: 1.34% completed - Leichtbauzentrum Sachsen
# 292: Scraping: 1.35% completed - Ecv sa
# 293: Scraping: 1.35% completed - Pro med instruments gmbh
# 294: Scraping: 1.35% completed - Doesburg components
# 295: Scraping: 1.36% completed - Documentación e Imagen del Noroeste (GRUPO SOLITIUM)
# 296: Scraping: 1.36% completed - G&W Joos GmbH
# 297: Scraping: 1.37% completed - Duepi
# 298: Scraping: 1.37% completed - B&c systems
# 299: Scraping: 1.38% completed - Duepi srl
# 300: Scraping: 1.38% completed - Kupron prototypes bv
# 301: Scraping: 1.39% completed - Neways technologies
# 302: Scraping: 1.39% completed - B&m longworth (edgworth) ltd
# 303: Scraping: 1.4% completed - B&m maschinenbau gmbh
# 304: Scraping: 1.4% completed - B&w engineering gmbh
# 305: Scraping: 1.41% completed - Novo nordisk
# 306: Scraping: 1.41% completed - B. braun surgical
# 307: Scraping: 1.41% completed - G&W Joos
# 308: Scraping: 1.42% completed - Klenke druck gmbh & co. kg
# 309: Scraping: 1.42% completed - B. naaktgeboren b.v
# 310: Scraping: 1.43% completed - B. y g. suministros ortopedicos
# 311: Scraping: 1.43% completed - Klaveness footwear oy
# 312: Scraping: 1.44% completed - B.c.e.s.r.l.
# 313: Scraping: 1.44% completed - Gino gmbh elektrotechnische fabrik
# 314: Scraping: 1.45% completed - Innome gmbh
# 315: Scraping: 1.45% completed - John deere
# 316: Scraping: 1.46% completed - Palemo electronics
# 317: Scraping: 1.46% completed - Coventry university
# 318: Scraping: 1.47% completed - Cejn ab
# 319: Scraping: 1.47% completed - Hf gmbh elektroplanung
# 320: Scraping: 1.47% completed - Pallmann.eu
# 321: Scraping: 1.48% completed - Cel sa
# 322: Scraping: 1.48% completed - Coty
# 323: Scraping: 1.49% completed - Cellier orthopédie
# 324: Scraping: 1.49% completed - Hh
# 325: Scraping: 1.5% completed - Celo fijaciones
# 326: Scraping: 1.5% completed - Celo, sa
# 327: Scraping: 1.51% completed - Costruzioni elettroniche canavesane di dr. marco monateri e c.s.a.s.
# 328: Scraping: 1.51% completed - Celsa group
# 329: Scraping: 1.52% completed - Celulosa fabril
# 330: Scraping: 1.52% completed - Costruzione e manutenzione stampi
# 331: Scraping: 1.53% completed - Selmec srl
# 332: Scraping: 1.53% completed - Cemas germany
# 333: Scraping: 1.53% completed - Planlicht gmbh & co kg
# 334: Scraping: 1.54% completed - COSNTRUCCIONES Y REFORMAS ZAER S.L.
# 335: Scraping: 1.54% completed - Cosmolux
# 336: Scraping: 1.55% completed - Panorámica latinoamericana - ue
# 337: Scraping: 1.55% completed - Cenim-csic
# 338: Scraping: 1.56% completed - IMG Pharma Biotech
# 339: Scraping: 1.56% completed - Sit - metering division (metersit)
# 340: Scraping: 1.57% completed - Center of Oncology - Cracow Division
# 341: Scraping: 1.57% completed - Sistemi automatici
# 342: Scraping: 1.58% completed - Imprimakers
# 343: Scraping: 1.58% completed - Coventya gmbh
# 344: Scraping: 1.59% completed - Heuille
# 345: Scraping: 1.59% completed - Paccar parts europe
# 346: Scraping: 1.59% completed - Cci indre
# 347: Scraping: 1.6% completed - skytendersolutions
# 348: Scraping: 1.6% completed - Plasti ouest
# 349: Scraping: 1.61% completed - Cdi
# 350: Scraping: 1.61% completed - Sks industrielackierungen gmbh & co. kg
# 351: Scraping: 1.62% completed - Plastcorner
# 352: Scraping: 1.62% completed - Inalfa
# 353: Scraping: 1.63% completed - Skoda auto a.s.
# 354: Scraping: 1.63% completed - Inacorte, Lda.
# 355: Scraping: 1.64% completed - Skoberne
# 356: Scraping: 1.64% completed - Cea
# 357: Scraping: 1.65% completed - Hexonia GmbH
# 358: Scraping: 1.65% completed - Cea tech
# 359: Scraping: 1.65% completed - In industrie und handwerk an der rwth aachen
# 360: Scraping: 1.66% completed - In cerca di occupazione
# 361: Scraping: 1.66% completed - Hevert arzneimittel gmbh & co. kg
# 362: Scraping: 1.67% completed - Plasma-kunststofftechnik.de
# 363: Scraping: 1.67% completed - Hexadrone
# 364: Scraping: 1.68% completed - Skf sverige ab
# 365: Scraping: 1.68% completed - IMS Production Automation
# 366: Scraping: 1.69% completed - Ims medical bv
# 367: Scraping: 1.69% completed - Covestro'
# 368: Scraping: 1.7% completed - Selectra srl
# 369: Scraping: 1.7% completed - Hexcel corporation / skechers
# 370: Scraping: 1.71% completed - Central
# 371: Scraping: 1.71% completed - Cosmind s.r.l.
# 372: Scraping: 1.71% completed - Herzog+heymann gmbh & co. kg
# 373: Scraping: 1.72% completed - Pladetec C.A
# 374: Scraping: 1.72% completed - Particular

# %%
companies_list

grid_header = ['Name','Sitio web', 'Sede', 'Tamaño', 'Fundada en', 'Tipo', 'Sector', 'Ingresos']
dataframe = []

for k in range(0,companies_count):
    j = 0
    i = 0
    lista = []

    while i< len(grid_header):
        try:
            if grid_header[i] == companies_list[0+k*2][j]:
                field = companies_list[1+k*2][j]
            else:
                field = None
                j -= 1
            lista.append(field)
            j +=1

        except:
            lista.append(None)
        i += 1    
    dataframe.append(lista)
    
df = pd.DataFrame.from_records(dataframe,columns=grid_header)
print(df[df['Ingresos']!=None].count()[7]/companies_count*100)
df
# Out:
# 22.93144208037825
#                          Name                    Sitio web                 Sede                   Tamaño Fundada en                                     Tipo                                Sector                               Ingresos
# 0                       Salli                         None                 None                     None       None                                     None                                  None                                   None
# 1                  Artdenteck                         None                 None                     None       None                                     None                                  None                                   None
# 2        Kongsberg automotive  www.kongsbergautomotive.com  Kongsberg (Noruega)  De 501 a 1000 empleados       1996  Empresa privada (cotiza en bolsa) (KOA)  Fabricación de equipos de transporte  De 2000 a 5000 millones (EUR) por año
# 3                      Gaiker                         None                 None                     None       None                                     None                                  None                                   None
# 4               Prinemo, Lda.                         None                 None                     None       None                                     None                                  None                                   None
# ..                        ...                          ...                  ...                      ...        ...                                      ...                                   ...                                    ...
# 841                Scandinova                         None                 None                     None       None                                     None                                  None                                   None
# 842              Olivia meyer                         None                 None                     None       None                                     None                                  None                                   None
# 843             Polymercenter                         None                 None                     None       None                                     None                                  None                                   None
# 844  Polymer system solutions                         None                 None                     None       None                                     None                                  None                                   None
# 845         Scania CV AB - IT                         None                 None                     None       None                                     None                                  None                                   None
#
# [846 rows x 8 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#############################################
focus_on = 'Ingresos'
#############################################

sns.set(style="darkgrid")
plt.figure(figsize=(15,20))
sns.set(font_scale = 1.5)
sns.countplot(y=focus_on, data=df, color="b", order = df[focus_on].value_counts().index)

# %%
#  df.to_excel("Scrapping revenue Upp (-1618) 6-3-20.xlsx")
